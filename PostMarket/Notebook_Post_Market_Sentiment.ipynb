# %%
import os
import pandas as pd
import datefinder
from PyPDF2 import PdfReader
import sys
import openai
sys.path.append('../')
from credentials_openai import openai_api_key
import tiktoken 

# Set pandas display options to show full column content
pd.set_option('display.max_colwidth', 50)

# Define the OpenAI API key
openai.api_key = openai_api_key

# %%
# Function to extract date from PDF using datefinder
def extract_date(pdf_path):
    with open(pdf_path, "rb") as pdf_file:
        reader = PdfReader(pdf_file)
        first_page_text = reader.pages[0].extract_text()

        # Use datefinder to extract dates
        matches = datefinder.find_dates(first_page_text)
        for match in matches:
            return match.strftime('%B %d, %Y')

        return "Date not found"

# %%
# Function to process PDF files in a folder and extract dates
def process_pdfs(pdf_folder):
    pdf_info_list = []

    for pdf_filename in os.listdir(pdf_folder):
        if pdf_filename.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, pdf_filename)
            date = extract_date(pdf_path)
            
            if date != "Date not found":
                pdf_info_list.append({"PDF Name": pdf_filename, "Date": date})
            else:
                print(f"Date not found for: {pdf_filename}")

    pdf_df = pd.DataFrame(pdf_info_list)
    return pdf_df

# %%
def openai_sentiment_analysis(text):
    encoding_name = "cl100k_base"  # Replace with the actual encoding name
    
    encoding = tiktoken.get_encoding(encoding_name)
    input_tokens = len(encoding.encode(text))
    
    if input_tokens > 3596:
        num_parts = input_tokens // 3596 + 1
        part_length = len(text) // num_parts
        
        summaries = []
        for i in range(num_parts):
            start_idx = i * part_length
            end_idx = start_idx + part_length
            part_text = text[start_idx:end_idx]
            
          
            
            summary_response = openai.Completion.create(
                engine="davinci",
                prompt=f"Summarize the following text: {part_text}",
                max_tokens=(3500// (num_parts+2))
            )
            summary = summary_response.choices[0].text.strip()
            summaries.append(summary)
        
        summarized_text = " ".join(summaries)
    else:
        summarized_text = text
    
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=f"Analyze sentiment of following text by giving overall polarity and subjectivity ratings on the strict range (very negative, moderately negative, slightly negative, neutral, slightly positive, moderately positive, very positive) and corresponding score on the strict range (-1,1) for the text: {summarized_text}",
        max_tokens=200,
        temperature=0.0
    )
    
    sentiment = response.choices[0].text.strip()
    return sentiment

# %%
# Function to analyze sentiment for a DataFrame and add results
def analyze_sentiment(df):
    df['sentiment_response'] = df['article_text'].apply(openai_sentiment_analysis)
    
    def extract_sentiment_parts(response):
        parts = response.split('\n')
        polarity = "Neutral"
        subjectivity = "Neutral"
        score = "0.0"
        
        for part in parts:
            if "Overall Polarity:" in part:
                polarity = part.split(': ')[1]
            elif "Subjectivity:" in part:
                subjectivity = part.split(': ')[1]
            elif "Score:" in part:
                score = part.split(': ')[1]
        
        return pd.Series([polarity, subjectivity, score])
    
    df[['polarity', 'subjectivity', 'score']] = df['sentiment_response'].apply(extract_sentiment_parts)
    df.drop('sentiment_response', axis=1, inplace=True)
    return df

# %%
# Main execution
pdf_folder = "../ShareholderLetters"
pdf_df = process_pdfs(pdf_folder)

csv_path = "ft_articles_merged.csv"
df = pd.read_csv(csv_path)
# Convert the 'date' column in df to datetime type
df['date'] = pd.to_datetime(df['date'])

pdf_df['Date'] = pd.to_datetime(pdf_df['Date'])
reference_time = pd.to_datetime('16:00:00').time()
pdf_df['NextDayDate'] = pdf_df['Date'] + pd.DateOffset(days=1)
pdf_df['ReferenceDateTime'] = pdf_df['Date'] + pd.DateOffset(hours=reference_time.hour, minutes=reference_time.minute)

filtered_df = df[df['date'].isin(pdf_df['Date']) | df['date'].isin(pdf_df['NextDayDate'])]
filtered_df = filtered_df[~((filtered_df['date'].isin(pdf_df['Date'])) & (filtered_df['date'].apply(lambda x: x.time()) < reference_time))]


ndf = filtered_df[filtered_df['heading'].str.contains('Netflix', case=False)].copy()
ndf['date'] = pd.to_datetime(ndf['date'])
ndf.reset_index(drop=True, inplace=True)

ndf = ndf[:1]

ndf = analyze_sentiment(ndf)

# %%
ndf
# Out:
#                                                   url              author  \
# 0   https://www.ft.com/content/fb270603-8ca0-42da-...         Kate Duguid
# 1   https://www.ft.com/content/43af9830-de8f-4eb5-...  Christopher Grimes
# 2   https://www.ft.com/content/7f031f82-3678-4a6a-...         Alex Barker
# 3   https://www.ft.com/content/ce322805-b424-460c-...           Dan Einav
# 4   https://www.ft.com/content/367c529e-b46c-4346-...        Gordon Smith
# 5   https://www.ft.com/content/166a7cac-ca72-4a6e-...       Anna Nicolaou
# 6   https://www.ft.com/content/c31e104d-0154-4508-...  Christopher Grimes
# 7   https://www.ft.com/content/0e5038a2-dabd-49d4-...       Anna Nicolaou
# 8   https://www.ft.com/content/d2c5e4f1-ac1e-485e-...       Naomi Rovnick
# 9   https://www.ft.com/content/948563cf-04d0-4088-...       Chris Nuttall
# 10  https://www.ft.com/content/70a28358-8720-4f36-...  Christopher Grimes
# 11  https://www.ft.com/content/be925177-92a2-405f-...        Gordon Smith
# 12  https://www.ft.com/content/47694fa4-2a4d-489d-...        Nikou Asgari
# 13  https://www.ft.com/content/7fe1734f-bbd6-481d-...       Chris Nuttall
# 14  https://www.ft.com/content/cea59de9-138c-4f6b-...         Alex Barker
# 15  https://www.ft.com/content/c3b63a57-0d46-41c7-...  Christopher Grimes
# 16  https://www.ft.com/content/36c96d6d-a4df-4b89-...  Robin Wigglesworth
# 17  https://www.ft.com/content/af97a9c8-2128-49cc-...       Chris Nuttall
# 18  https://www.ft.com/content/fea461d6-e3e0-4016-...  Christopher Grimes
# 19  https://www.ft.com/content/f41bf4e4-0e87-4d28-...       Anna Nicolaou
# 20  https://www.ft.com/content/52705cd6-eb44-4845-...       Anna Nicolaou
# 21  https://www.ft.com/content/e88132b0-bc8d-4c6a-...        Jamie Powell
# 22  https://www.ft.com/content/ae6f0ad5-a685-4eab-...       Anna Nicolaou
# 23  https://www.ft.com/content/da6d7fc5-4e4f-4816-...       Chris Nuttall
# 16  Back in January, Bill Ackman’s Pershing Square...    Slightly Negative
# 17  This article is an on-site version of our #tec...    Slightly Positive
# 18  Netflix has warned that subscriber growth woul...    Slightly Negative
# 19  Netflix employees and activists staged a walko...    Slightly Negative
# 20  Netflix shares opened sharply lower on Wednesd...    Slightly Negative
# 21  “The Lord gave and the Lord hath taken away,” ...    Slightly Negative
# 22  Netflix will no longer raise debt to fund its ...  Moderately Positive
# 23  Netflix has always been a distribution company...    Slightly Positive
# 24  FT subscribers can click here to receive tech ...    Slightly Positive
# 25  Netflix borrowed billions of dollars to rise f...    Slightly Negative
# 26  Netflix has fallen far short of its own foreca...    Slightly Negative
# 27  Racking up double-digit share price gains in J...  Moderately Positive
# 28  Tech companies including Netflix, YouTube, Ama...    Slightly Negative
# 29  It has been full stream ahead for Netflix’s st...  Moderately Positive
# 30  Netflix shot past estimates for subscriber gro...  Moderately Positive
# 31  ● Crest Nicholson led housebuilders lower afte...              Neutral
# 32  Netflix has set a bullish tone for the Faang s...              Neutral
# 33  Netflix tussled with Walt Disney for the crown...    Slightly Negative
# 34  In the US, Netflix dropped after its quarterly...              Neutral
# 35  Netflix, the ever-churning content flywheel, r...    Slightly Negative
# 36  Welcome to Authers’ Note, in which I will atte...    Slightly Positive
# 37  Investors may have lost their appetite for Net...    Slightly Positive
# 38  Technology stocks put in a strong showing on T...  Moderately Positive
# 39  Stranger Things have happened than a solid day...  Moderately Positive
# 40  Netflix expects international revenues to exce...  Moderately Positive
# 41  Netflix, the company behind hit original shows...  Moderately Positive
# 42  When the first season of House of Cards made i...    Slightly Positive
# 43  Netflix attracted more new subscribers than ex...  Moderately Positive
#
#          subjectivity score
# 0             Neutral  -0.3
# 1             Neutral   0.5
# 2             Neutral   0.5
# 3   Slightly Positive   0.7
# 4             Neutral   0.5
# 5             Neutral   0.5
# 6             Neutral   0.5
# 7             Neutral   0.5
# 8             Neutral   0.5
# 9             Neutral   0.5
# 10            Neutral  -0.5
# 11            Neutral     0
# 12            Neutral  -0.5
# 13            Neutral   0.5
# 14            Neutral  -0.5
# 15            Neutral  -0.5
# 16            Neutral  -0.5
# 17            Neutral   0.5
# 18            Neutral  -0.5
# 19            Neutral  -0.5
# 20            Neutral  -0.5
# 21            Neutral  -0.5
# 22            Neutral   0.5
# 23            Neutral   0.5
# 24            Neutral   0.5
# 25            Neutral  -0.5
# 26            Neutral  -0.5
# 27            Neutral   0.5
# 28            Neutral  -0.5
# 29            Neutral   0.5
# 30            Neutral   0.7
# 31            Neutral     0
# 32            Neutral     0
# 33            Neutral  -0.5
# 34            Neutral     0
# 35            Neutral  -0.5
# 36            Neutral   0.5
# 37            Neutral   0.5
# 38            Neutral   0.5
# 39            Neutral   0.5
# 40            Neutral   0.5
# 41            Neutral   0.7
# 42            Neutral   0.5
# 43            Neutral   0.5

# %%
# Save the DataFrame to a CSV file
ndf.to_csv('postmarket_openai.csv', index=False)
