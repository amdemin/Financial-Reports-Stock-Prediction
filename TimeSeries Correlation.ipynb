# %%
# Import libraries
from PyPDF2 import PdfReader
from tqdm.notebook import tqdm
from textblob import TextBlob
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import pdfplumber
import re
import os

# %%
# load data
netflix_df = pd.read_csv('Src/NFLX.csv')
# find the daily return
netflix_df["Daily Return"] = netflix_df["Close"].pct_change()
# drop columns
netflix_df.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'], inplace=True)

# %%
netflix_df.head()
# Out:
#          Date      Close  Daily Return
# 0  2013-06-17  32.747143           NaN
# 1  2013-06-18  32.689999     -0.001745
# 2  2013-06-19  33.187141      0.015208
# 3  2013-06-20  31.931429     -0.037837
# 4  2013-06-21  30.985714     -0.029617

# %%
folder = 'ShareholderLetters'

report_dates = {}
main_pattern = r"([a-zA-Z]+) ([0-9]+), ([0-9]+)"
recovery_pattern = r"([a-zA-Z]+)([0-9]+),([0-9]+)"

# iterate through all files in the folder and extract report dates
for file in tqdm(os.listdir(folder)):
    pdf = pdfplumber.open(folder + "/" + file)
    report_date = pdf.pages[0].extract_text().split('\n')[0]
    if re.search(main_pattern, report_date):
        report_dates[file] = report_date
    else:
        report_date = re.sub(recovery_pattern, r"\1 \2, \3", report_date)
        report_dates[file] = report_date

# %%
# create a dataframe from the dictionary
report_dates_df = pd.DataFrame.from_dict(report_dates, orient='index', columns=['Report_Date'])
# format the date columns in dataframes
report_dates_df['Report_Date'] = pd.to_datetime(report_dates_df['Report_Date'], format='%B %d, %Y')
netflix_df['Date'] = pd.to_datetime(netflix_df['Date'])
# merge the two dataframes
total_df = pd.merge(netflix_df, report_dates_df, left_on='Date', right_on='Report_Date', how='left')

total_df["Day 1"] = total_df["Report_Date"] + timedelta(days=1)
total_df["Day 1 return"] = total_df["Daily Return"].shift(-1)
total_df["Day 2"] = total_df["Report_Date"] + timedelta(days=2)
total_df["Day 2 return"] = total_df["Daily Return"].shift(-2)
total_df["Day 3"] = total_df["Report_Date"] + timedelta(days=3)
total_df["Day 3 return"] = total_df["Daily Return"].shift(-3)
total_df["Average 3-Day return"] = (total_df["Day 1 return"] + total_df["Day 2 return"] + total_df["Day 3 return"]) / 3

# %%
sentiment_scores_df = pd.read_excel('Sentiment Scores.xlsx')
sentiment_scores_df['Report_Date'] = pd.to_datetime(sentiment_scores_df['Report_Date'])
# merge the two dataframes
total_df = pd.merge(total_df, sentiment_scores_df, left_on='Report_Date', right_on='Report_Date', how='left')

# %%
anr_df = pd.read_excel('ANR.xlsx', sheet_name='Sheet2')

# %%
anr_df.head()
# Out:
#     ANR_Date Date in 1 year  Target price estimate in 1 year Closest date  \
# 0 2023-04-01     2024-03-31                           366.69   2023-04-01
# 1 2023-03-25     2024-03-24                           366.69   2023-04-01
# 2 2023-03-18     2024-03-17                           365.15   2023-04-01
# 3 2023-03-11     2024-03-10                           363.36   2023-04-01
# 4 2023-03-04     2024-03-03                           364.64   2023-04-01
#
#    Actual price in 1 year
# 0                  345.48
# 1                  345.48
# 2                  345.48
# 3                  345.48
# 4                  345.48

# %%
anr_df['ANR_Date'] = pd.to_datetime(anr_df['ANR_Date'])
# shift the ANR date by 1 day before
anr_df['ANR_Date'] = anr_df['ANR_Date'] - timedelta(days=1)
# merge the two dataframes
total_df = pd.merge(total_df, anr_df, left_on='Date', right_on='ANR_Date', how='left')

# %%
def nearest(items, pivot):
    return min(items, key=lambda x: abs((x - pivot)))

# %%
total_df["Report_Date"].fillna(0, inplace=True)
total_df["Closest date"].fillna(0, inplace=True)

# %%
total_df["Report_Date"] = pd.to_datetime(total_df["Report_Date"])
total_df["Closest date"] = pd.to_datetime(total_df["Closest date"])

# %%
total_df['Closest_Report_Date'] = total_df.apply(lambda x: nearest(total_df['Closest date'], x['Report_Date']), axis=1)

# %%
total_df[~ total_df["Report"].isnull()].T
# Out:
#                                                                                 2226  \
# Date                                                             2022-04-19 00:00:00
# Close                                                                     348.609985
# Daily Return                                                                0.031818
# Report_Date                                                      2022-04-19 00:00:00
# Day 1                                                            2022-04-20 00:00:00
# Day 1 return                                                               -0.351166
# Day 2                                                            2022-04-21 00:00:00
# Day 2 return                                                               -0.035236
# Day 3                                                            2022-04-22 00:00:00
# Day 3 return                                                               -0.012373
# Average 3-Day return                                                       -0.132925
# Report                                                                       Q1 2022
# Polarity Score                                                                -0.179
# Subjectivity Score                                                             0.737
# Answer Score                       The sentiment of the information for Netflix i...
# ANR_Date                                                                         NaT
# Date in 1 year                                                                   NaT
# Target price estimate in 1 year_x                                                NaN
# Actual price in 1 year_x                                                         NaN
# Closest_Report_Date                                              2022-04-16 00:00:00
# Closest date                                                     2022-04-16 00:00:00
# Actual price in 1 year                                                        341.13
# Target price estimate in 1 year_y                                              613.0
#
#                                                                                 2288  \
# Date                                                             2022-07-19 00:00:00
# Close                                                                     201.630005
# Daily Return                                                                0.056097
# Report_Date                                                      2022-07-19 00:00:00
# Day 1                                                            2022-07-20 00:00:00
# Day 1 return                                                                0.073451
# Day 2                                                            2022-07-21 00:00:00
# Day 2 return                                                                0.034374
# Day 3                                                            2022-07-22 00:00:00
# Day 3 return                                                               -0.015365
# Average 3-Day return                                                         0.03082
# Report                                                                       Q2 2022
# Polarity Score                                                                  0.03
# Subjectivity Score                                                              0.35
# Answer Score                       Sentiment: Neutral. Polarity score: 0.03 Subje...
# ANR_Date                                                                         NaT
# Date in 1 year                                                                   NaT
# Target price estimate in 1 year_x                                                NaN
# Actual price in 1 year_x                                                         NaN
# Closest_Report_Date                                              2022-07-16 00:00:00
# Closest date                                                     2022-07-16 00:00:00
# Actual price in 1 year                                                        189.11
# Target price estimate in 1 year_y                                              601.5
#
#                                                                                 2352  \
# Date                                                             2022-10-18 00:00:00
# Close                                                                     240.860001
# Daily Return                                                               -0.017299
# Report_Date                                                      2022-10-18 00:00:00
# Day 1                                                            2022-10-19 00:00:00
# Day 1 return                                                                0.130864
# Day 2                                                            2022-10-20 00:00:00
# Day 2 return                                                               -0.015493
# Day 3                                                            2022-10-21 00:00:00
# Day 3 return                                                                 0.07984
# Average 3-Day return                                                        0.065071
# Report                                                                       Q3 2022
# Polarity Score                                                                0.3125
# Subjectivity Score                                                            0.4583
# Answer Score                       Sentiment: Positive Polarity Score: 0.3125 Sub...
# ANR_Date                                                                         NaT
# Date in 1 year                                                                   NaT
# Target price estimate in 1 year_x                                                NaN
# Actual price in 1 year_x                                                         NaN
# Closest_Report_Date                                              2022-10-15 00:00:00
# Closest date                                                     2022-10-15 00:00:00
# Actual price in 1 year                                                         230.0
# Target price estimate in 1 year_y                                             639.54
#
#                                                                                 2415
# Date                                                             2023-01-19 00:00:00
# Close                                                                     315.779999
# Daily Return                                                               -0.032329
# Report_Date                                                      2023-01-19 00:00:00
# Day 1                                                            2023-01-20 00:00:00
# Day 1 return                                                                0.084616
# Day 2                                                            2023-01-21 00:00:00
# Day 2 return                                                                0.043562
# Day 3                                                            2023-01-22 00:00:00
# Day 3 return                                                                0.017934
# Average 3-Day return                                                        0.048704
# Report                                                                       Q4 2022
# Polarity Score                                                                 0.501
# Subjectivity Score                                                             0.438
# Answer Score                       Sentiment: Positive Polarity score: 0.501 Subj...
# ANR_Date                                                                         NaT
# Date in 1 year                                                                   NaT
# Target price estimate in 1 year_x                                                NaN
# Actual price in 1 year_x                                                         NaN
# Closest_Report_Date                                              2023-01-21 00:00:00
# Closest date                                                     2023-01-21 00:00:00
# Actual price in 1 year                                                         342.5
# Target price estimate in 1 year_y                                             545.26

# %%
total_df.drop(columns=["Closest date_y", "Actual price in 1 year_y", "Closest date_x"], inplace=True)

# %%
last_df = anr_df[["Closest date", "Actual price in 1 year", "Target price estimate in 1 year"]]

# %%
anr_df
# Out:
#       ANR_Date Date in 1 year  Target price estimate in 1 year Closest date  \
# 0   2023-03-31     2024-03-31                           366.69   2023-04-01
# 1   2023-03-24     2024-03-24                           366.69   2023-04-01
# 2   2023-03-17     2024-03-17                           365.15   2023-04-01
# 3   2023-03-10     2024-03-10                           363.36   2023-04-01
# 4   2023-03-03     2024-03-03                           364.64   2023-04-01
# ..         ...            ...                              ...          ...
# 767 2008-07-18     2009-07-19                             4.77   2009-07-18
# 768 2008-07-11     2009-07-12                             4.77   2009-07-11
# 769 2008-07-04     2009-07-05                             4.77   2009-07-04
# 770 2008-06-27     2009-06-28                             4.82   2009-06-27
# 771 2008-06-20     2009-06-21                             4.82   2009-06-20
#
#      Actual price in 1 year
# 0                    345.48
# 1                    345.48
# 2                    345.48
# 3                    345.48
# 4                    345.48
# ..                      ...
# 767                    6.31
# 768                    5.72
# 769                    5.70
# 770                    5.77
# 771                    5.94
#
# [772 rows x 5 columns]

# %%
last_df["Closest date"] = pd.to_datetime(last_df["Closest date"])
total_df["Closest_Report_Date"] = pd.to_datetime(total_df["Closest_Report_Date"])
# Out:
# C:\Users\Я\AppData\Local\Temp\ipykernel_17484\2991060944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_df["Closest date"] = pd.to_datetime(last_df["Closest date"])

# %%
total_df = pd.merge(total_df, last_df, left_on='Closest_Report_Date', right_on='Closest date', how='left')

# %%
total_df["Actual price in 1 year"] = anr_df[anr_df["Closest date"] == total_df["Closest_Report_Date"]]["Actual price in 1 year"].values

# %%
total
# Out:
#       ANR_Date Date in 1 year  Target price estimate in 1 year Closest date  \
# 0   2023-03-31     2024-03-31                           366.69   2023-04-01
# 1   2023-03-24     2024-03-24                           366.69   2023-04-01
# 2   2023-03-17     2024-03-17                           365.15   2023-04-01
# 3   2023-03-10     2024-03-10                           363.36   2023-04-01
# 4   2023-03-03     2024-03-03                           364.64   2023-04-01
# ..         ...            ...                              ...          ...
# 767 2008-07-18     2009-07-19                             4.77   2009-07-18
# 768 2008-07-11     2009-07-12                             4.77   2009-07-11
# 769 2008-07-04     2009-07-05                             4.77   2009-07-04
# 770 2008-06-27     2009-06-28                             4.82   2009-06-27
# 771 2008-06-20     2009-06-21                             4.82   2009-06-20
#
#      Actual price in 1 year
# 0                    345.48
# 1                    345.48
# 2                    345.48
# 3                    345.48
# 4                    345.48
# ..                      ...
# 767                    6.31
# 768                    5.72
# 769                    5.70
# 770                    5.77
# 771                    5.94
#
# [772 rows x 5 columns]

# %%
check_df = total_df[['Report_Date', 'Closest date']]

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Report_Date   20 non-null     datetime64[ns]
#  1   Closest date  494 non-null    datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 39.5 KB

# %%
check_df.fillna(0, inplace=True)
# Out:
# C:\Users\Я\AppData\Local\Temp\ipykernel_17484\3598655241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_df.fillna(0, inplace=True)

# %%
check_df['Report_Date'] = pd.to_datetime(check_df['Report_Date'])
check_df['Closest date'] = pd.to_datetime(check_df['Closest date'])
# Out:
# C:\Users\Я\AppData\Local\Temp\ipykernel_17484\1532036003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_df['Report_Date'] = pd.to_datetime(check_df['Report_Date'])
# C:\Users\Я\AppData\Local\Temp\ipykernel_17484\1532036003.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_df['Closest date'] = pd.to_datetime(check_df['Closest date'])

# %%
check_df['Closest'] = check_df.apply(lambda x: nearest(check_df['Closest date'], x['Report_Date']), axis=1)
# Out:
# C:\Users\Я\AppData\Local\Temp\ipykernel_17484\3384942226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_df['Closest'] = check_df.apply(lambda x: nearest(check_df['Closest date'], x['Report_Date']), axis=1)

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Report_Date   2517 non-null   datetime64[ns]
#  1   Closest date  2517 non-null   datetime64[ns]
#  2   Closest       2517 non-null   datetime64[ns]
# dtypes: datetime64[ns](3)
# memory usage: 59.1 KB

# %%
check_df[check_df['Report_Date'] != "1970-01-01"]
# Out:
#      Report_Date Closest date    Closest
# 965   2017-04-17   1970-01-01 2017-04-15
# 1028  2017-07-17   1970-01-01 2017-07-15
# 1092  2017-10-16   1970-01-01 2017-10-14
# 1158  2018-01-22   1970-01-01 2018-01-20
# 1531  2019-07-17   1970-01-01 2019-07-20
# 1595  2019-10-16   1970-01-01 2019-10-19
# 1660  2020-01-21   1970-01-01 2020-01-18
# 1723  2020-04-21   1970-01-01 2020-04-25
# 1783  2020-07-16   1970-01-01 2020-07-18
# 1850  2020-10-20   1970-01-01 2020-10-17
# 1911  2021-01-19   1970-01-01 2021-01-16
# 1974  2021-04-20   1970-01-01 2021-04-17
# 2037  2021-07-20   1970-01-01 2021-07-17
# 2101  2021-10-19   1970-01-01 2021-10-16
# 2165  2022-01-20   1970-01-01 2022-01-22
# 2226  2022-04-19   1970-01-01 2022-04-16
# 2288  2022-07-19   1970-01-01 2022-07-16
# 2352  2022-10-18   1970-01-01 2022-10-15
# 2415  2023-01-19   1970-01-01 2023-01-21
# 2476  2023-04-18   1970-01-01 2023-04-01

# %%
anr_df.head()
# Out:
#     ANR_Date Date in 1 year  Target price estimate in 1 year Closest date  \
# 0 2023-03-31     2024-03-31                           366.69   2023-04-01
# 1 2023-03-24     2024-03-24                           366.69   2023-04-01
# 2 2023-03-17     2024-03-17                           365.15   2023-04-01
# 3 2023-03-10     2024-03-10                           363.36   2023-04-01
# 4 2023-03-03     2024-03-03                           364.64   2023-04-01
#
#    Actual price in 1 year
# 0                  345.48
# 1                  345.48
# 2                  345.48
# 3                  345.48
# 4                  345.48

# %%
total_df[~ total_df["Report"].isnull()].T
# Out:
#                                                                               2226  \
# Date                                                           2022-04-19 00:00:00
# Close                                                                   348.609985
# Daily Return                                                              0.031818
# Report_Date                                                    2022-04-19 00:00:00
# Day 1                                                          2022-04-20 00:00:00
# Day 1 return                                                             -0.351166
# Day 2                                                          2022-04-21 00:00:00
# Day 2 return                                                             -0.035236
# Day 3                                                          2022-04-22 00:00:00
# Day 3 return                                                             -0.012373
# Average 3-Day return                                                     -0.132925
# Report                                                                     Q1 2022
# Polarity Score                                                              -0.179
# Subjectivity Score                                                           0.737
# Answer Score                     The sentiment of the information for Netflix i...
# ANR_Date                                                                       NaT
# Date in 1 year                                                                 NaT
# Target price estimate in 1 year                                                NaN
# Closest date                                                                   NaT
# Actual price in 1 year                                                         NaN
#
#                                                                               2288  \
# Date                                                           2022-07-19 00:00:00
# Close                                                                   201.630005
# Daily Return                                                              0.056097
# Report_Date                                                    2022-07-19 00:00:00
# Day 1                                                          2022-07-20 00:00:00
# Day 1 return                                                              0.073451
# Day 2                                                          2022-07-21 00:00:00
# Day 2 return                                                              0.034374
# Day 3                                                          2022-07-22 00:00:00
# Day 3 return                                                             -0.015365
# Average 3-Day return                                                       0.03082
# Report                                                                     Q2 2022
# Polarity Score                                                                0.03
# Subjectivity Score                                                            0.35
# Answer Score                     Sentiment: Neutral. Polarity score: 0.03 Subje...
# ANR_Date                                                                       NaT
# Date in 1 year                                                                 NaT
# Target price estimate in 1 year                                                NaN
# Closest date                                                                   NaT
# Actual price in 1 year                                                         NaN
#
#                                                                               2352  \
# Date                                                           2022-10-18 00:00:00
# Close                                                                   240.860001
# Daily Return                                                             -0.017299
# Report_Date                                                    2022-10-18 00:00:00
# Day 1                                                          2022-10-19 00:00:00
# Day 1 return                                                              0.130864
# Day 2                                                          2022-10-20 00:00:00
# Day 2 return                                                             -0.015493
# Day 3                                                          2022-10-21 00:00:00
# Day 3 return                                                               0.07984
# Average 3-Day return                                                      0.065071
# Report                                                                     Q3 2022
# Polarity Score                                                              0.3125
# Subjectivity Score                                                          0.4583
# Answer Score                     Sentiment: Positive Polarity Score: 0.3125 Sub...
# ANR_Date                                                                       NaT
# Date in 1 year                                                                 NaT
# Target price estimate in 1 year                                                NaN
# Closest date                                                                   NaT
# Actual price in 1 year                                                         NaN
#
#                                                                               2415
# Date                                                           2023-01-19 00:00:00
# Close                                                                   315.779999
# Daily Return                                                             -0.032329
# Report_Date                                                    2023-01-19 00:00:00
# Day 1                                                          2023-01-20 00:00:00
# Day 1 return                                                              0.084616
# Day 2                                                          2023-01-21 00:00:00
# Day 2 return                                                              0.043562
# Day 3                                                          2023-01-22 00:00:00
# Day 3 return                                                              0.017934
# Average 3-Day return                                                      0.048704
# Report                                                                     Q4 2022
# Polarity Score                                                               0.501
# Subjectivity Score                                                           0.438
# Answer Score                     Sentiment: Positive Polarity score: 0.501 Subj...
# ANR_Date                                                                       NaT
# Date in 1 year                                                                 NaT
# Target price estimate in 1 year                                                NaN
# Closest date                                                                   NaT
# Actual price in 1 year                                                         NaN

# %%
total_df[total_df["Date"] > "2022-04-15"]
# Out:
# Empty DataFrame
# Columns: [Date, Close, Daily Return, Report_Date, Day 1, Day 1 return, Day 2, Day 2 return, Day 3, Day 3 return, Average 3-Day return, Report, Polarity Score, Subjectivity Score, Answer Score, ANR_Date, Date in 1 year, Target price estimate in 1 year, Closest date, Actual price in 1 year, Report_Date_ordinal, Closest date_ordinal, closest_date_new]
# Index: []
#
# [0 rows x 23 columns]

# %%
total_df['Report_Date'] = pd.to_datetime(total_df['Report_Date'])
total_df['Closest date'] = pd.to_datetime(total_df['Closest date'])

# %%
total_df
# Out:
# Empty DataFrame
# Columns: [Date, Close, Daily Return, Report_Date, Day 1, Day 1 return, Day 2, Day 2 return, Day 3, Day 3 return, Average 3-Day return, Report, Polarity Score, Subjectivity Score, Answer Score, ANR_Date, Date in 1 year, Target price estimate in 1 year, Closest date, Actual price in 1 year, Report_Date_ordinal, Closest date_ordinal, closest_date_new]
# Index: []
#
# [0 rows x 23 columns]

# %%
total_df[~ total_df["Date in 1 year"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Close, Daily Return, Report_Date, Day 1, Day 1 return, Day 2, Day 2 return, Day 3, Day 3 return, Average 3-Day return, Report, Polarity Score, Subjectivity Score, Answer Score, Date in 1 year, Target price estimate in 1 year, Closest date, Actual price in 1 year]
# Index: []
