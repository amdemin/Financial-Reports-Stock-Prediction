# %%
# retrieve text from PDF
from tqdm.notebook import tqdm
from PyPDF2 import PdfReader
from tqdm.notebook import tqdm
from textblob import TextBlob
import numpy as np
import credentials
import spacy  
import re
from collections import Counter
from nltk.corpus import wordnet
import nltk
nltk.download('omw-1.4')
import pandas as pd
import numpy as np
from transformers import pipeline
import pdfplumber
import os
from difflib import SequenceMatcher
# Out:
# /Users/yingyingren/opt/anaconda3/envs/numpy_environment/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-08-02 15:33:29.280460: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/yingyingren/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# #### Scrapping last 10 quarterly reports

# %%
# Define similarity function
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
# Define headings in the document using word size function
def word_ratio_func(word):
    try:
        word_length = len(word["text"])
        word_bottom = float(word['bottom'])
        word_top = float(word['top'])
        return (word_bottom - word_top), word_length, word["text"]
        
    except:
        return 0, 0, 0

def preprocess_text(texts):

    # preprocess the text
    text = "".join(texts.values()).strip("●").strip("*")
    text = text.split("\n")
    text = [x for x in text if x != '' and x.startswith("Source") == False]
    text = [x[0].replace("●", "") + x[1:] if x[0] == "●" else x for x in text]
    text = [x[0].replace("*", "") + x[1:] if x[0] == "*" else x for x in text]
    text = [x[0].replace("○", "") + x[1:] if x[0] == "○" else x for x in text]
    text = [x[0].replace("1", "") + x[1:] if x[1:3] in ["Q1", "Q2", "Q3", "Q4"] else x for x in text]
    text = text[2:]

    return text

# %%
# get file paths for all pdfs
pdf_paths = []
for root, dirs, files in os.walk("ShareholderLetters/"):
    for file in files:
        if file.endswith(".pdf"):
             pdf_paths.append(os.path.join(root, file))

# %%
# creating a pdf reader object
pdf_paths = ["ShareholderLetters/FINAL-Q1-21-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q2-21-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q3-21-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q4-21-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q1-22-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q2-22-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q3-22-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q4-22-Shareholder-Letter.pdf",
             "ShareholderLetters/FINAL-Q1-23-Shareholder-Letter.pdf",
            "ShareholderLetters/FINAL-Q2-23-Shareholder-Letter.pdf"]

pdf_texts = {}
pdf_headings = {}

if not os.path.exists('Txt'):
    os.makedirs('Txt')

for file_path in tqdm(pdf_paths):

    try:
        
        reader = pdfplumber.open(file_path)

        texts = {}
        texts_v2 = {}
        headings = []
        headings_count = 0

        for page_number in range(0, len(reader.pages)):

            # get the specific page from the pdf file
            page = reader.pages[page_number]
            # extract text from page
            text = page.extract_text()
            # add text to dictionary
            texts[page_number] = text

            # extract headings from page
            words = page.extract_words()
            word_count = 0
            while word_count < len(words):
                # find if the words are large enough to be headings
                word_size, word_length, word_text = word_ratio_func(words[word_count])
                heading = []

                if word_size > 15 and word_length > 1:
                    while True:
                        heading.append(word_text)
                        word_count += 1
                        if word_count >= len(words):
                            break
                        word_size, word_length, word_text = word_ratio_func(words[word_count])
                        if not word_size > 15 and word_length > 1:
                            headings.append(" ".join(heading))
                            word_count += 10
                            break
                headings_count += 1
                word_count += 1
            
            # break if the page covers the reference section
            if re.search("\nReference\n", text):
                break
        
        # preprocess the text
        text = preprocess_text(texts)
        final_text = " ".join(text)

        # export the text to a txt file
        with open("Txt/" + file_path.split("/")[-1].split(".")[0] + ".txt", "w", encoding='utf-8') as f:
            f.write(final_text)

        # add the text to the dictionary
        pdf_texts[file_path.split("/")[-1].split(".")[0]] = final_text
        # add the headings to the dictionary
        pdf_headings[file_path.split("/")[-1].split(".")[0]] = headings

    except Exception as e:
        print(e)
        continue
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
# view your pdf texts with pdf names as keys
list(pdf_texts.items())
# Out:
# [('FINAL-Q1-21-Shareholder-Letter',
#   "Revenue grew 24% year over year and was in line withour beginning of quarter forecast, while operating profit and margin reached all-time highs. We finishedQ1’21 with 208m paid memberships, up 14% year over year, but below our guidance forecast of 210mpaid memberships. We believe paid membership growth slowed due to the big Covid-19 pull forwardin 2020 and a lighter content slate in the firsthalf of this year, due to Covid-19 production delays. We continueto anticipate a strong second half with the return of new seasons of some of our biggest hitsand an exciting film lineup. In the short-term, thereis some uncertainty from Covid-19; in the long-term,the rise of streaming to replace linear TV aroundthe world is the clear trend in entertainment. Q1 Results and Q2 Forecast Average revenue per membership1rose 6% year overyear, or 5%, excluding a foreign exchange impact of +$80m. Operating income of $2 billion vs. $958 millionmore than doubled vs. Q1’20. This exceeded our guidance forecast primarily due to the timing of contentspend. EPS of $3.75 vs. $1.57 a year ago included a $253m non-cash unrealized gain from F/Xremeasurement on our Euro denominated debt. The extraordinary events of Covid-19 led to unprecedentedmembership growth in 2020, as it pulled forward growth from 2021, and delayed production acrossevery region. In turn, we ended 2020 with a bigger membership and revenue base than we would otherwisehave had, contributing to record Q1’21 revenues. And since we were still ramping productionlevels late last year, we had lower content spendin 1Average revenue per membership (ARM) is defined asstreaming revenue divided by the average number of streaming paid memberships divided by the number ofmonths in the period. These figures do not includesales taxes or VAT. Q1’21 - content amortization only grew 9.5% year over year in Q1’21 vs. 17% in FY20. The result was a 10 percentage point year over year jump in our operatingmargin to 27% in Q1, which is an all-time high. As we discussed in past letters, these dynamics arealso contributing to a lighter content slate in thefirst half of 2021, and hence, we believe slower membership growth. In Q1, paid net additions of 4m were below our 6m guidance (and the 16m net additions inthe year ago quarter) primarily due to acquisition, as retention in Q1 was in line with our expectations.We don’t believe competitive intensity materially changed in the quarter or was a material factor inthe variance as the over-forecast was across allof our regions. We also saw similar percentage year-over-yeardeclines in paid net adds in all regions (see our Regional Breakdown table below), whereas the levelof competitive intensity varies by country. As a reminder, the quarterly guidance we provide isour actual internal forecast at the time we report. That means in some quarters our results will be highrelative to our guidance forecast and, in others,it will be low, as can be seen in the chart below. Asour membership base continues to grow, there will naturally be more volatility in our absolute paidnet additions performance vs. forecast. With similar pull forward and delayed slate dynamicsplus our typical seasonality expected to impact Q2’21, we project paid net additions of 1m (vs. 10min the prior year quarter) with our UCAN and LATAM regions expected to be roughly flattish in memberships(+/- a couple hundred thousand paid net adds). We anticipate paid membership growth will re-acceleratein the second half of 2021 as we ramp into a very strong back half slate with the return of bighits likeSex Education,The Witcher,La Casa dePapel (akaMoney Heist), andYou, as well as an excitingarray of original films including the finale toTheKissing Boothtrilogy and large scale, star-driven featureslikeRed Notice(starring Gal Gadot, Dwayne Johnson and Ryan Reynolds) andDon’t Look Up(with an all-starcast including Leonardo DiCaprio, Jennifer Lawrence, Cate Blanchett, Timothée Chalamet, and MerylStreep). We’ll also have ou ...
#  ('FINAL-Q2-21-Shareholder-Letter',
#   'In Q2, revenue increased 19% year over year to $7.3billion, while operating income rose 36% year over year to $1.8 billion. We finished the quarter withover 209m paid memberships, slightly ahead of our forecast. COVID has created some lumpiness in ourmembership growth (higher growth in 2020, slower growth this year), which is working its way through.We continue to focus on improving our service for our members and bringing them the best stories fromaround the world. Our summary results and forecast for Q3 are below. Q2 Results and Q3 Forecast Revenue growth was driven by an 11% increase in averagepaid streaming memberships and 8% growth in average revenue per membership (ARM)1. ARM rose4%, excluding a foreign exchange (FX) impact of +$277m. Operating margin of 25.2% expanded 3 percentagepoints compared with the year ago quarter. EPS of $2.97 vs. $1.59 a year ago included a $63mnon-cash unrealized loss from FX remeasurement on our Euro denominated debt. The pandemic has created unusual choppiness in ourgrowth and distorts year-over-year comparisons as acquisition and engagement per member household spikedin the early months of COVID. In Q2’21, our engagement per member household was, as expected,down vs. those unprecedented levels but was still up 17% compared with a more comparable Q2’19. Similarly,retention continues to be strong and better than pre-COVID Q2’19 levels, even as average revenueper membership has grown 8% over this two-year 1Average revenue per membership (ARM) is defined asstreaming revenue divided by the average number of streaming paid memberships divided by the number ofmonths in the period. These figures do not includesales taxes or VAT. 1period, demonstrating how much our members value Netflix and that as we improve our service we can charge a bit more. We added 1.5m paid memberships in Q2, slightly aheadof our 1.0m guidance forecast. The APAC region represented about two-thirds of our global paid net adds in the quarter. As expected, Q2 paid memberships in the UCAN region were slightly downsequentially (-0.4m paid net adds). We believe our large membership base in UCAN coupled with a seasonallysmaller quarter for acquisition is the main reason for this dynamic. This is similar to what weexperienced in Q2’19 when our UCAN paid net adds were -0.1m; since then we’ve added nearly 7.5m paidnet adds in UCAN. As a reminder, the quarterly guidance we provide isour actual internal forecast at the time we report. For Q3’21, we forecast paid net additions of 3.5mvs. 2.2m in the prior year period. If we achieve our forecast, we will have added more than 54m paid netadds over the past 24 months or 27m on an annualized basis over that time period, which is consistentwith our pre-COVID annual rate of net additions. We forecast that ARM will grow roughly5% year over year on a FX neutral basis in Q3’21. We continue to target a 20% operating margin for thefull year 2021 vs. 18% in 2020. After our big global launch in January 2016, we committed to steadily growingour operating margin thereafter at an average rate of three percentage points per year over anyfew-year period. Some years we’ll be a little over(like in 2020), some years a little under (like in 2021).Assuming we achieve our margin target this year,we will have quintupled our operating margin in the lastfive years and are tracking ahead of this average annual three percentage point pace. 2With revenue and margin both increasing, our operatingprofit dollars have risen dramatically as well (even as we have been investing heavily), from about$100 million per quarter in 2016 to nearly $2 billion per quarter so far in 2021. Our belief isthat as we steadily improve our service to betterplease our members, this will lead to continued growth inour membership base, ARM, revenue, operating margin and profit dollars. Content We launched our first original scripted TV seriesin 2012 and we’ve since expanded our original programming effort to many additional categories,from  ...
#  ('FINAL-Q3-21-Shareholder-Letter',
#   'After a lighter-than-normal content slate in Q1 and Q2 due to COVID-related production delays in 2020, we are seeing the positive effects of a stronger slate in the second half of the year. In Q3, we grew revenue 16% year over year to $7.5 billion, while operating income rose 33% vs. the prior year quarter to $1.8 billion. We added 4.4m paid net adds (vs. 2.2m in Q3’20) to end the quarter with 214m paid memberships. We’re very excited to finish the year with what we expect to be our strongest Q4 content offering yet, which shows up as bigger content expense and lower operating margins sequentially. Q3 Results and Q4 Forecast Revenue growth in Q3 was driven by a 9% and 7% increase in average paid streaming memberships and ARM1, respectively. Excluding a foreign exchange (FX)impact of +$128m, ARM rose 5% year over year. Operating margin for Q3 amounted to 23.5%, a three percentage point increase vs. the year ago period. This was above our beginning of quarter forecast due to the timing of content spend, as well as lower than forecasted marketing spend. EPS of $3.19 vs. $1.74 a year ago included a $136m non-cash unrealized gain from FX remeasurement on our Euro denominated debt. We under-forecasted paid net adds for the quarter (4.4m actual vs. our 3.5m projection), while ending paid memberships of 214m was within 0.4% of our forecast. For the second consecutive quarter, the APAC region was our largest contributor to membership growth with 2.2m paid net adds (half of total paid net adds) as we are continuing to improve our service in this region. In EMEA, paid net adds of 1.8m improved sequentially vs. the 188k in Q2 as several titles had a particularly strong impact. The UCAN and 1ARM (Average Revenue per Membership) is defined asstreaming revenue divided by the average number of streaming paid memberships divided by the number of months in the period. These figures do not include sales taxes or VAT. 1LATAM regions grew paid memberships more slowly. These regions have higher penetration of broadband homes although we believe we still have ample runway for growth as we continue to improve our service. As a reminder, the quarterly guidance we provide is our actual internal forecast at the time we report and we strive for accuracy. For Q4’21, we forecast paid net adds of 8.5m, consistent with Q4’20 paid net additions. For the full year 2021, we forecast an operating margin of 20% or slightly better. This means that Q4’21 operating margin will be approximately 6.5% compared with 14% in Q4’20. The year over year decline in operating margin is due mostly to our backloaded big content release schedule in this Q4, which will result in a roughly 19% year over year increase in content amortization for Q4’21 (compared with ~8% growth year to date). Content Our programming strategy is to provide members with a wide variety of high quality content that’s loved and watched in large numbers. Season five ofLa Casade Papel(akaMoney Heist) and season three of Sex Educationwere two of our biggest returning showsin the quarter with 69m and 55m member households, respectively, choosing to watch these fan favorites in the first four weeks. On the heels of The Queen’s Gambit, we’ve had another limited serieshit withMaidwhich launched just after quarter-end on October 1. We expect this story about living on the poverty line by award-winning playwright and screenwriter Molly Smith Metzler to reach 67m households during its first four weeks. La Casa de Papelwas our first non-English languagetitle to show that - with subtitling and dubbing - great stories truly can come from anywhere and be loved everywhere. We are now producing local TV and film in approximately 45 countries and have built deep relationships with creative communities around the world. While the goal of our local content executives is always to create locally authentic stories that will resonate in their country (likeThe Chestnut Manwhich we expect to be watched by 2approximately two t ...
#  ('FINAL-Q4-21-Shareholder-Letter',
#   "We achieved several milestones in 2021: we had the biggest TV show of the year (Squid Game), our two biggest film releases of all time (Red NoticeandDon’t Look Up) and Netflix was the most Emmy-winning and most nominated TV network and the most Oscar-winning and nominated movie studio of 2021. Full year revenue of $30 billion grew 19% year over year while operating income of $6.2 billion rose 35% year over year. We finished Q4 with 222m paid memberships (with 8.3m paid net adds in Q4). Even in a world of uncertainty and increasing competition, we’re optimistic about our long-term growth prospects as streaming supplants linear entertainment around the world. We're continually improving Netflix so that we can please our members, grow our share of leisure time and lead in this transition. Our summary results and forecast are below. Q4 Results and Q1 Forecast Revenue in Q4’21 grew 16% year over year with a 9% increase in average paid memberships. ARM1rose 7% year over year on both a reported and foreign exchange (F/X) neutral basis, two percentage points faster than Q3’21 (ex-F/X). Operating margin for Q4 amounted to 8%, a six percentage point decrease vs. the year ago period. The decline in operating margin was expected given our large content slate in Q4 this year. Operating margin was above our beginning of quarter forecast of 6.5% due to slightly lower than forecasted content spend. As a result, our full year operating margin was 21% vs. 18% in 2020, 1ARM(Average Revenue per Membership) is defined asstreaming revenue divided by the average number of streaming paid memberships divided by the number of months in the period. These figures do not include sales taxes or VAT. 1above our 20% guidance forecast. EPS in Q4 of $1.33 vs. $1.19 a year ago included a $104m non-cash unrealized gain from FX remeasurement on our Euro denominated debt. We slightly over-forecasted paid net adds in Q4 (8.3m actual compared to the 8.5m paid net adds in both the year ago quarter and our beginning of quarter projection). For the full year 2021, paid net adds totaled 18m vs 37m in 2020. Our service continues to grow globally, with more than 90% of our paid net adds in 2021 coming from outside the UCAN region. Nonetheless, our UCAN region added 1.2m paid memberships in Q4’21 (vs. 0.9m last year), marking our strongest quarter of member growth in this region since the early days of COVID-19 in 2020. In APAC, we increased paid memberships by 2.6m (vs. 2.0m in the year ago quarter) with strong growth in both Japan and India. EMEA was our largest contributor to paid net adds in Q4 (3.5m vs. 4.5m in the prior year period) and the region delivered record quarterly revenue, exceeding $2.5 billion for the first time. LATAM paid net adds totaled 1.0m vs. 1.2m last year. As a reminder, the quarterly guidance we provide is our actual internal forecast at the time we report. That means in some quarters our results will be high relative to our guidance forecast and in others it will be low, as can be seen in the chart below. As our membership base continues to grow, there will naturally be more volatility in our absolute paid net adds performance vs. forecast. For Q1’22, we forecast paid net adds of 2.5m vs. 4.0m in the year ago quarter. Our guidance reflects a more back-end weighted content slate in Q1’22 (for example,BridgertonS2 and our new original film The Adam Projectwill both be launching in March).In addition, while retention and engagement remain healthy, acquisition growth has not yet re-accelerated to pre-Covid levels. We think this may be due to several factors including the ongoing Covid overhang and macro-economic hardship in several parts of the world like LATAM. 2For 2022, we are currently targeting an operating margin of 19%-20% (assuming no material swings in foreign currency from current levels). Our operating margin outlook is driven by two main factors. First, as seen in the chart below, we delivered above the three percentage point annual  ...
#  ('FINAL-Q1-22-Shareholder-Letter',
#   "Our revenue growth has slowed considerably as our results and forecast below show. Streaming is winning over linear, as we predicted, and Netflix titles are very popular globally. However, our relatively high household penetration - when including the large number of households sharing accounts - combined with competition, is creating revenue growth headwinds. The big COVID boost to streaming obscured the picture until recently. While we work to reaccelerate our revenue growth - through improvements to our service and more effective monetization of multi-household sharing - we’ll be holding our operating margin at around 20%. Key to our success has been our ability to create amazing entertainment from all around the world, present it in highly personalized ways, and win more viewing than our competitors. These are Netflix's core strengths and competitive advantages. Together with our strong profitability, we believe we have the foundation from which we can both significantly improve, and better monetize, our service longer term. Growth Outlook Since launching streaming in 2007, we’ve operated under the firm belief that internet-delivered, on demand entertainment will supplant linear TV, and that this transition represents a once-in-a-generation opportunity to build a highly popular and profitable entertainment company. People love movies, TV shows and games; broadband and smart TV penetration continue to grow globally with more and more connected devices; and while hundreds of millions of homes pay for Netflix, well over half of the world’s broadband homes don’t yet, representing huge future growth potential. 1In the near term though, we’re not growing revenue as fast as we’d like. COVID clouded the picture by significantly increasing our growth in 2020, leading us to believe that most of our slowing growth in 2021 was due to the COVID pull forward. Now, we believe there are four main inter-related factors at work. First, it’s increasingly clear that the pace of growthinto our underlying addressable market (broadband homes) is partly dependent on factors we don’t directly control, like the uptake of connected TVs (since the majority of our viewing is on TVs), the adoption of on-demand entertainment, and data costs. We believe these factors will keep improving over time, so that all broadband households will be potential Netflix customers. Second, in addition to our 222m paying households,we estimate that Netflix is being shared with over 100m additional households, including over 30m in the UCAN region. Account sharing as a percentage of our paying membership hasn’t changed much over the years, but, coupled with the first factor, means it’s harder to grow membership in many markets - an issue that was obscured by our COVID growth. Third, competition for viewing with linear TV as wellas YouTube, Amazon, and Hulu has been robust for the last 15 years. However, over the last three years, as traditional entertainment companies realized streaming is the future, many new streaming services have also launched. While our US television viewing share, for example, has been steady to up according to Nielsen, we want to grow that share faster. Higher view share is an indicator of higher satisfaction, which supports higher retention and revenue. Fourth, macro factors, including sluggish economicgrowth, increasing inflation, geopolitical events such as Russia’s invasion of Ukraine, and some continued disruption from COVID are likely having an impact as well. 2Our plan is to reaccelerate our viewing and revenue growth by continuing to improve all aspects of Netflix - in particular the quality of our programming and recommendations, which is what our members value most. On the content side, we’re doubling down on story development and creative excellence, which we see reflected in big Q1’22 TV hits likeBridgerton(627 million hours viewed for season 21*, our biggest English language series in our history) andInventing Anna(512m hours viewed ...
#  ('FINAL-Q2-22-Shareholder-Letter',
#   'Q2 was better-than-expected on membership growth, and foreign exchange was worse-than-expected (stronger US dollar), resulting in 9% revenue growth (13% constant currency). Our challenge and opportunity is to accelerate our revenue and membership growth by continuing to improve our product, content, and marketing as we’ve done for the last 25 years, and to better monetize our big audience. We’re in a position of strength given our $30 billion-plus in revenue, $6 billion in operating profit last year, growing free cash flow and a strong balance sheet. Our summary results and forecast are below. Q2 Results Revenue in Q2 grew 9% year over year (or 13% excluding a -$339 million foreign currency impact), driven by a 6% and 2% increase in average paid memberships and ARM1, respectively. Excluding the impact of foreign exchange (F/X), ARM rose 7% year over year. The appreciation of the US dollar (USD) vs. most other currencies since our April earnings report was the primary reason for the variance to our revenue guidance forecast. We slightly under-forecasted global paid net adds in Q2 (-1.0m vs. -2.0m forecast and compared to +1.5m in the year ago quarter).  In APAC, revenue grew 23% year over year, excluding F/X. At over $900 million of revenue, APAC is approaching the size of our LATAM business. We added 1.1m paid memberships in the region (vs. 1.0m last Q2). ARM in APAC was -2% year over year on a F/X neutral basis, due to the impact from our price decrease in India last December as well as plan mix, which was partially offset by 1ARM(Average Revenue per Membership) is defined asstreaming revenue divided by the average number of streaming paid memberships divided by the number of months in the period. These figures do not include sales taxes or VAT. 1higher ARM in Korea and Australia. Excluding India, APAC ARM grew 4% year over year on a constant currency basis.  Excluding F/X, EMEA revenue and ARM increased 13% and 6% year over year, respectively, while paid net additions totaled -0.8m vs. 0.2m in the year ago quarter.  Revenue in LATAM grew 19% year over year excluding F/X and surpassed the $1 billion quarterly mark for the first time, helped by constant currency ARM growth of 15%. Paid memberships were flat sequentially (compared to 0.8m paid net adds in Q2’21).  In UCAN, ARM and revenue each increased 10% year over year, excluding the impact of F/X. Paid net adds were -1.3m vs. -0.4m in the year ago period. Retention improved over the course of the quarter and, while churn remains slightly elevated, it is now back near pre-price change levels. We’ve adjusted our cost structure for our current rate of revenue growth. This resulted in approximately $70 million of severance costs and an $80m non-cash impairment of certain real estate leases primarily related to rightsizing our office footprint. Excluding these items totaling $150 million, and the F/X impact of the stronger US dollar since our April report, operating profit and operating margin were slightly ahead of our guidance forecast. EPS of $3.20 vs. $2.97 a year ago exceeded our guidance forecast of $3.00 due to a $305 million non-cash unrealized gain from F/X remeasurement on our Euro denominated debt, which is recognized below operating income in “interest and other income.” Our approximately $5 billion of Euro bonds provides us with some natural hedge against the Euro for net income, but doesn’t affect operating income. Year to date, our gain from F/X remeasurement on our Euro debt is $467 million. Q3 Forecast As a reminder, the quarterly guidance we provide is our actual internal forecast at the time we report. As always, we strive for accuracy although the current uncertain macro-economic environment leads to less-than-normal visibility. The US dollar continues to strengthen meaningfully against most currencies at ahistoric pace, withthe Euro recently falling below the US dollarfor thefirst time in two decades, a significant headwind for all multinational US compan ...
#  ('FINAL-Q3-22-Shareholder-Letter',
#   "Summary:  Revenue, operating income and membership slightly exceeded our forecast in Q3’22.  We had big hits across TV and film in Q3 – launching some of our most watched series and films of all time, including:  Monster: The Jeffrey Dahmer Story,Stranger ThingsS4,Extraordinary Attorney Woo, The Gray Man, andPurple Hearts  Our lower priced ad-supported plan launches in 12 countries in November – just six months after our initial announcement. Our existing plans remain ad free.  Netflix has higher engagement than any other streamer – with room for growth:  In the UK, Netflix accounts for 8.2% of video viewing, 2.3x Amazon and 2.7x Disney+1;  In the US, Netflix accounts for 7.6% of TV time, 2.6x Amazon and 1.4x Disney + Hulu + Hulu Live2.  Our competitors are investing heavily to drive subscribers and engagement, but building a large, successful streaming business is hard - we estimate they are all losing money, with combined 2022 operating losses well over $10 billion, vs. Netflix's $5 to $6 billion annual operating profit. After a challenging first half, we believe we’re on a path to reaccelerate growth. The key is pleasing members. It’s why we’ve always focused on winning the competition for viewing every day. When our series and movies excite our members, they tell their friends, and then more people watch, join and stay with us. 1Based on reporting fromBARB, as of September 2022 2Based onNielsen’s Gauge, as of August 2022 Q3 Results Our 6% year-over-year revenue growth in Q3 was driven by a 5% increase in average paid memberships and a 1% rise in ARM3. Excluding the impact of foreign exchange (F/X), revenue and ARM grew 13% and 8% year-over-year, respectively. The sequential decline in revenue was entirely due to F/X. We under-forecasted paid net additions, which totaled 2.4 million vs. our 1.0m forecast and compared to 4.4m in the year ago quarter.  In APAC, revenue grew 19% excluding F/X as average paid memberships rose 23% year-over-year. ARM was -3% year-over-year, excluding F/X, partially driven by lower ARM in India, somewhat offset by higher ARM in Australia and Korea. We added 1.4m paid memberships in the region (vs. 2.2m last Q3).  Excluding F/X, EMEA revenue and ARM grew 13% and 7%, respectively. Paid net adds totaled 0.6m vs. 1.8m in the year ago quarter.  In LATAM, revenue increased 19% year-over-year, supported by ARM growth of 16% vs. the year ago quarter excluding F/X. We added 0.3m paid memberships, in-line with membership growth in Q3’21.  In UCAN, our most penetrated market, ARM and revenue grew by 12% and 11%, respectively, excluding F/X. Paid net adds totaled 0.1m (similar to the 0.1m in Q3’21). For Q3, operating income totaled $1.5 billion vs. $1.8 billion in Q3’21. Operating income was above our beginning-of-quarter forecast, partially due to higher revenue, as well as a shift in timing of some spend from Q3 to Q4. As a result, operating margin of 19% was above our 16% forecast. The four percentage point year-over-year decline in operating margin is almost entirely due to the appreciation in the US dollar vs. most other currencies during this period. EPS of $3.10 vs. $3.19 a year ago included a $348 million non-cash unrealized gain from F/X remeasurement on our Euro denominated debt. Q4 Forecast As a reminder, the quarterly guidance we provide is our actual internal forecast at the time we report. The appreciation of the US dollar remains a significant headwind for us (and US-based multinationals in general). For Q4’22, we’re expecting revenue of $7.8 billion with the sequential decline entirely due to the continued strengthening of the US dollar vs. other currencies. On a constant currency basis, this equates to 9% year-over-year revenue growth. Our revenue growth forecast is driven by our expectation for 4.5m paid net adds (vs. 8.3m in Q4’21) and ARM growth of 6% year-over-year, excluding F/X. Our paid net adds forecast assumes that we experience our usual seasonality as well as the impact of a st ...
#  ('FINAL-Q4-22-Shareholder-Letter',
#   'Summary:  Q4’22 revenue, operating profit and membership growth exceeded our forecast - we continue to lead the industry in streaming engagement, revenue and profit.  Our Q4 content slate outperformed even our high expectations:  Wednesdaywas our third most popular series ever,Harry & Meghanour second most popular documentary series,Trollour most popularnon-English film, andGlass Onion: A Knives Out Mysteryour fourth most popular film1.  We successfully launched our new, lower priced ad-supported plan in November and are pleased with the early results, with much more still to do.  We delivered on the high end of our operating profit margin target for full year 2022, and we expect to increase our operating margin in 2023 vs. 2022.  For 2022, we finished with 231M paid memberships and generated $32B of revenue, $5.6B in operating income, $2.0B of net cash from operating activities and $1.6B of free cash flow (FCF). In 2023, we expect at least $3B of FCF, assuming no material swings in F/X.  Ted Sarandos and Greg Peters are now co-CEOs of Netflix, with Reed Hastings as Executive Chairman – completing our succession process. 2022 was a tough year, with a bumpy start but a brighter finish. We believe we have a clear path to reaccelerate our revenue growth: continuing to improve all aspects of Netflix, launching paid sharing and building our ads offering. As always, our north stars remain pleasing our members and building even greater profitability over time. 1As defined by cumulative view hours in the first 28 days 1Ted Sarandos and Greg Peters as our co-CEOs To complete our succession process, Reed Hastings has become Executive Chairman, and Greg Peters has stepped up from COO to become Ted Sarandos’ co-CEO, and a member of the Netflix board. Reed, Greg, and Ted have been working closely together for 15 years, and this makes formal externally how we have been operating internally. More details are here on ourblog. Ted said: “I want to thank Reed for his visionary leadership, mentorship and friendship over the last 20 years. We’ve all learned so much from his intellectual rigor, honesty and willingness to take big bets – and we look forward to working with him for many more years to come. Since Reed started to delegate management to us, Greg and I have built a strong operating model based on our shared values and like-minded approach to growth. I am so excited to start this new chapter with Greg as co-CEO.” Greg said: "I feel humbled and privileged to become co-CEO of Netflix. Ted and I have worked together for many years – building tremendous trust and respect for each other. We\'re also motivated by the same goal: a desire to better serve our members so that we can continue to grow our business.” In addition to these changes, Bela Bajaria, formerly Head of Global TV, has become Chief Content Officer and Scott Stuber has become Chairman of Netflix Film. Ted said: “Bela and Scott are outstanding creative executives with proven track records at Netflix. In 2022 we premiered many of our most popular series and films in Netflix history, including Wednesday, Glass Onion: A Knives Out Mystery, Purple Hearts, Monster: The Jeffrey Dahmer Story, The Adam Project and Harry & Meghan – a testament to their leadership and creativity. I couldn’t be more excited to work alongside them as we seek to delight audiences for years to come.” For full details of Netflix leadership seehere. Q4 Results Year over year revenue growth of 2% in Q4 (10% on a foreign exchange (F/X) neutral basis2) was driven by a 4% increase in average paid memberships. ARM3declined 2% year over year, but grew 5% on a F/X neutral basis2. Revenue was slightly above our beginning-of-quarterprojection, as paid net adds of 7.7M (vs. 8.3M in Q4’21) came in higher than our 4.5M forecast, due to both strong acquisition and retention, driven primarily by the success of our Q4 content slate. In addition, the US dollar depreciated vs. most other currencies during the quarter, which r ...
#  ('FINAL-Q1-23-Shareholder-Letter',
#   "Summary:  Q1‘23revenueandoperatingprofitwerein-linewithourforecast.  WedeliveredastrongcontentslateinQ1with:  SuccessfulreturningseasonslikeOuterBanks,You,Ginny&Georgiaandabigsequel filmMurderMystery2.  NewhitsacrossnearlyeverygenreofTVlikeTheNightAgent(nowour6thmostpopular EnglishlanguageTVshowever),TheGlory(our5thmostpopularnon-EnglishTVshow ever),FullSwing,That90sShowandfilmsYouPeopleandLuther:TheFallenSun.  WithMoody’srecentupgrade,weachievedinvestmentgradestatus.Netflixistheleading streamingservicebasedonengagement,revenueandprofitandweareworkingtobuildonthat in‘23,byseekingtoexpandoperatingmarginto18%-20%andtogenerateatleast+$3.5Bof freecashflow(upfromourpriorexpectationofatleast$3.0BofFCF).  InQ1,welaunchedpaidsharinginfourcountriesandarepleasedwiththeresults.Weare planningonabroadrollout,includingintheUS,inQ2.  Givencurrenthealthyperformanceandtrajectoryofourper-memberadvertisingeconomics, particularlyintheUS,we’reupgradingouradsexperiencewithmorestreamsandimproved videoqualitytoattractabroaderrangeofconsumers. Inshort,we’reofftoagoodstartin2023.Asalways,ourfocusremainspleasingourmembersand attractinggreatcreatorssothatwecancontinuetobuildawildlysuccessfulbusiness. Q2'23 (inmillionsexceptpersharedata) Q1'22 Q2'22 Q3'22 Q4'22 Q1'23 Forecast Revenue $7,868 $7,970 $7,926 $7,852 $8,162 $8,242 Y/Y%Growth 9.8% 8.6% 5.9% 1.9% 3.7% 3.4% OperatingIncome $1,972 $1,578 $1,533 $550 $1,714 $1,565 OperatingMargin 25.1% 19.8% 19.3% 7.0% 21.0% 19.0% NetIncome $1,597 $1,441 $1,398 $55 $1,305 $1,283 DilutedEPS $3.53 $3.20 $3.10 $0.12 $2.88 $2.84 GlobalStreamingPaidMemberships 221.64 220.67 223.09 230.75 232.50 Y/Y%Growth 6.7% 5.5% 4.5% 4.0% 4.9% GlobalStreamingPaidNetAdditions -0.20 -0.97 2.41 7.66 1.75 Netcashprovidedbyoperatingactivities $923 $103 $557 $444 $2,179 FreeCashFlow* $802 $13 $472 $332 $2,117 Shares(FD) 453.0 450.2 450.3 451.6 452.4 Q1 Results Revenuegrew4%yearoveryearinQ1(+8%onaforeignexchange(F/X)neutralbasis1),consistentwith ourbeginning-of-quarterforecast.Averagepaidmembershipsincreased4%yearoveryear,whileARM2 was-1%vs.Q1’22(+4%onanF/Xneutralbasis).Paidnetaddsamountedto1.8MforQ1vs.-0.2Minthe yearagoquarter.Regionalhighlightsinclude:  UCANrevenuegrew8%yearoveryear(bothreportedandF/Xneutral)drivenbya9%increase inARM(bothreportedandF/Xneutral).  EMEArevenuewasdown2%yearoveryear(+6%onanF/Xneutralbasis),dueprimarilytoa declineof6%inARM(+1%onanF/Xneutralbasis),offsetpartiallybya4%increaseinaverage paidmemberships.  LATAMrevenueincreased7%yearoveryear(+13%F/Xneutral),witha3%riseinARM(+8%F/X neutral).Paidmembershipdippedby0.4M,whichwebelieveisduetopullforwardfromQ4 (whenwehadabigquarterwith1.8Mpaidnetadds)andongoingmacroeconomicsoftness.  APACrevenuegrew2%yearoveryear(+10%F/Xneutral).Averagepaidmembershipsincreased 17%yearoveryear.Thisoffseta13%decreaseinARM(-6%F/Xneutral),whichwasduetoplan mixandahighermixofmembergrowthincountrieswithlowerpricing. Operatingincometotaled$1.7Bvs.$2.0BinQ1‘22-aboveourguidanceforecastof$1.6Bdueto ongoingexpensemanagementandtimingofhiringandcontentspend.Operatingmarginwas21% comparedto25%intheyearagoperiod.Theyearoveryeardeclineinoperatingmarginwasprimarily duetoF/X-theappreciationoftheUSdollaraccountedforroughlythreepercentagepointsoftheyear overyearchangeinoperatingmargin.Q1’23EPSof$2.88(vs.$3.53inQ1‘22)wasin-linewithour guidanceof$2.82andincludedan$81millionnon-cashunrealizedlossfromF/Xremeasurementonour Eurodenominateddebt. Forecast Ourprimaryfinancialmetricsarerevenueforgrowthandoperatingmarginforprofitability.Ourlong termfinancialobjectivesareunchanged-sustaindoubledigitrevenuegrowth,expandoperatingmargin anddelivergrowingpositivefreecashflow.Thequarterlyguidanceweprovideisouractualinternal forecastatthetimewereport.Westriveforaccuracyalthoughtherolloutofmajornewinitiatives(paid sharingandads)leadstoless-than-normalvisibility. We’reontracktomeetourfullyear2023financialobjectives.ForQ2’23,weforecastrevenueof$8.2B, up3%yearoveryear,or6%growthonanF/Xneutralbasis.We’repleasedwiththemostrecent  ...
#  ('FINAL-Q2-23-Shareholder-Letter',
#   " InMay,wesuccessfullylaunchedpaidsharingin100+countries,representingmorethan80%of ourrevenuebase.  Revenueineachregionisnowhigherthanpre-launch,withsign-upsalreadyexceeding cancellations.  Paidnetadditionswere5.9MinQ2,andtodaywe’rerollingoutpaidsharingtoalmost alloftheremainingcountries.  Q2‘23revenueof$8.2Bandoperatingprofitof$1.8Bweregenerallyin-linewithour forecast—andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad-supportedplan. We’restilltargetingafullyear2023operatingmarginof18%to20%.  We’realeaderintermsofstreamingengagementand,perNielsen,wehadthetoporiginal streamingseriesintheUSfor24ofthefirst25weeksof2023,andthetopmoviefor21weeks. Whilewe’vemadesteadyprogressthisyear,wehavemoreworktodotoreaccelerateourgrowth.We remainfocusedon:creatingasteadydrumbeatofmustwatchshowsandmovies;improving monetization;growingtheenjoymentofourgames;andinvestingtoimproveourserviceformembers. Q3'23 (inmillionsexceptpersharedata) Q2'22 Q3'22 Q4'22 Q1'23 Q2'23 Forecast Revenue $7,970 $7,926 $7,852 $8,162 $8,187 $8,520 Y/Y%Growth 8.6% 5.9% 1.9% 3.7% 2.7% 7.5% OperatingIncome $1,578 $1,533 $550 $1,714 $1,827 $1,890 OperatingMargin 19.8% 19.3% 7.0% 21.0% 22.3% 22.2% NetIncome $1,441 $1,398 $55 $1,305 $1,488 $1,580 DilutedEPS $3.20 $3.10 $0.12 $2.88 $3.29 $3.52 GlobalStreamingPaidMemberships 220.67 223.09 230.75 232.50 238.39 Y/Y%Growth 5.5% 4.5% 4.0% 4.9% 8.0% GlobalStreamingPaidNetAdditions -0.97 2.41 7.66 1.75 5.89 Netcashprovidedbyoperatingactivities $103 $557 $444 $2,179 $1,440 FreeCashFlow $13 $472 $332 $2,117 $1,339 Shares(FD) 450.2 450.3 451.6 452.4 451.6 Q2 Results RevenueinQ2grew3%yearoveryear(+6%onaforeignexchange(F/X)neutralbasis1).Revenuegrowth wasdrivenbya6%increaseinaveragepaidmembership,whileARM2declined3%yearoveryear(-1% F/Xneutral).Theyear-over-yearARMdeclinewasdrivenbyacombinationoflimitedpriceincreasesover thepast12months(leadinguptothelaunchofpaidsharing),timingofpaidnetadditions(primarilylate inthequarterduetotheMay23rolloutofpaidsharinginQ2),andahighermixofmembershipgrowth fromlowerARMcountries. Wehadpaidnetadditionsof5.9MforQ2’23(withover1Mpaidnetaddsineachregion)vs.-1.0Min Q2’22aswesuccessfullyrolledoutpaidsharingtomorethan100countries(representingover80%of ourrevenue).Q2operatingincometotaled$1.8B,up16%vs.$1.6Bintheyearagoquarter.Operating marginwas22%,comparedwith20%inQ2’22.Bothwereslightlyaheadofourbeginning-of-quarter forecastduetoongoingexpensemanagement,slower-than-projectedheadcountgrowthandtimingof contentspend.EPSinQ2amountedto$3.29vs.$3.20inQ2’22andincludeda$29millionnon-cash unrealizedlossfromF/XremeasurementonourEurodenominateddebt,whichisrecognizedbelow operatingincomein“interestandotherincome/expense.” Forecast Ourprimaryfinancialmetricsarerevenueforgrowth,andoperatingmarginforprofitability.Ourgoalis toacceleraterevenuegrowth,expandouroperatingmarginanddelivergrowingpositivefreecashflow. Asareminder,thequarterlyguidanceweprovideisouractualinternalforecastatthetimewereport. Nowthatwe’velaunchedpaidsharingbroadly,wehaveincreasedconfidenceinourfinancialoutlook. Weexpectrevenuegrowthwillaccelerateinthesecondhalfof2023asmonetizationgrowsfromour mostrecentpaidsharinglaunchandweexpandourinitiativeacrossnearlyallremainingcountriesplus thecontinuedsteadygrowthinourad-supportedplan(moredetailsintheMonetizationandRevenue section). ForQ3,weforecastrevenueof$8.5B,up7%yearoveryearonbothareportedandF/Xneutralbasis,a slightaccelerationfromourQ2’23F/Xneutralrevenuegrowthrateof6%.OurrevenuegrowthinQ3will comefromgrowthinaveragepaidmemberships.WeexpectF/XneutralARMtobeflattoslightlydown yearoveryear,aswearelappingpriceincreasesin2022andwegenerallyhaven’thadpriceincreasesin ourlargestrevenuemarketssincethefirsthalfoflastyear(limitedduringpaidsharingrollout).Revenue fromadvertisingandourextramemberfeature3arenotyetmaterialenoughtooffsetthesefactors.We anticipateQ3’23paidnetaddswillbesimilartoQ2’23paidnetadditions.Weexpectthatourrevenue 1Excluding ...

# %% [markdown]
# ### Tokenized the earning reports

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Tokenize all the reports
tokenized_reports = {}

# Loop through each report in pdf_texts
for report_name, report_text in pdf_texts.items():
    # Use the nlp.pipe method to tokenize the report_text
    tokenized_report = [doc for doc in nlp.pipe([report_text])]
    
    # Add tokenized_report to tokenized_reports
    tokenized_reports[report_name] = tokenized_report

# Print the tokenized reports
for report_name, tokenized_report in tokenized_reports.items():
    print(f"Report name: {report_name}")
    for doc in tokenized_report:
        print([token.lemma_ for token in doc if not token.is_stop and not token.is_punct])  
    print("\n")
# Out:
# /Users/yingyingren/opt/anaconda3/envs/numpy_environment/lib/python3.9/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# Report name: FINAL-Q1-21-Shareholder-Letter
# ['revenue', 'grew', '24', 'year', 'year', 'line', 'withour', 'beginning', 'quarter', 'forecast', 'operating', 'profit', 'margin', 'reached', 'time', 'highs', 'finishedq1’21', '208', 'm', 'paid', 'memberships', '14', 'year', 'year', 'guidance', 'forecast', '210mpaid', 'memberships', 'believe', 'paid', 'membership', 'growth', 'slowed', 'big', 'covid-19', 'pull', 'forwardin', '2020', 'lighter', 'content', 'slate', 'firsthalf', 'year', 'covid-19', 'production', 'delays', 'continueto', 'anticipate', 'strong', 'second', 'half', 'return', 'new', 'seasons', 'biggest', 'hitsand', 'exciting', 'film', 'lineup', 'short', 'term', 'thereis', 'uncertainty', 'covid-19', 'long', 'term', 'rise', 'streaming', 'replace', 'linear', 'tv', 'aroundthe', 'world', 'clear', 'trend', 'entertainment', 'q1', 'results', 'q2', 'forecast', 'average', 'revenue', 'membership1rose', '6', 'year', 'overyear', '5', 'excluding', 'foreign', 'exchange', 'impact', '+', '$', '80', 'm.', 'operating', 'income', '$', '2', 'billion', 'vs.', '$', '958', 'millionmore', 'doubled', 'vs.', 'q1’20', 'exceeded', 'guidance', 'forecast', 'primarily', 'timing', 'contentspend', 'eps', '$', '3.75', 'vs.', '$', '1.57', 'year', 'ago', 'included', '$', '253', 'm', 'non', 'cash', 'unrealized', 'gain', 'f', 'xremeasurement', 'euro', 'denominated', 'debt', 'extraordinary', 'events', 'covid-19', 'led', 'unprecedentedmembership', 'growth', '2020', 'pulled', 'forward', 'growth', '2021', 'delayed', 'production', 'acrossevery', 'region', 'turn', 'ended', '2020', 'bigger', 'membership', 'revenue', 'base', 'otherwisehave', 'contributing', 'record', 'q1’21', 'revenues', 'ramping', 'productionlevels', 'late', 'year', 'lower', 'content', 'spendin', '1average', 'revenue', 'membership', 'arm', 'defined', 'asstreaming', 'revenue', 'divided', 'average', 'number', 'streaming', 'paid', 'memberships', 'divided', 'number', 'ofmonths', 'period', 'figures', 'includesales', 'taxes', 'vat', 'q1’21', 'content', 'amortization', 'grew', '9.5', 'year', 'year', 'q1’21', 'vs.', '17', 'fy20', 'result', '10', 'percentage', 'point', 'year', 'year', 'jump', 'operatingmargin', '27', 'q1', 'time', 'high', 'discussed', 'past', 'letters', 'dynamics', 'arealso', 'contributing', 'lighter', 'content', 'slate', 'thefirst', 'half', '2021', 'believe', 'slower', 'membership', 'growth', 'q1', 'paid', 'net', 'additions', '4', 'm', '6', 'm', 'guidance', '16', 'm', 'net', 'additions', 'inthe', 'year', 'ago', 'quarter', 'primarily', 'acquisition', 'retention', 'q1', 'line', 'expectations', 'believe', 'competitive', 'intensity', 'materially', 'changed', 'quarter', 'material', 'factor', 'inthe', 'variance', 'forecast', 'allof', 'regions', 'saw', 'similar', 'percentage', 'year', 'yeardeclines', 'paid', 'net', 'adds', 'regions', 'regional', 'breakdown', 'table', 'levelof', 'competitive', 'intensity', 'varies', 'country', 'reminder', 'quarterly', 'guidance', 'provide', 'isour', 'actual', 'internal', 'forecast', 'time', 'report', 'means', 'quarters', 'results', 'highrelative', 'guidance', 'forecast', 'low', 'seen', 'chart', 'asour', 'membership', 'base', 'continues', 'grow', 'naturally', 'volatility', 'absolute', 'paidnet', 'additions', 'performance', 'vs.', 'forecast', 'similar', 'pull', 'forward', 'delayed', 'slate', 'dynamicsplus', 'typical', 'seasonality', 'expected', 'impact', 'q2’21', 'project', 'paid', 'net', 'additions', '1', 'm', 'vs.', '10min', 'prior', 'year', 'quarter', 'ucan', 'latam', 'regions', 'expected', 'roughly', 'flattish', 'memberships(+/-', 'couple', 'thousand', 'paid', 'net', 'adds', 'anticipate', 'paid', 'membership', 'growth', 'acceleratein', 'second', 'half', '2021', 'ramp', 'strong', 'half', 'slate', 'return', 'bighits', 'likesex', 'education', 'witcher', 'la', 'casa', 'depapel', 'akamoney', 'heist', 'andyou', 'excitingarray', 'original', 'films', 'including', 'finale', 'tothekissing', 'boothtrilogy', 'large', 'scale', 'star', 'driven', 'featureslikered', 'notice(starring', 'gal', 'gadot', 'dwayne', 'johnson', 'ryan', ...
#
#
# Report name: FINAL-Q2-21-Shareholder-Letter
# ['q2', 'revenue', 'increased', '19', 'year', 'year', '$', '7.3billion', 'operating', 'income', 'rose', '36', 'year', 'year', '$', '1.8', 'billion', 'finished', 'quarter', 'withover', '209', 'm', 'paid', 'memberships', 'slightly', 'ahead', 'forecast', 'covid', 'created', 'lumpiness', 'ourmembership', 'growth', 'higher', 'growth', '2020', 'slower', 'growth', 'year', 'working', 'way', 'continue', 'focus', 'improving', 'service', 'members', 'bringing', 'best', 'stories', 'fromaround', 'world', 'summary', 'results', 'forecast', 'q3', 'q2', 'results', 'q3', 'forecast', 'revenue', 'growth', 'driven', '11', 'increase', 'averagepaid', 'streaming', 'memberships', '8', 'growth', 'average', 'revenue', 'membership', 'arm)1', 'arm', 'rose4', 'excluding', 'foreign', 'exchange', 'fx', 'impact', '+', '$', '277', 'm.', 'operating', 'margin', '25.2', 'expanded', '3', 'percentagepoints', 'compared', 'year', 'ago', 'quarter', 'eps', '$', '2.97', 'vs.', '$', '1.59', 'year', 'ago', 'included', '$', '63mnon', 'cash', 'unrealized', 'loss', 'fx', 'remeasurement', 'euro', 'denominated', 'debt', 'pandemic', 'created', 'unusual', 'choppiness', 'ourgrowth', 'distorts', 'year', 'year', 'comparisons', 'acquisition', 'engagement', 'member', 'household', 'spikedin', 'early', 'months', 'covid', 'q2’21', 'engagement', 'member', 'household', 'expected', 'vs.', 'unprecedented', 'levels', '17', 'compared', 'comparable', 'q2’19', 'similarly', 'retention', 'continues', 'strong', 'better', 'pre', 'covid', 'q2’19', 'levels', 'average', 'revenueper', 'membership', 'grown', '8', 'year', '1average', 'revenue', 'membership', 'arm', 'defined', 'asstreaming', 'revenue', 'divided', 'average', 'number', 'streaming', 'paid', 'memberships', 'divided', 'number', 'ofmonths', 'period', 'figures', 'includesales', 'taxes', 'vat', '1period', 'demonstrating', 'members', 'value', 'netflix', 'improve', 'service', 'charge', 'bit', 'added', '1.5', 'm', 'paid', 'memberships', 'q2', 'slightly', 'aheadof', '1.0', 'm', 'guidance', 'forecast', 'apac', 'region', 'represented', 'thirds', 'global', 'paid', 'net', 'adds', 'quarter', 'expected', 'q2', 'paid', 'memberships', 'ucan', 'region', 'slightly', 'downsequentially', '-0.4', 'm', 'paid', 'net', 'adds', 'believe', 'large', 'membership', 'base', 'ucan', 'coupled', 'seasonallysmaller', 'quarter', 'acquisition', 'main', 'reason', 'dynamic', 'similar', 'weexperienced', 'q2’19', 'ucan', 'paid', 'net', 'adds', '-0.1', 'm', 'added', 'nearly', '7.5', 'm', 'paidnet', 'adds', 'ucan', 'reminder', 'quarterly', 'guidance', 'provide', 'isour', 'actual', 'internal', 'forecast', 'time', 'report', 'q3’21', 'forecast', 'paid', 'net', 'additions', '3.5mvs', '2.2', 'm', 'prior', 'year', 'period', 'achieve', 'forecast', 'added', '54', 'm', 'paid', 'netadds', 'past', '24', 'months', '27', 'm', 'annualized', 'basis', 'time', 'period', 'consistentwith', 'pre', 'covid', 'annual', 'rate', 'net', 'additions', 'forecast', 'arm', 'grow', 'roughly5', 'year', 'year', 'fx', 'neutral', 'basis', 'q3’21', 'continue', 'target', '20', 'operating', 'margin', 'thefull', 'year', '2021', 'vs.', '18', '2020', 'big', 'global', 'launch', 'january', '2016', 'committed', 'steadily', 'growingour', 'operating', 'margin', 'average', 'rate', 'percentage', 'points', 'year', 'anyfew', 'year', 'period', 'years', 'little', 'over(like', '2020', 'years', 'little', 'like', '2021).assuming', 'achieve', 'margin', 'target', 'year', 'quintupled', 'operating', 'margin', 'lastfive', 'years', 'tracking', 'ahead', 'average', 'annual', 'percentage', 'point', 'pace', '2with', 'revenue', 'margin', 'increasing', 'operatingprofit', 'dollars', 'risen', 'dramatically', 'investing', 'heavily', 'about$100', 'million', 'quarter', '2016', 'nearly', '$', '2', 'billion', 'quarter', 'far', '2021', 'belief', 'isthat', 'steadily', 'improve', 'service', 'betterplease', 'members', 'lead', 'continued', 'growth', 'inour', 'membership', 'base', 'arm', 'revenue', 'operating', 'margin', 'profit', 'dollars', 'content', 'launched',  ...
#
#
# Report name: FINAL-Q3-21-Shareholder-Letter
# ['lighter', 'normal', 'content', 'slate', 'q1', 'q2', 'covid', 'related', 'production', 'delays', '2020', 'seeing', 'positive', 'effects', 'stronger', 'slate', 'second', 'half', 'year', 'q3', 'grew', 'revenue', '16', 'year', 'year', '$', '7.5', 'billion', 'operating', 'income', 'rose', '33', 'vs.', 'prior', 'year', 'quarter', '$', '1.8', 'billion', 'added', '4.4', 'm', 'paid', 'net', 'adds', 'vs.', '2.2', 'm', 'q3’20', 'end', 'quarter', '214', 'm', 'paid', 'memberships', 'excited', 'finish', 'year', 'expect', 'strongest', 'q4', 'content', 'offering', 'shows', 'bigger', 'content', 'expense', 'lower', 'operating', 'margins', 'sequentially', 'q3', 'results', 'q4', 'forecast', 'revenue', 'growth', 'q3', 'driven', '9', '7', 'increase', 'average', 'paid', 'streaming', 'memberships', 'arm1', 'respectively', 'excluding', 'foreign', 'exchange', 'fx)impact', '+', '$', '128', 'm', 'arm', 'rose', '5', 'year', 'year', 'operating', 'margin', 'q3', 'amounted', '23.5', 'percentage', 'point', 'increase', 'vs.', 'year', 'ago', 'period', 'beginning', 'quarter', 'forecast', 'timing', 'content', 'spend', 'lower', 'forecasted', 'marketing', 'spend', 'eps', '$', '3.19', 'vs.', '$', '1.74', 'year', 'ago', 'included', '$', '136', 'm', 'non', 'cash', 'unrealized', 'gain', 'fx', 'remeasurement', 'euro', 'denominated', 'debt', 'forecasted', 'paid', 'net', 'adds', 'quarter', '4.4', 'm', 'actual', 'vs.', '3.5', 'm', 'projection', 'ending', 'paid', 'memberships', '214', 'm', '0.4', 'forecast', 'second', 'consecutive', 'quarter', 'apac', 'region', 'largest', 'contributor', 'membership', 'growth', '2.2', 'm', 'paid', 'net', 'adds', 'half', 'total', 'paid', 'net', 'adds', 'continuing', 'improve', 'service', 'region', 'emea', 'paid', 'net', 'adds', '1.8', 'm', 'improved', 'sequentially', 'vs.', '188k', 'q2', 'titles', 'particularly', 'strong', 'impact', 'ucan', '1arm', 'average', 'revenue', 'membership', 'defined', 'asstreaming', 'revenue', 'divided', 'average', 'number', 'streaming', 'paid', 'memberships', 'divided', 'number', 'months', 'period', 'figures', 'include', 'sales', 'taxes', 'vat', '1latam', 'regions', 'grew', 'paid', 'memberships', 'slowly', 'regions', 'higher', 'penetration', 'broadband', 'homes', 'believe', 'ample', 'runway', 'growth', 'continue', 'improve', 'service', 'reminder', 'quarterly', 'guidance', 'provide', 'actual', 'internal', 'forecast', 'time', 'report', 'strive', 'accuracy', 'q4’21', 'forecast', 'paid', 'net', 'adds', '8.5', 'm', 'consistent', 'q4’20', 'paid', 'net', 'additions', 'year', '2021', 'forecast', 'operating', 'margin', '20', 'slightly', 'better', 'means', 'q4’21', 'operating', 'margin', 'approximately', '6.5', 'compared', '14', 'q4’20', 'year', 'year', 'decline', 'operating', 'margin', 'backloaded', 'big', 'content', 'release', 'schedule', 'q4', 'result', 'roughly', '19', 'year', 'year', 'increase', 'content', 'amortization', 'q4’21', 'compared', '~8', 'growth', 'year', 'date', 'content', 'programming', 'strategy', 'provide', 'members', 'wide', 'variety', 'high', 'quality', 'content', 'loved', 'watched', 'large', 'numbers', 'season', 'ofla', 'casade', 'papel(akamoney', 'heist', 'season', 'sex', 'educationwere', 'biggest', 'returning', 'showsin', 'quarter', '69', 'm', '55', 'm', 'member', 'households', 'respectively', 'choosing', 'watch', 'fan', 'favorites', 'weeks', 'heels', 'queen', 'gambit', 'limited', 'serieshit', 'withmaidwhich', 'launched', 'quarter', 'end', 'october', '1', 'expect', 'story', 'living', 'poverty', 'line', 'award', 'winning', 'playwright', 'screenwriter', 'molly', 'smith', 'metzler', 'reach', '67', 'm', 'households', 'weeks', 'la', 'casa', 'de', 'papelwas', 'non', 'english', 'languagetitle', 'subtitling', 'dubbing', 'great', 'stories', 'truly', 'come', 'loved', 'producing', 'local', 'tv', 'film', 'approximately', '45', 'countries', 'built', 'deep', 'relationships', 'creative', 'communities', 'world', 'goal', 'local', 'content', 'executives', 'create', 'locally', 'authentic', 'stories', 'resonate', 'cou ...
#
#
# Report name: FINAL-Q4-21-Shareholder-Letter
# ['achieved', 'milestones', '2021', 'biggest', 'tv', 'year', 'squid', 'game', 'biggest', 'film', 'releases', 'time', 'red', 'noticeanddon’t', 'look', 'netflix', 'emmy', 'winning', 'nominated', 'tv', 'network', 'oscar', 'winning', 'nominated', 'movie', 'studio', '2021', 'year', 'revenue', '$', '30', 'billion', 'grew', '19', 'year', 'year', 'operating', 'income', '$', '6.2', 'billion', 'rose', '35', 'year', 'year', 'finished', 'q4', '222', 'm', 'paid', 'memberships', '8.3', 'm', 'paid', 'net', 'adds', 'q4', 'world', 'uncertainty', 'increasing', 'competition', 'optimistic', 'long', 'term', 'growth', 'prospects', 'streaming', 'supplants', 'linear', 'entertainment', 'world', 'continually', 'improving', 'netflix', 'members', 'grow', 'share', 'leisure', 'time', 'lead', 'transition', 'summary', 'results', 'forecast', 'q4', 'results', 'q1', 'forecast', 'revenue', 'q4’21', 'grew', '16', 'year', 'year', '9', 'increase', 'average', 'paid', 'memberships', 'arm1rose', '7', 'year', 'year', 'reported', 'foreign', 'exchange', 'f', 'x', 'neutral', 'basis', 'percentage', 'points', 'faster', 'q3’21', 'ex', 'f', 'x', 'operating', 'margin', 'q4', 'amounted', '8', 'percentage', 'point', 'decrease', 'vs.', 'year', 'ago', 'period', 'decline', 'operating', 'margin', 'expected', 'given', 'large', 'content', 'slate', 'q4', 'year', 'operating', 'margin', 'beginning', 'quarter', 'forecast', '6.5', 'slightly', 'lower', 'forecasted', 'content', 'spend', 'result', 'year', 'operating', 'margin', '21', 'vs.', '18', '2020', '1arm(average', 'revenue', 'membership', 'defined', 'asstreaming', 'revenue', 'divided', 'average', 'number', 'streaming', 'paid', 'memberships', 'divided', 'number', 'months', 'period', 'figures', 'include', 'sales', 'taxes', 'vat', '1above', '20', 'guidance', 'forecast', 'eps', 'q4', '$', '1.33', 'vs.', '$', '1.19', 'year', 'ago', 'included', '$', '104', 'm', 'non', 'cash', 'unrealized', 'gain', 'fx', 'remeasurement', 'euro', 'denominated', 'debt', 'slightly', 'forecasted', 'paid', 'net', 'adds', 'q4', '8.3', 'm', 'actual', 'compared', '8.5', 'm', 'paid', 'net', 'adds', 'year', 'ago', 'quarter', 'beginning', 'quarter', 'projection', 'year', '2021', 'paid', 'net', 'adds', 'totaled', '18', 'm', 'vs', '37', 'm', '2020', 'service', 'continues', 'grow', 'globally', '90', 'paid', 'net', 'adds', '2021', 'coming', 'outside', 'ucan', 'region', 'nonetheless', 'ucan', 'region', 'added', '1.2', 'm', 'paid', 'memberships', 'q4’21', 'vs.', '0.9', 'm', 'year', 'marking', 'strongest', 'quarter', 'member', 'growth', 'region', 'early', 'days', 'covid-19', '2020', 'apac', 'increased', 'paid', 'memberships', '2.6', 'm', 'vs.', '2.0', 'm', 'year', 'ago', 'quarter', 'strong', 'growth', 'japan', 'india', 'emea', 'largest', 'contributor', 'paid', 'net', 'adds', 'q4', '3.5', 'm', 'vs.', '4.5', 'm', 'prior', 'year', 'period', 'region', 'delivered', 'record', 'quarterly', 'revenue', 'exceeding', '$', '2.5', 'billion', 'time', 'latam', 'paid', 'net', 'adds', 'totaled', '1.0', 'm', 'vs.', '1.2', 'm', 'year', 'reminder', 'quarterly', 'guidance', 'provide', 'actual', 'internal', 'forecast', 'time', 'report', 'means', 'quarters', 'results', 'high', 'relative', 'guidance', 'forecast', 'low', 'seen', 'chart', 'membership', 'base', 'continues', 'grow', 'naturally', 'volatility', 'absolute', 'paid', 'net', 'adds', 'performance', 'vs.', 'forecast', 'q1’22', 'forecast', 'paid', 'net', 'adds', '2.5', 'm', 'vs.', '4.0', 'm', 'year', 'ago', 'quarter', 'guidance', 'reflects', 'end', 'weighted', 'content', 'slate', 'q1’22', 'example', 'bridgertons2', 'new', 'original', 'film', 'adam', 'projectwill', 'launching', 'march).in', 'addition', 'retention', 'engagement', 'remain', 'healthy', 'acquisition', 'growth', 'accelerated', 'pre', 'covid', 'levels', 'think', 'factors', 'including', 'ongoing', 'covid', 'overhang', 'macro', 'economic', 'hardship', 'parts', 'world', 'like', 'latam', '2for', '2022', 'currently', 'targeting', 'operating', 'margin', '19%-20', 'assuming', 'material', 'swings ...
#
#
# Report name: FINAL-Q1-22-Shareholder-Letter
# ['revenue', 'growth', 'slowed', 'considerably', 'results', 'forecast', 'streaming', 'winning', 'linear', 'predicted', 'netflix', 'titles', 'popular', 'globally', 'relatively', 'high', 'household', 'penetration', 'including', 'large', 'number', 'households', 'sharing', 'accounts', 'combined', 'competition', 'creating', 'revenue', 'growth', 'headwinds', 'big', 'covid', 'boost', 'streaming', 'obscured', 'picture', 'recently', 'work', 'reaccelerate', 'revenue', 'growth', 'improvements', 'service', 'effective', 'monetization', 'multi', 'household', 'sharing', 'holding', 'operating', 'margin', '20', 'key', 'success', 'ability', 'create', 'amazing', 'entertainment', 'world', 'present', 'highly', 'personalized', 'ways', 'win', 'viewing', 'competitors', 'netflix', 'core', 'strengths', 'competitive', 'advantages', 'strong', 'profitability', 'believe', 'foundation', 'significantly', 'improve', 'better', 'monetize', 'service', 'longer', 'term', 'growth', 'outlook', 'launching', 'streaming', '2007', 'operated', 'firm', 'belief', 'internet', 'delivered', 'demand', 'entertainment', 'supplant', 'linear', 'tv', 'transition', 'represents', 'generation', 'opportunity', 'build', 'highly', 'popular', 'profitable', 'entertainment', 'company', 'people', 'love', 'movies', 'tv', 'shows', 'games', 'broadband', 'smart', 'tv', 'penetration', 'continue', 'grow', 'globally', 'connected', 'devices', 'hundreds', 'millions', 'homes', 'pay', 'netflix', 'half', 'world', 'broadband', 'homes', 'representing', 'huge', 'future', 'growth', 'potential', '1in', 'near', 'term', 'growing', 'revenue', 'fast', 'like', 'covid', 'clouded', 'picture', 'significantly', 'increasing', 'growth', '2020', 'leading', 'believe', 'slowing', 'growth', '2021', 'covid', 'pull', 'forward', 'believe', 'main', 'inter', 'related', 'factors', 'work', 'increasingly', 'clear', 'pace', 'growthinto', 'underlying', 'addressable', 'market', 'broadband', 'homes', 'partly', 'dependent', 'factors', 'directly', 'control', 'like', 'uptake', 'connected', 'tvs', 'majority', 'viewing', 'tvs', 'adoption', 'demand', 'entertainment', 'data', 'costs', 'believe', 'factors', 'improving', 'time', 'broadband', 'households', 'potential', 'netflix', 'customers', 'second', 'addition', '222', 'm', 'paying', 'households', 'estimate', 'netflix', 'shared', '100', 'm', 'additional', 'households', 'including', '30', 'm', 'ucan', 'region', 'account', 'sharing', 'percentage', 'paying', 'membership', 'changed', 'years', 'coupled', 'factor', 'means', 'harder', 'grow', 'membership', 'markets', 'issue', 'obscured', 'covid', 'growth', 'competition', 'viewing', 'linear', 'tv', 'wellas', 'youtube', 'amazon', 'hulu', 'robust', '15', 'years', 'years', 'traditional', 'entertainment', 'companies', 'realized', 'streaming', 'future', 'new', 'streaming', 'services', 'launched', 'television', 'viewing', 'share', 'example', 'steady', 'according', 'nielsen', 'want', 'grow', 'share', 'faster', 'higher', 'view', 'share', 'indicator', 'higher', 'satisfaction', 'supports', 'higher', 'retention', 'revenue', 'fourth', 'macro', 'factors', 'including', 'sluggish', 'economicgrowth', 'increasing', 'inflation', 'geopolitical', 'events', 'russia', 'invasion', 'ukraine', 'continued', 'disruption', 'covid', 'likely', 'having', 'impact', '2our', 'plan', 'reaccelerate', 'viewing', 'revenue', 'growth', 'continuing', 'improve', 'aspects', 'netflix', 'particular', 'quality', 'programming', 'recommendations', 'members', 'value', 'content', 'doubling', 'story', 'development', 'creative', 'excellence', 'reflected', 'big', 'q1’22', 'tv', 'hits', 'likebridgerton(627', 'million', 'hours', 'viewed', 'season', '21', 'biggest', 'english', 'language', 'series', 'history', 'andinventing', 'anna(512', 'm', 'hours', 'viewed', 'extremely', 'successful', 'partnership', 'shonda', 'rhimes', 'films', 'liketinder', 'swindler(166', 'm', 'hours', 'viewed', 'biggest', 'documentary', 'film', 'released', 'andthe', 'adam', 'project(233', 'm', 'hours', 'viewed', 'come', 'q4', 'hitsred ...
#
#
# Report name: FINAL-Q2-22-Shareholder-Letter
# ['q2', 'better', 'expected', 'membership', 'growth', 'foreign', 'exchange', 'worse', 'expected', 'stronger', 'dollar', 'resulting', '9', 'revenue', 'growth', '13', 'constant', 'currency', 'challenge', 'opportunity', 'accelerate', 'revenue', 'membership', 'growth', 'continuing', 'improve', 'product', 'content', 'marketing', '25', 'years', 'better', 'monetize', 'big', 'audience', 'position', 'strength', 'given', '$', '30', 'billion', 'plus', 'revenue', '$', '6', 'billion', 'operating', 'profit', 'year', 'growing', 'free', 'cash', 'flow', 'strong', 'balance', 'sheet', 'summary', 'results', 'forecast', 'q2', 'results', 'revenue', 'q2', 'grew', '9', 'year', 'year', '13', 'excluding', '-$339', 'million', 'foreign', 'currency', 'impact', 'driven', '6', '2', 'increase', 'average', 'paid', 'memberships', 'arm1', 'respectively', 'excluding', 'impact', 'foreign', 'exchange', 'f', 'x', 'arm', 'rose', '7', 'year', 'year', 'appreciation', 'dollar', 'usd', 'vs.', 'currencies', 'april', 'earnings', 'report', 'primary', 'reason', 'variance', 'revenue', 'guidance', 'forecast', 'slightly', 'forecasted', 'global', 'paid', 'net', 'adds', 'q2', '-1.0', 'm', 'vs.', '-2.0', 'm', 'forecast', 'compared', '+1.5', 'm', 'year', 'ago', 'quarter', ' ', 'apac', 'revenue', 'grew', '23', 'year', 'year', 'excluding', 'f', 'x.', '$', '900', 'million', 'revenue', 'apac', 'approaching', 'size', 'latam', 'business', 'added', '1.1', 'm', 'paid', 'memberships', 'region', 'vs.', '1.0', 'm', 'q2', 'arm', 'apac', '-2', 'year', 'year', 'f', 'x', 'neutral', 'basis', 'impact', 'price', 'decrease', 'india', 'december', 'plan', 'mix', 'partially', 'offset', '1arm(average', 'revenue', 'membership', 'defined', 'asstreaming', 'revenue', 'divided', 'average', 'number', 'streaming', 'paid', 'memberships', 'divided', 'number', 'months', 'period', 'figures', 'include', 'sales', 'taxes', 'vat', '1higher', 'arm', 'korea', 'australia', 'excluding', 'india', 'apac', 'arm', 'grew', '4', 'year', 'year', 'constant', 'currency', 'basis', ' ', 'excluding', 'f', 'x', 'emea', 'revenue', 'arm', 'increased', '13', '6', 'year', 'year', 'respectively', 'paid', 'net', 'additions', 'totaled', '-0.8', 'm', 'vs.', '0.2', 'm', 'year', 'ago', 'quarter', ' ', 'revenue', 'latam', 'grew', '19', 'year', 'year', 'excluding', 'f', 'x', 'surpassed', '$', '1', 'billion', 'quarterly', 'mark', 'time', 'helped', 'constant', 'currency', 'arm', 'growth', '15', 'paid', 'memberships', 'flat', 'sequentially', 'compared', '0.8', 'm', 'paid', 'net', 'adds', 'q2’21', ' ', 'ucan', 'arm', 'revenue', 'increased', '10', 'year', 'year', 'excluding', 'impact', 'f', 'x.', 'paid', 'net', 'adds', '-1.3', 'm', 'vs.', '-0.4', 'm', 'year', 'ago', 'period', 'retention', 'improved', 'course', 'quarter', 'churn', 'remains', 'slightly', 'elevated', 'near', 'pre', 'price', 'change', 'levels', 'adjusted', 'cost', 'structure', 'current', 'rate', 'revenue', 'growth', 'resulted', 'approximately', '$', '70', 'million', 'severance', 'costs', '$', '80', 'm', 'non', 'cash', 'impairment', 'certain', 'real', 'estate', 'leases', 'primarily', 'related', 'rightsizing', 'office', 'footprint', 'excluding', 'items', 'totaling', '$', '150', 'million', 'f', 'x', 'impact', 'stronger', 'dollar', 'april', 'report', 'operating', 'profit', 'operating', 'margin', 'slightly', 'ahead', 'guidance', 'forecast', 'eps', '$', '3.20', 'vs.', '$', '2.97', 'year', 'ago', 'exceeded', 'guidance', 'forecast', '$', '3.00', '$', '305', 'million', 'non', 'cash', 'unrealized', 'gain', 'f', 'x', 'remeasurement', 'euro', 'denominated', 'debt', 'recognized', 'operating', 'income', 'interest', 'income', 'approximately', '$', '5', 'billion', 'euro', 'bonds', 'provides', 'natural', 'hedge', 'euro', 'net', 'income', 'affect', 'operating', 'income', 'year', 'date', 'gain', 'f', 'x', 'remeasurement', 'euro', 'debt', '$', '467', 'million', 'q3', 'forecast', 'reminder', 'quarterly', 'guidance', 'provide', 'actual', 'internal', 'forecast', 'time', 'report', 'strive', 'accuracy', 'current', ...
#
#
# Report name: FINAL-Q3-22-Shareholder-Letter
# ['summary', ' ', 'revenue', 'operating', 'income', 'membership', 'slightly', 'exceeded', 'forecast', 'q3’22', ' ', 'big', 'hits', 'tv', 'film', 'q3', 'launching', 'watched', 'series', 'films', 'time', 'including', ' ', 'monster', 'jeffrey', 'dahmer', 'story', 'stranger', 'thingss4,extraordinary', 'attorney', 'woo', 'gray', 'man', 'andpurple', 'hearts', ' ', 'lower', 'priced', 'ad', 'supported', 'plan', 'launches', '12', 'countries', 'november', 'months', 'initial', 'announcement', 'existing', 'plans', 'remain', 'ad', 'free', ' ', 'netflix', 'higher', 'engagement', 'streamer', 'room', 'growth', ' ', 'uk', 'netflix', 'accounts', '8.2', 'video', 'viewing', '2.3x', 'amazon', '2.7x', 'disney+1', ' ', 'netflix', 'accounts', '7.6', 'tv', 'time', '2.6x', 'amazon', '1.4x', 'disney', '+', 'hulu', '+', 'hulu', 'live2', ' ', 'competitors', 'investing', 'heavily', 'drive', 'subscribers', 'engagement', 'building', 'large', 'successful', 'streaming', 'business', 'hard', 'estimate', 'losing', 'money', 'combined', '2022', 'operating', 'losses', '$', '10', 'billion', 'vs.', 'netflix', '$', '5', '$', '6', 'billion', 'annual', 'operating', 'profit', 'challenging', 'half', 'believe', 'path', 'reaccelerate', 'growth', 'key', 'pleasing', 'members', 'focused', 'winning', 'competition', 'viewing', 'day', 'series', 'movies', 'excite', 'members', 'tell', 'friends', 'people', 'watch', 'join', 'stay', '1based', 'reporting', 'frombarb', 'september', '2022', '2based', 'onnielsen', 'gauge', 'august', '2022', 'q3', 'results', '6', 'year', 'year', 'revenue', 'growth', 'q3', 'driven', '5', 'increase', 'average', 'paid', 'memberships', '1', 'rise', 'arm3', 'excluding', 'impact', 'foreign', 'exchange', 'f', 'x', 'revenue', 'arm', 'grew', '13', '8', 'year', 'year', 'respectively', 'sequential', 'decline', 'revenue', 'entirely', 'f', 'x.', 'forecasted', 'paid', 'net', 'additions', 'totaled', '2.4', 'million', 'vs.', '1.0', 'm', 'forecast', 'compared', '4.4', 'm', 'year', 'ago', 'quarter', ' ', 'apac', 'revenue', 'grew', '19', 'excluding', 'f', 'x', 'average', 'paid', 'memberships', 'rose', '23', 'year', 'year', 'arm', '-3', 'year', 'year', 'excluding', 'f', 'x', 'partially', 'driven', 'lower', 'arm', 'india', 'somewhat', 'offset', 'higher', 'arm', 'australia', 'korea', 'added', '1.4', 'm', 'paid', 'memberships', 'region', 'vs.', '2.2', 'm', 'q3', ' ', 'excluding', 'f', 'x', 'emea', 'revenue', 'arm', 'grew', '13', '7', 'respectively', 'paid', 'net', 'adds', 'totaled', '0.6', 'm', 'vs.', '1.8', 'm', 'year', 'ago', 'quarter', ' ', 'latam', 'revenue', 'increased', '19', 'year', 'year', 'supported', 'arm', 'growth', '16', 'vs.', 'year', 'ago', 'quarter', 'excluding', 'f', 'x.', 'added', '0.3', 'm', 'paid', 'memberships', 'line', 'membership', 'growth', 'q3’21', ' ', 'ucan', 'penetrated', 'market', 'arm', 'revenue', 'grew', '12', '11', 'respectively', 'excluding', 'f', 'x.', 'paid', 'net', 'adds', 'totaled', '0.1', 'm', 'similar', '0.1', 'm', 'q3’21', 'q3', 'operating', 'income', 'totaled', '$', '1.5', 'billion', 'vs.', '$', '1.8', 'billion', 'q3’21', 'operating', 'income', 'beginning', 'quarter', 'forecast', 'partially', 'higher', 'revenue', 'shift', 'timing', 'spend', 'q3', 'q4', 'result', 'operating', 'margin', '19', '16', 'forecast', 'percentage', 'point', 'year', 'year', 'decline', 'operating', 'margin', 'entirely', 'appreciation', 'dollar', 'vs.', 'currencies', 'period', 'eps', '$', '3.10', 'vs.', '$', '3.19', 'year', 'ago', 'included', '$', '348', 'million', 'non', 'cash', 'unrealized', 'gain', 'f', 'x', 'remeasurement', 'euro', 'denominated', 'debt', 'q4', 'forecast', 'reminder', 'quarterly', 'guidance', 'provide', 'actual', 'internal', 'forecast', 'time', 'report', 'appreciation', 'dollar', 'remains', 'significant', 'headwind', 'based', 'multinationals', 'general', 'q4’22', 'expecting', 'revenue', '$', '7.8', 'billion', 'sequential', 'decline', 'entirely', 'continued', 'strengthening', 'dollar', 'vs.', 'currencies', 'constant', 'currency', 'basis', 'equates', '9 ...
#
#
# Report name: FINAL-Q4-22-Shareholder-Letter
# ['summary', ' ', 'q4’22', 'revenue', 'operating', 'profit', 'membership', 'growth', 'exceeded', 'forecast', 'continue', 'lead', 'industry', 'streaming', 'engagement', 'revenue', 'profit', ' ', 'q4', 'content', 'slate', 'outperformed', 'high', 'expectations', ' ', 'wednesdaywas', 'popular', 'series', 'harry', 'meghanour', 'second', 'popular', 'documentary', 'series', 'trollour', 'popularnon', 'english', 'film', 'andglass', 'onion', 'knives', 'mysteryour', 'fourth', 'popular', 'film1', ' ', 'successfully', 'launched', 'new', 'lower', 'priced', 'ad', 'supported', 'plan', 'november', 'pleased', 'early', 'results', ' ', 'delivered', 'high', 'end', 'operating', 'profit', 'margin', 'target', 'year', '2022', 'expect', 'increase', 'operating', 'margin', '2023', 'vs.', '2022', ' ', '2022', 'finished', '231', 'm', 'paid', 'memberships', 'generated', '$', '32b', 'revenue', '$', '5.6b', 'operating', 'income', '$', '2.0b', 'net', 'cash', 'operating', 'activities', '$', '1.6b', 'free', 'cash', 'flow', 'fcf', '2023', 'expect', '$', '3b', 'fcf', 'assuming', 'material', 'swings', 'f', 'x.', ' ', 'ted', 'sarandos', 'greg', 'peters', 'co', 'ceos', 'netflix', 'reed', 'hastings', 'executive', 'chairman', 'completing', 'succession', 'process', '2022', 'tough', 'year', 'bumpy', 'start', 'brighter', 'finish', 'believe', 'clear', 'path', 'reaccelerate', 'revenue', 'growth', 'continuing', 'improve', 'aspects', 'netflix', 'launching', 'paid', 'sharing', 'building', 'ads', 'offering', 'north', 'stars', 'remain', 'pleasing', 'members', 'building', 'greater', 'profitability', 'time', '1as', 'defined', 'cumulative', 'view', 'hours', '28', 'days', '1ted', 'sarandos', 'greg', 'peters', 'co', 'ceos', 'complete', 'succession', 'process', 'reed', 'hastings', 'executive', 'chairman', 'greg', 'peters', 'stepped', 'coo', 'ted', 'sarandos', 'co', 'ceo', 'member', 'netflix', 'board', 'reed', 'greg', 'ted', 'working', 'closely', '15', 'years', 'makes', 'formal', 'externally', 'operating', 'internally', 'details', 'ourblog', 'ted', 'said', 'want', 'thank', 'reed', 'visionary', 'leadership', 'mentorship', 'friendship', '20', 'years', 'learned', 'intellectual', 'rigor', 'honesty', 'willingness', 'big', 'bets', 'look', 'forward', 'working', 'years', 'come', 'reed', 'started', 'delegate', 'management', 'greg', 'built', 'strong', 'operating', 'model', 'based', 'shared', 'values', 'like', 'minded', 'approach', 'growth', 'excited', 'start', 'new', 'chapter', 'greg', 'co', 'ceo', 'greg', 'said', 'feel', 'humbled', 'privileged', 'co', 'ceo', 'netflix', 'ted', 'worked', 'years', 'building', 'tremendous', 'trust', 'respect', 'motivated', 'goal', 'desire', 'better', 'serve', 'members', 'continue', 'grow', 'business', 'addition', 'changes', 'bela', 'bajaria', 'head', 'global', 'tv', 'chief', 'content', 'officer', 'scott', 'stuber', 'chairman', 'netflix', 'film', 'ted', 'said', 'bela', 'scott', 'outstanding', 'creative', 'executives', 'proven', 'track', 'records', 'netflix', '2022', 'premiered', 'popular', 'series', 'films', 'netflix', 'history', 'including', 'wednesday', 'glass', 'onion', 'knives', 'mystery', 'purple', 'hearts', 'monster', 'jeffrey', 'dahmer', 'story', 'adam', 'project', 'harry', 'meghan', 'testament', 'leadership', 'creativity', 'excited', 'work', 'alongside', 'seek', 'delight', 'audiences', 'years', 'come', 'details', 'netflix', 'leadership', 'seehere', 'q4', 'results', 'year', 'year', 'revenue', 'growth', '2', 'q4', '10', 'foreign', 'exchange', 'f', 'x', 'neutral', 'basis2', 'driven', '4', 'increase', 'average', 'paid', 'memberships', 'arm3declined', '2', 'year', 'year', 'grew', '5', 'f', 'x', 'neutral', 'basis2', 'revenue', 'slightly', 'beginning', 'quarterprojection', 'paid', 'net', 'adds', '7.7', 'm', 'vs.', '8.3', 'm', 'q4’21', 'came', 'higher', '4.5', 'm', 'forecast', 'strong', 'acquisition', 'retention', 'driven', 'primarily', 'success', 'q4', 'content', 'slate', 'addition', 'dollar', 'depreciated', 'vs.', 'currencies', 'quarter', 'resulted', 'slightly', 'h ...
#
#
# Report name: FINAL-Q1-23-Shareholder-Letter
# ['summary', ' ', 'q1‘23revenueandoperatingprofitwerein', 'linewithourforecast', ' ', 'wedeliveredastrongcontentslateinq1with', ' ', 'successfulreturningseasonslikeouterbanks', 'ginny&georgiaandabigsequel', 'filmmurdermystery2', ' ', 'newhitsacrossnearlyeverygenreoftvlikethenightagent(nowour6thmostpopular', 'englishlanguagetvshowever),theglory(our5thmostpopularnon', 'englishtvshow', 'ever),fullswing', 'that90sshowandfilmsyoupeopleandluther', 'thefallensun', ' ', 'withmoody’srecentupgrade', 'weachievedinvestmentgradestatus', 'netflixistheleading', 'streamingservicebasedonengagement', 'revenueandprofitandweareworkingtobuildonthat', 'in‘23,byseekingtoexpandoperatingmarginto18%-20%andtogenerateatleast+$3.5bof', 'freecashflow(upfromourpriorexpectationofatleast$3.0boffcf', ' ', 'inq1,welaunchedpaidsharinginfourcountriesandarepleasedwiththeresults', 'weare', 'planningonabroadrollout', 'includingintheus', 'inq2', ' ', 'givencurrenthealthyperformanceandtrajectoryofourper', 'memberadvertisingeconomics', 'particularlyintheus', 'we’reupgradingouradsexperiencewithmorestreamsandimproved', 'videoqualitytoattractabroaderrangeofconsumers', 'inshort', 'we’reofftoagoodstartin2023.asalways', 'ourfocusremainspleasingourmembersand', 'attractinggreatcreatorssothatwecancontinuetobuildawildlysuccessfulbusiness', "q2'23", 'inmillionsexceptpersharedata', "q1'22", "q2'22", "q3'22", "q4'22", "q1'23", 'forecast', 'revenue', '$', '7,868', '$', '7,970', '$', '7,926', '$', '7,852', '$', '8,162', '$', '8,242', 'y', 'y%growth', '9.8', '8.6', '5.9', '1.9', '3.7', '3.4', 'operatingincome', '$', '1,972', '$', '1,578', '$', '1,533', '$', '550', '$', '1,714', '$', '1,565', 'operatingmargin', '25.1', '19.8', '19.3', '7.0', '21.0', '19.0', 'netincome', '$', '1,597', '$', '1,441', '$', '1,398', '$', '55', '$', '1,305', '$', '1,283', 'dilutedeps', '$', '3.53', '$', '3.20', '$', '3.10', '$', '0.12', '$', '2.88', '$', '2.84', 'globalstreamingpaidmemberships', '221.64', '220.67', '223.09', '230.75', '232.50', 'y', 'y%growth', '6.7', '5.5', '4.5', '4.0', '4.9', 'globalstreamingpaidnetadditions', '-0.20', '-0.97', '2.41', '7.66', '1.75', 'netcashprovidedbyoperatingactivities', '$', '923', '$', '103', '$', '557', '$', '444', '$', '2,179', 'freecashflow', '$', '802', '$', '13', '$', '472', '$', '332', '$', '2,117', 'shares(fd', '453.0', '450.2', '450.3', '451.6', '452.4', 'q1', 'results', 'revenuegrew4%yearoveryearinq1(+8%onaforeignexchange(f', 'x)neutralbasis1),consistentwith', 'ourbeginning', 'quarterforecast', 'averagepaidmembershipsincreased4%yearoveryear', 'whilearm2', 'was-1%vs', 'q1’22(+4%onanf', 'xneutralbasis).paidnetaddsamountedto1.8mforq1vs.-0.2minthe', 'yearagoquarter', 'regionalhighlightsinclude', ' ', 'ucanrevenuegrew8%yearoveryear(bothreportedandf', 'xneutral)drivenbya9%increase', 'inarm(bothreportedandf', 'xneutral', ' ', 'emearevenuewasdown2%yearoveryear(+6%onanf', 'xneutralbasis),dueprimarilytoa', 'declineof6%inarm(+1%onanf', 'xneutralbasis),offsetpartiallybya4%increaseinaverage', 'paidmemberships', ' ', 'latamrevenueincreased7%yearoveryear(+13%f', 'xneutral),witha3%riseinarm(+8%f', 'x', 'neutral).paidmembershipdippedby0.4m', 'whichwebelieveisduetopullforwardfromq4', 'whenwehadabigquarterwith1.8mpaidnetadds)andongoingmacroeconomicsoftness', ' ', 'apacrevenuegrew2%yearoveryear(+10%f', 'xneutral).averagepaidmembershipsincreased', '17%yearoveryear', 'thisoffseta13%decreaseinarm(-6%f', 'xneutral),whichwasduetoplan', 'mixandahighermixofmembergrowthincountrieswithlowerpricing', 'operatingincometotaled$1.7bvs.$2.0binq1‘22', 'aboveourguidanceforecastof$1.6bdueto', 'ongoingexpensemanagementandtimingofhiringandcontentspend', 'operatingmarginwas21', 'comparedto25%intheyearagoperiod', 'theyearoveryeardeclineinoperatingmarginwasprimarily', 'duetof', 'x', 'theappreciationoftheusdollaraccountedforroughlythreepercentagepointsoftheyear', 'overyearchangeinoperatingmargin', 'q1’23epsof$2.88(vs.$3.53inq1‘22)wasin', 'linewithour', 'guidanceof$2.82andincludedan$81millionnon', 'cash ...
#
#
# Report name: FINAL-Q2-23-Shareholder-Letter
# [' ', 'inmay', 'wesuccessfullylaunchedpaidsharingin100+countries', 'representingmorethan80%of', 'ourrevenuebase', ' ', 'revenueineachregionisnowhigherthanpre', 'launch', 'withsign', 'upsalreadyexceeding', 'cancellations', ' ', 'paidnetadditionswere5.9minq2,andtodaywe’rerollingoutpaidsharingtoalmost', 'alloftheremainingcountries', ' ', 'q2‘23revenueof$8.2bandoperatingprofitof$1.8bweregenerallyin', 'linewithour', 'forecast', 'andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto', 'seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad', 'supportedplan', 'we’restilltargetingafullyear2023operatingmarginof18%to20', ' ', 'we’realeaderintermsofstreamingengagementand', 'pernielsen', 'wehadthetoporiginal', 'streamingseriesintheusfor24ofthefirst25weeksof2023,andthetopmoviefor21weeks', 'whilewe’vemadesteadyprogressthisyear', 'wehavemoreworktodotoreaccelerateourgrowth', 'remainfocusedon', 'creatingasteadydrumbeatofmustwatchshowsandmovies;improving', 'monetization;growingtheenjoymentofourgames;andinvestingtoimproveourserviceformembers', "q3'23", 'inmillionsexceptpersharedata', "q2'22", "q3'22", "q4'22", "q1'23", "q2'23", 'forecast', 'revenue', '$', '7,970', '$', '7,926', '$', '7,852', '$', '8,162', '$', '8,187', '$', '8,520', 'y', 'y%growth', '8.6', '5.9', '1.9', '3.7', '2.7', '7.5', 'operatingincome', '$', '1,578', '$', '1,533', '$', '550', '$', '1,714', '$', '1,827', '$', '1,890', 'operatingmargin', '19.8', '19.3', '7.0', '21.0', '22.3', '22.2', 'netincome', '$', '1,441', '$', '1,398', '$', '55', '$', '1,305', '$', '1,488', '$', '1,580', 'dilutedeps', '$', '3.20', '$', '3.10', '$', '0.12', '$', '2.88', '$', '3.29', '$', '3.52', 'globalstreamingpaidmemberships', '220.67', '223.09', '230.75', '232.50', '238.39', 'y', 'y%growth', '5.5', '4.5', '4.0', '4.9', '8.0', 'globalstreamingpaidnetadditions', '-0.97', '2.41', '7.66', '1.75', '5.89', 'netcashprovidedbyoperatingactivities', '$', '103', '$', '557', '$', '444', '$', '2,179', '$', '1,440', 'freecashflow', '$', '13', '$', '472', '$', '332', '$', '2,117', '$', '1,339', 'shares(fd', '450.2', '450.3', '451.6', '452.4', '451.6', 'q2', 'results', 'revenueinq2grew3%yearoveryear(+6%onaforeignexchange(f', 'x)neutralbasis1).revenuegrowth', 'wasdrivenbya6%increaseinaveragepaidmembership', 'whilearm2declined3%yearoveryear(-1', 'f', 'xneutral).theyear', 'yeararmdeclinewasdrivenbyacombinationoflimitedpriceincreasesover', 'thepast12months(leadinguptothelaunchofpaidsharing),timingofpaidnetadditions(primarilylate', 'inthequarterduetothemay23rolloutofpaidsharinginq2),andahighermixofmembershipgrowth', 'fromlowerarmcountries', 'wehadpaidnetadditionsof5.9mforq2’23(withover1mpaidnetaddsineachregion)vs.-1.0min', 'q2’22aswesuccessfullyrolledoutpaidsharingtomorethan100countries(representingover80%of', 'ourrevenue).q2operatingincometotaled$1.8b', 'up16%vs.$1.6bintheyearagoquarter', 'operating', 'marginwas22%,comparedwith20%inq2’22.bothwereslightlyaheadofourbeginning', 'quarter', 'forecastduetoongoingexpensemanagement', 'slower', 'projectedheadcountgrowthandtimingof', 'contentspend', 'epsinq2amountedto$3.29vs.$3.20inq2’22andincludeda$29millionnon', 'cash', 'unrealizedlossfromf', 'xremeasurementonoureurodenominateddebt', 'whichisrecognizedbelow', 'operatingincomein“interestandotherincome', 'expense', 'forecast', 'ourprimaryfinancialmetricsarerevenueforgrowth', 'andoperatingmarginforprofitability', 'ourgoalis', 'toacceleraterevenuegrowth', 'expandouroperatingmarginanddelivergrowingpositivefreecashflow', 'asareminder', 'thequarterlyguidanceweprovideisouractualinternalforecastatthetimewereport', 'nowthatwe’velaunchedpaidsharingbroadly', 'wehaveincreasedconfidenceinourfinancialoutlook', 'weexpectrevenuegrowthwillaccelerateinthesecondhalfof2023asmonetizationgrowsfromour', 'mostrecentpaidsharinglaunchandweexpandourinitiativeacrossnearlyallremainingcountriesplus', 'thecontinuedsteadygrowthinourad', 'supportedplan(moredetailsinthemonetizationandrevenue', 'section', 'forq3,weforecastrevenueof$8.5b', 'u ...

# %% [markdown]
# ### Find the most frequent mentioned financial keywords in each report

# %%
def find_related_financial_keywords(tokenized_reports):
    # financial_terms.txt is a list of financial keywords from Tilburg University
    with open('financial_terms.txt', 'r') as f:
        financial_keywords = [line.strip() for line in f]

    # Find all synsets related to financial keywords
    financial_synsets = [wordnet.synsets(keyword) for keyword in financial_keywords]

    # Flatten the list of synsets
    financial_synsets = [synset for sublist in financial_synsets for synset in sublist]

    # Find all lemmas for these synsets
    financial_lemmas = [lemma.name() for synset in financial_synsets for lemma in synset.lemmas()]

    # Initialize a dictionary to store the most frequent financial keywords for each document
    financial_keywords_counts_dict = {}

    # Iterate over each document in tokenized_reports
    for report_name, tokenized_report in tokenized_reports.items():

        # For each tokenized report, get a list of all tokens
        all_tokens = [token.text for doc in tokenized_report for token in doc]

        # Filter tokens to only include those in the financial lemmas list
        financial_tokens = [token for token in all_tokens if token in financial_lemmas]

        # Use Counter to count each financial token's occurrences
        financial_token_counts = Counter(financial_tokens)

        # Only keep the top 10 most frequent financial words
        top_10_financial_words = financial_token_counts.most_common(10)

        # Add the result to the dictionary
        financial_keywords_counts_dict[report_name] = top_10_financial_words

    return financial_keywords_counts_dict

# Call the function
financial_keywords_counts = find_related_financial_keywords(tokenized_reports)

# Print the results
for report_name, financial_keywords_counts in financial_keywords_counts.items():
    print(f"Report name: {report_name}")
    for word, count in financial_keywords_counts:
        print(f"Word: {word}, Count: {count}")
    print("\n")
# Out:
# Report name: FINAL-Q1-21-Shareholder-Letter
# Word: be, Count: 9
# Word: forecast, Count: 7
# Word: net, Count: 7
# Word: revenue, Count: 5
# Word: second, Count: 4
# Word: world, Count: 4
# Word: production, Count: 3
# Word: number, Count: 3
# Word: line, Count: 2
# Word: return, Count: 2
#
#
# Report name: FINAL-Q2-21-Shareholder-Letter
# Word: be, Count: 11
# Word: revenue, Count: 7
# Word: forecast, Count: 7
# Word: net, Count: 7
# Word: world, Count: 6
# Word: share, Count: 4
# Word: cost, Count: 3
# Word: number, Count: 2
# Word: value, Count: 2
# Word: global, Count: 2
#
#
# Report name: FINAL-Q3-21-Shareholder-Letter
# Word: be, Count: 11
# Word: net, Count: 9
# Word: production, Count: 5
# Word: forecast, Count: 5
# Word: number, Count: 5
# Word: global, Count: 4
# Word: release, Count: 3
# Word: variety, Count: 3
# Word: event, Count: 3
# Word: second, Count: 2
#
#
# Report name: FINAL-Q4-21-Shareholder-Letter
# Word: net, Count: 10
# Word: world, Count: 8
# Word: be, Count: 8
# Word: forecast, Count: 7
# Word: revenue, Count: 6
# Word: number, Count: 3
# Word: structure, Count: 3
# Word: variety, Count: 3
# Word: make, Count: 3
# Word: value, Count: 3
#
#
# Report name: FINAL-Q1-22-Shareholder-Letter
# Word: revenue, Count: 17
# Word: net, Count: 12
# Word: forecast, Count: 7
# Word: be, Count: 6
# Word: number, Count: 5
# Word: share, Count: 4
# Word: price, Count: 4
# Word: world, Count: 3
# Word: line, Count: 3
# Word: profitability, Count: 2
#
#
# Report name: FINAL-Q2-22-Shareholder-Letter
# Word: revenue, Count: 23
# Word: be, Count: 15
# Word: forecast, Count: 10
# Word: net, Count: 10
# Word: profit, Count: 7
# Word: currency, Count: 6
# Word: world, Count: 6
# Word: global, Count: 5
# Word: range, Count: 4
# Word: second, Count: 4
#
#
# Report name: FINAL-Q3-22-Shareholder-Letter
# Word: revenue, Count: 23
# Word: forecast, Count: 9
# Word: be, Count: 8
# Word: net, Count: 7
# Word: pay, Count: 7
# Word: profit, Count: 6
# Word: annual, Count: 4
# Word: price, Count: 4
# Word: global, Count: 4
# Word: release, Count: 4
#
#
# Report name: FINAL-Q4-22-Shareholder-Letter
# Word: revenue, Count: 21
# Word: net, Count: 11
# Word: be, Count: 10
# Word: profit, Count: 7
# Word: forecast, Count: 7
# Word: result, Count: 5
# Word: share, Count: 5
# Word: number, Count: 4
# Word: value, Count: 3
# Word: line, Count: 3
#
#
# Report name: FINAL-Q1-23-Shareholder-Letter
# Word: value, Count: 1
# Word: gaming, Count: 1
#
#
# Report name: FINAL-Q2-23-Shareholder-Letter
# Word: forecast, Count: 1

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def find_top10_frequent_words(tokenized_reports):
    # Select the two reports
    reports = ['FINAL-Q1-23-Shareholder-Letter', 'FINAL-Q2-23-Shareholder-Letter']

    # Initialize a dictionary to store the most frequent words for each selected report
    frequent_words_counts_dict = {}

    # Iterate over each selected report
    for report_name in reports:
        if report_name in tokenized_reports:
            tokenized_report = tokenized_reports[report_name]

            # For each tokenized report, get a list of all tokens
            all_tokens = [token.text.lower() for doc in tokenized_report for token in doc]

            # Filter out punctuation, stop words, and other non-alphabetic tokens
            all_tokens = [token for token in all_tokens if token.isalpha() and not nlp.vocab[token].is_stop]

            # Use Counter to count each token's occurrences
            token_counts = Counter(all_tokens)

            # Only keep the top 10 most frequent words
            top_10_words = token_counts.most_common(10)

            # Add the result to the dictionary
            frequent_words_counts_dict[report_name] = top_10_words

    return frequent_words_counts_dict

# Call the function
frequent_words_counts = find_top10_frequent_words(tokenized_reports)

# Print the results
for report_name, frequent_words_counts in frequent_words_counts.items():
    print(f"Report name: {report_name}")
    for word, count in frequent_words_counts:
        print(f"Word: {word}, Count: {count}")
    print("\n")
# Out:
# Report name: FINAL-Q1-23-Shareholder-Letter
# Word: forexample, Count: 4
# Word: x, Count: 3
# Word: memberadvertisingeconomics, Count: 2
# Word: forecast, Count: 2
# Word: revenue, Count: 2
# Word: y, Count: 2
# Word: business, Count: 2
# Word: similarly, Count: 2
# Word: monetization, Count: 2
# Word: summary, Count: 1
#
#
# Report name: FINAL-Q2-23-Shareholder-Letter
# Word: forecast, Count: 3
# Word: inmay, Count: 2
# Word: revenue, Count: 2
# Word: y, Count: 2
# Word: f, Count: 2
# Word: cash, Count: 2
# Word: ourrevenuebase, Count: 1
# Word: revenueineachregionisnowhigherthanpre, Count: 1
# Word: launch, Count: 1
# Word: withsign, Count: 1

# %% [markdown]
# ### split documents into sentence

# %%
# Initialize a dictionary to store the joined sentences for each report.
joined_sentences = {}

# Iterate over each report in pdf_texts.
for report_name, report_text in pdf_texts.items():

    # Split the report text into sentences.
    sentences = nlp(report_text).sents

    # Initialize a list to hold the tokenized sentences for this report.
    tokenized_report_sentences = []

    # Iterate over each sentence.
    for sentence in sentences:
        # Tokenize, lemmatize, and remove stop words and punctuation.
        tokenized = [token.lemma_ for token in sentence if not token.is_stop and not token.is_punct]
        # Add the tokenized sentence to the list.
        tokenized_report_sentences.append(tokenized)

    # Join each tokenized sentence into a single string, and store them in a list.
    joined_report_sentences = [' '.join(sentence) for sentence in tokenized_report_sentences]

    # Add the joined sentences for this report to joined_sentences.
    joined_sentences[report_name] = joined_report_sentences

# Print the joined sentences for each report.
for report_name, joined_report_sentences in joined_sentences.items():
    print(f"Report name: {report_name}")
    print(joined_report_sentences)
    print("\n")
# Out:
# Report name: FINAL-Q1-21-Shareholder-Letter
# ['revenue grow 24 year year line withour beginning quarter forecast operate profit margin reach time high', 'finishedq1’21 208 m pay membership 14 year year guidance forecast 210mpaid membership', 'believe pay membership growth slow big Covid-19 pull forwardin 2020 light content slate firsthalf year Covid-19 production delay', 'continueto anticipate strong second half return new season big hitsand exciting film lineup', 'short term thereis uncertainty Covid-19 long term rise streaming replace linear tv aroundthe world clear trend entertainment', 'Q1 Results Q2 Forecast Average revenue membership1rose 6 year overyear 5 exclude foreign exchange impact + $ 80 m. operate income $ 2 billion vs. $ 958 millionmore double vs. Q1’20', 'exceed guidance forecast primarily timing contentspend', 'EPS $ 3.75 vs. $ 1.57 year ago include $ 253 m non cash unrealized gain F Xremeasurement Euro denominate debt', 'extraordinary event Covid-19 lead unprecedentedmembership growth 2020 pull forward growth 2021 delay production acrossevery region', 'turn end 2020 big membership revenue base otherwisehave contribute record q1’21 revenue', 'ramp productionlevel late year low content spendin 1average revenue membership ARM define asstreame revenue divide average number streaming pay membership divide number ofmonth period', 'figure includesale taxis VAT', 'Q1’21 content amortization grow 9.5 year year Q1’21 vs. 17 FY20', 'result 10 percentage point year year jump operatingmargin 27 Q1 time high', 'discuss past letter dynamic arealso contribute light content slate thefirst half 2021 believe slow membership growth', 'Q1 pay net addition 4 m 6 m guidance 16 m net addition inthe year ago quarter primarily acquisition retention Q1 line expectation', 'believe competitive intensity materially change quarter material factor inthe variance forecast allof region', 'see similar percentage year yeardecline pay net add region Regional Breakdown table levelof competitive intensity vary country', 'reminder quarterly guidance provide isour actual internal forecast time report', 'mean quarter result highrelative guidance forecast low see chart', 'asour membership base continue grow naturally volatility absolute paidnet addition performance vs. forecast', 'similar pull forward delay slate dynamicsplus typical seasonality expect impact Q2’21 project pay net addition 1 m vs. 10min prior year quarter UCAN LATAM region expect roughly flattish memberships(+/- couple thousand pay net add', 'anticipate pay membership growth acceleratein second half 2021 ramp strong half slate return bighit likeSex', 'Education Witcher La Casa dePapel akaMoney Heist andYou excitingarray original film include finale tothekisse Boothtrilogy large scale star drive featureslikeRed Notice(starring Gal Gadot Dwayne Johnson Ryan Reynolds', 'andDon’t look up(with starcast include Leonardo DiCaprio Jennifer Lawrence Cate Blanchett Timothée Chalamet MerylStreep', 'comprehensive offering date local language titlesincludingToo', 'hot Handlefor Brazil Mexico 2a special base korean hit franchiseKingdom action thrillerDhamaka(India new season ofSintonia(Brazil andControl Z(Mexico', 'focus fundamental ourbusiness remain healthy', 'addition record financial result engagement member householdgrew solidly year year Q1’21', 'see member value Netflix q1’21churn q1‘20 level demonstrate improve service charge bit', 'FY21 operate margin target 20 vs. 18 year remain unchanged', 'optimistic aboutthe future believe earlyday adoption internet entertainment shouldprovide year growth ahead', 'Content see weekly growth chart earlyQ1 benefit ofBridgerton LupinandCobra Kai follow growth trajectory similarto recent year', 'note previously production delay Covid-19 2020 leadto 2021 slate heavily second half weight large number return franchise', 'roll vaccine uneven world produce safelyin major market exception Brazil India', 'assume continue spendover $ 17 billion cash content year continue deliver amazing range titlesfor member ...
#
#
# Report name: FINAL-Q2-21-Shareholder-Letter
# ['Q2 revenue increase 19 year year $ 7.3billion operating income rise 36 year year $ 1.8 billion', 'finish quarter withover 209 m pay membership slightly ahead forecast', 'COVID create lumpiness ourmembership growth high growth 2020 slow growth year work way', 'continue focus improve service member bring good story fromaround world', 'summary result forecast Q3', 'q2 result Q3 Forecast Revenue growth drive 11 increase averagepaid stream membership 8 growth average revenue membership ARM)1', 'ARM rose4 exclude foreign exchange FX impact + $ 277 m. operate margin 25.2 expand 3 percentagepoint compare year ago quarter', 'EPS $ 2.97 vs. $ 1.59 year ago include $ 63mnon cash unrealized loss FX remeasurement Euro denominate debt', 'pandemic create unusual choppiness ourgrowth distort year year comparison acquisition engagement member household spikedin early month covid', 'Q2’21 engagement member household expect vs. unprecedented level 17 compare comparable Q2’19', 'similarly retention continue strong well pre covid Q2’19 level average revenueper membership grow 8 year 1average revenue membership ARM define asstreame revenue divide average number streaming pay membership divide number ofmonth period', 'figure includesale taxis VAT', '1period demonstrate member value Netflix improve service charge bit', 'add 1.5 m pay membership Q2 slightly aheadof 1.0 m guidance forecast', 'APAC region represent third global pay net add quarter', 'expect Q2 pay membership UCAN region slightly downsequentially -0.4 m pay net add', 'believe large membership base UCAN couple seasonallysmaller quarter acquisition main reason dynamic', 'similar weexperience Q2’19 UCAN pay net add -0.1 m add nearly 7.5 m paidnet add UCAN', 'reminder quarterly guidance provide isour actual internal forecast time report', 'Q3’21 forecast pay net addition 3.5mvs', '2.2 m prior year period', 'achieve forecast add 54 m pay netadd past 24 month 27 m annualize basis time period consistentwith pre covid annual rate net addition', 'forecast ARM grow roughly5 year year FX neutral basis Q3’21', 'continue target 20 operating margin thefull year 2021 vs. 18 2020', 'big global launch January 2016 commit steadily growingour operate margin average rate percentage point year anyfew year period', 'year little over(like 2020 year little like 2021).assuming achieve margin target year quintuple operate margin lastfive year track ahead average annual percentage point pace', '2with revenue margin increase operatingprofit dollar rise dramatically invest heavily about$100 million quarter 2016 nearly $ 2 billion quarter far 2021', 'belief isthat steadily improve service betterplease member lead continued growth inour membership base ARM revenue operate margin profit dollar', 'content launch original scripted tv seriesin 2012 expand original programming effort additional category world', 'goal choice entertainment varietyand quality title', 'despite covid relate production delay 2020 ableto deliver exciting portfolio title Q2’21 exemplify ambition', 'example Shadow Bone fantasy series basedon popularGrishaverse book series prove popular member', '55 m memberhousehold choose watch 28 day renew second season', 'Sweet Tooth base beloved DC comic hit series 60 m member household choosingthis title week', 'expansion non fiction series go', 'past quarter standout unscripted title include season date showToo', 'hot Handleand socialexperiment reality', 'programThe circle(an estimate 29 m 14 m respectively choose watchin 28 day true crime docu seriesThe Sons Sam(19 m', 'buildingout unscripted title local version format', 'example TooHot handle BrazilandToo Hot handle Latino launch later July September respectively serve LATAM region', '3we’re quickly grow live action animate original film offering impactful title Q2', 'Zack snyder’sarmy Deadwas blockbuster 75 m member household choose watch action pack zombie spectaclein 28 day release', 'extensionto Army Dead prequel Army Thieves willbe release Q4’21 spin ...
#
#
# Report name: FINAL-Q3-21-Shareholder-Letter
# ['light normal content slate Q1 Q2 covid relate production delay 2020 see positive effect strong slate second half year', 'Q3 grow revenue 16 year year $ 7.5 billion operating income rise 33 vs. prior year quarter $ 1.8 billion', 'add 4.4 m pay net add vs. 2.2 m Q3’20 end quarter 214 m pay membership', 'excited finish year expect strong Q4 content offer show big content expense low operating margin sequentially', 'Q3 result Q4 Forecast Revenue growth Q3 drive 9 7 increase average pay stream membership ARM1 respectively', 'exclude foreign exchange fx)impact + $ 128 m ARM rise 5 year year', 'operate margin Q3 amount 23.5 percentage point increase vs. year ago period', 'beginning quarter forecast timing content spend low forecast marketing spend', 'EPS $ 3.19 vs. $ 1.74 year ago include $ 136 m non cash unrealized gain FX remeasurement Euro denominate debt', 'forecast pay net add quarter 4.4 m actual vs. 3.5 m projection end pay membership 214 m 0.4 forecast', 'second consecutive quarter APAC region large contributor membership growth 2.2 m pay net add half total pay net add continue improve service region', 'EMEA pay net add 1.8 m improve sequentially vs. 188k Q2 title particularly strong impact', 'UCAN 1ARM Average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period', 'figure include sale taxis vat', '1latam region grew pay membership slowly', 'region high penetration broadband home believe ample runway growth continue improve service', 'reminder quarterly guidance provide actual internal forecast time report strive accuracy', 'Q4’21 forecast pay net add 8.5 m consistent Q4’20 pay net addition', 'year 2021 forecast operate margin 20 slightly well', 'mean Q4’21 operating margin approximately 6.5 compare 14 Q4’20', 'year year decline operate margin backloade big content release schedule q4 result roughly 19 year year increase content amortization Q4’21 compare ~8 growth year date', 'content programming strategy provide member wide variety high quality content love watch large number', 'season ofla Casade Papel(akaMoney Heist season Sex Educationwere big return showsin quarter 69 m 55 m member household respectively choose watch fan favorite week', 'heel Queen Gambit limited serieshit withmaidwhich launch quarter end October 1', 'expect story live poverty line award win playwright screenwriter Molly Smith Metzler reach 67 m household week', 'La Casa de Papelwas non english languagetitle subtitle dub great story truly come love', 'produce local tv film approximately 45 country build deep relationship creative community world', 'goal local content executive create locally authentic story resonate country likeThe Chestnut Manwhich expect watch 2approximately third danish member week Netflix global direct consumer service enable creator reach broad audience give member great choice story enjoy', 'well example thanSquid Game unique korean story capture zeitgeist Korea globally', 'release September 17 becomeour big tv', 'mind boggling142mmember household globally havechosen watch title week', 'breadth ofSquid Game popularity truly amazing;this rank 1 program 94 country include', 'like big hit Squid Gamehas pierce cultural zeitgeist spawn aSaturday Night Liveskitandmemes clip TikTokwith 42 billion view', 'demand consumer product celebrate fandom forSquid Gameis high item way retail', 'film slate continue build variety successful Q3 title action filmsweetgirl star Jason Momoa 68 m member household choose watch weeks),kisse Booth 3 59 m installment rom com trilogy animate family filmvivo(46 m andBlood Red Sky german language action horror movie 53 m', 'later year shift report hour view title number account choose watch', 'difference ranking think engagement measure hour view slightly well indicator overall success title member satisfaction', 'match outside service measure tv viewing give proper credit rewatche', 'addition start release title metric regularly outside earning  ...
#
#
# Report name: FINAL-Q4-21-Shareholder-Letter
# ['achieve milestone 2021 big tv year Squid Game big film release time Red NoticeandDon’t look Netflix emmy winning nominated tv network oscar win nominated movie studio 2021', 'year revenue $ 30 billion grow 19 year year operate income $ 6.2 billion rise 35 year year', 'finish Q4 222 m pay membership 8.3 m pay', 'net add Q4', 'world uncertainty increase competition optimistic long term growth prospect streaming supplant linear entertainment world', 'continually improve Netflix member grow share leisure time lead transition', 'summary result forecast', 'Q4 Results Q1 Forecast Revenue Q4’21 grow 16 year year 9 increase average pay membership', 'ARM1rose 7 year year reported foreign exchange F X neutral basis percentage point fast Q3’21 ex F X', 'operate margin Q4 amount 8 percentage point decrease vs. year ago period', 'decline operate margin expect give large content slate Q4 year', 'operate margin beginning quarter forecast 6.5 slightly low forecast content spend', 'result year operating margin 21 vs. 18 2020 1arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period', 'figure include sale taxis vat', '1above 20 guidance forecast', 'EPS Q4 $ 1.33 vs. $ 1.19 year ago include $ 104 m non cash unrealized gain FX remeasurement Euro denominate debt', 'slightly forecast pay net add Q4 8.3 m actual compare 8.5 m pay net add year ago quarter beginning quarter projection', 'year 2021 pay net add total 18 m vs 37 m 2020', 'service continue grow globally 90 pay net add 2021 come outside UCAN region', 'nonetheless UCAN region add 1.2 m pay membership Q4’21 vs. 0.9 m year mark strong quarter member growth region early day COVID-19 2020', 'APAC increase pay membership 2.6 m vs. 2.0 m year ago quarter strong growth Japan India', 'EMEA large contributor pay net add Q4 3.5 m vs. 4.5 m prior year period region deliver record quarterly revenue exceed $ 2.5 billion time', 'LATAM pay net add total 1.0 m vs. 1.2 m year', 'reminder quarterly guidance provide actual internal forecast time report', 'mean quarter result high relative guidance forecast low see chart', 'membership base continue grow naturally volatility absolute pay net add performance vs. forecast', 'Q1’22 forecast pay net add 2.5 m vs. 4.0 m year ago quarter', 'guidance reflect end weight content slate Q1’22 example bridgertons2 new original film Adam Projectwill launch March).In addition retention engagement remain healthy acquisition growth accelerate pre covid level', 'think factor include ongoing covid overhang macro economic hardship part world like LATAM', '2for 2022 currently target operate margin 19%-20 assume material swing foreign currency current level', 'operate margin outlook drive main factor', 'see chart deliver percentage point annual linear progression past year average percentage point year', 'second theus dollar strengthen meaningfullyagainst currency', '~60 revenue outside international success estimate dollar appreciation past month cost roughly $ 1 billion expect 2022 revenue reminder hedge', 'vast majority expense dollar translate estimate percentage point negative impact 2022 operating margin', 'write past medium term believe adjust pricing cost structure strong dollar world', 'near term want continue invest appropriately business want react F X fluctuation detriment long term growth', 'change goal steadily grow operate margin average increase percentage point year year period', '3content Q4 content slate epitomize strive wide variety quality tv series film', 'number big hit Q4', 'release new season return show likeThe Witcher(484 million hour viewed2),you(468 m hour viewed),emily inparis(287 million hour view December 31 Cobra Kai(274 m hour view criticallyacclaimed limit seriesmaid(469 m hour view', 'dystopian korean thrillersquid Game- late Q3 release break globally early q4 generate 1.65 billion hour view week big tv season', 'fourth quarter feature conclusion popular show -La', 'Casa de ...
#
#
# Report name: FINAL-Q1-22-Shareholder-Letter
# ['revenue growth slow considerably result forecast', 'streaming win linear predict Netflix title popular globally', 'relatively high household penetration include large number household share account combine competition create revenue growth headwind', 'big covid boost streaming obscure picture recently', 'work reaccelerate revenue growth improvement service effective monetization multi household sharing hold operate margin 20', 'key success ability create amazing entertainment world present highly personalized way win viewing competitor', 'Netflix core strength competitive advantage', 'strong profitability believe foundation significantly improve well monetize service long term', 'growth Outlook launch streaming 2007 operate firm belief internet deliver demand entertainment supplant linear TV transition represent generation opportunity build highly popular profitable entertainment company', 'People love movie tv show game broadband smart tv penetration continue grow globally connected device hundred million home pay Netflix half world broadband home represent huge future growth potential', '1in', 'near term grow revenue fast like', 'covid cloud picture significantly increase growth 2020 lead believe slow growth 2021 covid pull forward', 'believe main inter related factor work', 'increasingly clear pace growthinto underlie addressable market broadband home partly dependent factor directly control like uptake connected tv majority viewing tv adoption demand entertainment datum cost', 'believe factor improve time broadband household potential Netflix customer', 'second addition 222 m pay household estimate Netflix share 100 m additional household include 30 m UCAN region', 'account sharing percentage pay membership change year couple factor mean hard grow membership market issue obscure covid growth', 'competition view linear tv wellas YouTube Amazon Hulu robust 15 year', 'year traditional entertainment company realize streaming future new streaming service launch', 'television viewing share example steady accord Nielsen want grow share fast', 'high view share indicator high satisfaction support high retention revenue', 'fourth macro factor include sluggish economicgrowth increase inflation geopolitical event Russia invasion Ukraine continue disruption COVID likely have impact', '2our plan reaccelerate viewing revenue growth continue improve aspect Netflix particular quality programming recommendation member value', 'content double story development creative excellence reflect big Q1’22 tv hit likeBridgerton(627 million hour view season 21 big english language series history', 'andinvente anna(512 m hour view extremely successful partnership Shonda Rhimes film liketinder Swindler(166 m hour view big documentary film release andThe', 'Adam Project(233 m hour view come Q4 hitsRed noticeanddon’tlook', 'product recently launch double thumb member well express truly love versus simply like enable continue improve personalize recommendation overall experience', 'focus continuous improvement serve past 25 year big battle Blockbuster nearly 20 year ago launch growth streaming switch licensed second run tv series film original programming development domestic business primarily english language content global entertainment service', 'large subscription streaming service world key metric pay membership engagement revenue profit', 'focus good monetize sharing 100M+ household household account', 'big opportunity household watch Netflix enjoy service', 'share likely help fuel growth get people enjoy Netflix', 'try sharingwithina member’shousehold easy feature like profile multiple stream', 'popular create confusion Netflix share household', 'early year start test different approach monetize sharing March introduce newpaid sharing feature current member choice pay additional household market Latin America', 'broad range engagement come share household high occasional viewing', 'will able monetize right believe large short- mid term opportunit ...
#
#
# Report name: FINAL-Q2-22-Shareholder-Letter
# ['Q2 well expect membership growth foreign exchange bad expect strong dollar result 9 revenue growth 13 constant currency', 'challenge opportunity accelerate revenue membership growth continue improve product content marketing 25 year well monetize big audience', 'position strength give $ 30 billion plus revenue $ 6 billion operating profit year grow free cash flow strong balance sheet', 'summary result forecast', 'q2 result Revenue Q2 grow 9 year year 13 exclude -$339 million foreign currency impact drive 6 2 increase average pay membership ARM1 respectively', 'exclude impact foreign exchange F X ARM rise 7 year year', 'appreciation dollar usd vs. currency April earning report primary reason variance revenue guidance forecast', 'slightly forecast global pay net add Q2 -1.0 m vs. -2.0 m forecast compare +1.5 m year ago quarter  ', 'APAC revenue grow 23 year year exclude F X.', '$ 900 million revenue APAC approach size LATAM business', 'add 1.1 m pay membership region vs. 1.0 m q2', 'ARM APAC -2', 'year year F x neutral basis impact price decrease India December plan mix partially offset 1arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period', 'figure include sale taxis vat', '1higher arm Korea Australia', 'exclude India APAC ARM grow 4 year year constant currency basis  ', 'exclude F X EMEA revenue ARM increase 13 6 year year respectively pay net addition total -0.8 m vs. 0.2 m year ago quarter  ', 'revenue LATAM grow 19 year year exclude F X surpass $ 1 billion quarterly mark time help constant currency arm growth 15', 'pay membership flat sequentially compare 0.8 m pay net add Q2’21  ', 'UCAN arm revenue increase 10 year year exclude impact F X. pay net add -1.3 m vs. -0.4 m year ago period', 'retention improve course quarter churn remain slightly elevate near pre price change level', 'adjust cost structure current rate revenue growth', 'result approximately $ 70 million severance cost $ 80 m non cash impairment certain real estate lease primarily relate rightsize office footprint', 'exclude item total $ 150 million F X impact strong dollar April report operate profit operating margin slightly ahead guidance forecast', 'EPS $ 3.20 vs. $ 2.97 year ago exceed guidance forecast $ 3.00 $ 305 million non cash unrealized gain F X remeasurement Euro denominate debt recognize operating income interest income', 'approximately $ 5 billion Euro bond provide natural hedge Euro net income affect operating income', 'year date gain F X remeasurement Euro debt $ 467 million', 'Q3 Forecast reminder quarterly guidance provide actual internal forecast time report', 'strive accuracy current uncertain macro economic environment lead normal visibility', 'dollar continue strengthen meaningfully currency ahistoric pace withthe Euro recently fall dollarfor thefirst time decade significant headwind multinational company', 'high exposure unprecedented appreciation usd nearly 60 revenue come outside swing F X large flow operate profit expense usd benefit strong usd', 'Q3 revenue growth forecast 5 translate 12 year year revenue growth constant currency basis', 'similarly exclude impact currency operate profit growth -3 year year vs forecast decline -29 operate margin 20 vs forecast 16', 'write past medium term intend continue adjust business appropriate give relative strength usd protect operate margin try avoid immediate action believe detrimental business', 'forecast pay net add Q3 +1.0 m vs. 4.4 m year ago quarter', 'continue expect year 2022 operating margin 19%-20 exclude unanticipated $ 150 m restructure cost Q2 2noted material movement F X January 2022 guidance set base F X time ourQ4’21 letter', 'Content Marketing product quarter discuss slow revenue growth believe result connected tv adoption account sharing competition macro factor sluggish economic growth impact war Ukraine', 'time understand issue good address', 'foremost need continue improve aspect Netflix', 'focus ...
#
#
# Report name: FINAL-Q3-22-Shareholder-Letter
# ['summary   revenue operate income membership slightly exceed forecast Q3’22  ', 'big hit tv film Q3 launch watch series film time include   monster Jeffrey Dahmer Story Stranger thingss4,extraordinary Attorney Woo Gray Man andPurple Hearts   lower price ad support plan launch 12 country November month initial announcement', 'exist plan remain ad free  ', 'Netflix high engagement streamer room growth   UK Netflix account 8.2 video viewing 2.3x Amazon 2.7x disney+1   Netflix account 7.6 tv time 2.6x Amazon 1.4x Disney + Hulu + Hulu Live2  ', 'competitor invest heavily drive subscriber engagement build large successful streaming business hard estimate lose money combine 2022 operating loss $ 10 billion vs. Netflix $ 5 $ 6 billion annual operating profit', 'challenging half believe path reaccelerate growth', 'key please member', 'focus win competition view day', 'series movie excite member tell friend people watch join stay', '1base report fromBARB September 2022 2based onNielsen Gauge August 2022 Q3 result 6 year year revenue growth Q3 drive 5 increase average pay membership 1 rise ARM3', 'exclude impact foreign exchange F X revenue ARM grow 13 8 year year respectively', 'sequential decline revenue entirely F X. forecast pay net addition total 2.4 million vs. 1.0 m forecast compare 4.4 m year ago quarter  ', 'APAC revenue grow 19 exclude F X average pay membership rise 23 year year', 'ARM -3 year year exclude F X partially drive low arm India somewhat offset high arm Australia Korea', 'add 1.4 m pay membership region vs. 2.2 m Q3  ', 'exclude F X EMEA revenue ARM grow 13 7 respectively', 'pay net add total 0.6 m vs. 1.8 m year ago quarter  ', 'LATAM revenue increase 19 year year support arm growth 16 vs. year ago quarter exclude F X.', 'add 0.3 m pay membership line membership growth Q3’21  ', 'UCAN penetrated market ARM revenue grow 12 11 respectively exclude F X. pay net add total 0.1 m similar 0.1 m Q3’21', 'Q3 operate income total $ 1.5 billion vs. $ 1.8 billion Q3’21', 'operate income beginning quarter forecast partially high revenue shift timing spend Q3 Q4', 'result operate margin 19 16 forecast', 'percentage point year year decline operate margin entirely appreciation dollar vs. currency period', 'EPS $ 3.10 vs. $ 3.19 year ago include $ 348 million non cash unrealized gain F X remeasurement Euro denominate debt', 'Q4 Forecast reminder quarterly guidance provide actual internal forecast time report', 'appreciation dollar remain significant headwind base multinational general', 'Q4’22 expect revenue $ 7.8 billion sequential decline entirely continue strengthening dollar vs. currency', 'constant currency basis equate 9 year year revenue growth', 'revenue growth forecast drive expectation 4.5 m pay net add vs. 8.3 m Q4’21 arm growth 6 year year exclude F X.', 'pay net add forecast assume experience usual seasonality impact strong content slate counterbalance macroeconomic weakness lead normal visibility', 'optimistic new advertising business expect material contribution Q4’22 launch Basic ad plan intra quarter anticipate grow membership plan gradually time', 'aim 3arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period', 'figure include sale taxis VAT', '2is prospective new member choice switch member current plan', 'member want change remain current plan ad current price', 'forecast Q4’22 operating margin 4 vs. 8 year ago period', 'fourth quarter typically low operating margin quarter year usually large quarter term content marketing spend', 'addition aforementioned F X impact high flow operate income ~75%-80 revenue impact cost dollar', 'exclude year year impact F X Q4’22 operating margin forecast 10 vs. 8 Q4’21', 'theus dollar strengthenedagainst othercurrencie historic rate year', 'base YTD actual Q4 guidance estimate appreciation January 1 2022 negatively impact year 2022 revenue operating income ~$1 billion $ 0.8 billion respectively', 'reminder ...
#
#
# Report name: FINAL-Q4-22-Shareholder-Letter
# ['summary   Q4’22 revenue operate profit membership growth exceed forecast continue lead industry stream engagement revenue profit  ', 'Q4 content slate outperform high expectation   wednesdaywas popular series Harry Meghanour second popular documentary series Trollour popularnon english film andGlass Onion knife Mysteryour fourth popular film1  ', 'successfully launch new lower price ad support plan November pleased early result  ', 'deliver high end operate profit margin target year 2022 expect increase operate margin 2023 vs. 2022  ', '2022 finish 231 M pay membership generate $ 32b revenue $ 5.6b operating income $ 2.0b net cash operate activity $ 1.6b free cash flow FCF', '2023 expect $ 3b FCF assume material swing F X.   Ted Sarandos Greg Peters co ceo Netflix Reed Hastings Executive Chairman complete succession process', '2022 tough year bumpy start bright finish', 'believe clear path reaccelerate revenue growth continue improve aspect Netflix launch pay sharing build ad offer', 'north star remain pleasing member build great profitability time', '1as define cumulative view hour 28 day 1Ted Sarandos Greg Peters co ceo complete succession process Reed Hastings Executive Chairman Greg Peters step COO Ted Sarandos co ceo member Netflix board', 'Reed Greg Ted work closely 15 year make formal externally operate internally', 'detail ourblog', 'Ted say want thank Reed visionary leadership mentorship friendship 20 year', 'learn intellectual rigor honesty willingness big bet look forward work year come', 'Reed start delegate management Greg build strong operating model base share value like minded approach growth', 'excited start new chapter Greg co ceo', 'Greg say feel humble privileged co ceo Netflix', 'Ted work year build tremendous trust respect', 'motivate goal desire well serve member continue grow business', 'addition change Bela Bajaria Head Global TV Chief Content Officer Scott Stuber Chairman Netflix Film', 'Ted say Bela Scott outstanding creative executive prove track record Netflix', '2022 premiere popular series film Netflix history include Wednesday Glass Onion Knives Mystery Purple Hearts Monster Jeffrey Dahmer Story Adam Project Harry Meghan testament leadership creativity', 'excited work alongside seek delight audience year come', 'detail Netflix leadership seehere', 'q4 Results Year year revenue growth 2 Q4 10 foreign exchange F X neutral basis2 drive 4 increase average pay membership', 'arm3decline 2 year year grow 5 F X neutral basis2', 'revenue slightly beginning quarterprojection pay net add 7.7 M vs. 8.3 M Q4’21 come high 4.5 M forecast strong acquisition retention drive primarily success Q4 content slate', 'addition dollar depreciate vs. currency quarter result slightly high project ARM', 'operate income $ 550 M Q4 vs. $ 632 M Q4 21', 'guidance forecast $ 330 m primarily high expect revenue slow forecast hiring', 'operate margin Q4 amount 7 compare 8 Q4’21', 'year year decline appreciation dollar', 'year 2022 operate margin amount 18 vs. 2excluding year year effect foreign exchangerate movement', 'Assumes foreign exchange rate remain constant foreign exchange rate corresponding month prior year period', '3arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period', 'figure include sale taxis VAT', '221 FY21', 'base F X rate beginning 2022 exclude $ 150 m restructure charge Q2’22 translate operate margin 20 high end 19%-20 target set inJanuary 2022', 'F X Neutral Operating Margin exclude restructure charge Q2 2022  ', 'base F X rate beginning year exclude $ 150 M restructure cost Q2 2022', 'note Excludes F X impact content amortization title amortize historical blended rate base timing spend', 'EPS Q4’22 $ 0.12 vs. $ 1.33 Q4‘21', '$ 0.36 forecast $ 462 m non cash unrealized loss F X remeasurement Euro denominate debt result depreciation dollar vs. Euro Q4’22', 'reminder approximately $ 5b Euro bond provide natural hedge relative value Eu ...
#
#
# Report name: FINAL-Q1-23-Shareholder-Letter
# ['summary   Q1‘23revenueandoperatingprofitwerein linewithourforecast  ', 'WedeliveredastrongcontentslateinQ1with  ', 'successfulreturningseasonslikeouterbank Ginny&Georgiaandabigsequel filmmurdermystery2  ', 'NewhitsacrossnearlyeverygenreofTVlikeTheNightAgent(nowour6thmostpopular englishlanguagetvshowever),theglory(our5thmostpopularnon englishtvshow ever),fullswing that90sshowandfilmsyoupeopleandluther TheFallenSun   WithMoody’srecentupgrade weachievedinvestmentgradestatus', 'netflixistheleade streamingservicebasedonengagement revenueandprofitandweareworkingtobuildonthat in‘23,byseekingtoexpandoperatingmarginto18%-20%andtogenerateatleast+$3.5Bof freecashflow(upfromourpriorexpectationofatleast$3.0boffcf  ', 'inq1,welaunchedpaidsharinginfourcountriesandarepleasedwiththeresult', 'Weare planningonabroadrollout includingintheUS inQ2  ', 'Givencurrenthealthyperformanceandtrajectoryofourper memberadvertisingeconomic particularlyintheus we’reupgradingouradsexperiencewithmorestreamsandimproved videoqualitytoattractabroaderrangeofconsumer', 'Inshort we’reofftoagoodstartin2023.Asalways ourfocusremainspleasingourmembersand attractinggreatcreatorssothatwecancontinuetobuildawildlysuccessfulbusiness', "Q2'23 inmillionsexceptpersharedata Q1'22 Q2'22 Q3'22 Q4'22", "Q1'23 Forecast Revenue $ 7,868 $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,242 Y Y%Growth 9.8 8.6 5.9 1.9 3.7 3.4 OperatingIncome $ 1,972 $ 1,578 $ 1,533 $ 550 $ 1,714 $ 1,565 OperatingMargin 25.1 19.8 19.3 7.0 21.0 19.0 NetIncome $ 1,597 $ 1,441 $ 1,398 $ 55 $ 1,305 $ 1,283 dilutedeps $ 3.53 $ 3.20 $ 3.10 $ 0.12 $ 2.88 $ 2.84 globalstreamingpaidmembership 221.64 220.67 223.09 230.75 232.50 Y Y%Growth 6.7 5.5 4.5 4.0 4.9 globalstreamingpaidnetaddition -0.20 -0.97 2.41 7.66 1.75 Netcashprovidedbyoperatingactivities $ 923 $ 103 $ 557 $ 444 $ 2,179 freecashflow $ 802 $ 13 $ 472 $ 332 $ 2,117 Shares(FD", '453.0 450.2 450.3 451.6 452.4 Q1 result Revenuegrew4%yearoveryearinQ1(+8%onaforeignexchange(F X)neutralbasis1),consistentwith ourbeginning quarterforecast', 'Averagepaidmembershipsincreased4%yearoveryear whilearm2 was-1%vs Q1’22(+4%onanF Xneutralbasis).Paidnetaddsamountedto1.8MforQ1vs.-0.2Minthe yearagoquarter', 'regionalhighlightsinclude   ucanrevenuegrew8%yearoveryear(bothreportedandf xneutral)drivenbya9%increase inARM(bothreportedandF Xneutral  ', 'EMEArevenuewasdown2%yearoveryear(+6%onanF Xneutralbasis),dueprimarilytoa declineof6%inARM(+1%onanF xneutralbasis),offsetpartiallybya4%increaseinaverage paidmembership  ', 'LATAMrevenueincreased7%yearoveryear(+13%F Xneutral),witha3%riseinARM(+8%F X neutral).paidmembershipdippedby0.4m whichwebelieveisduetopullforwardfromq4 whenwehadabigquarterwith1.8Mpaidnetadds)andongoingmacroeconomicsoftness  ', 'APACrevenuegrew2%yearoveryear(+10%F xneutral).averagepaidmembershipsincrease 17%yearoveryear', 'thisoffseta13%decreaseinarm(-6%f Xneutral),whichwasduetoplan mixandahighermixofmembergrowthincountrieswithlowerpricing', 'Operatingincometotaled$1.7Bvs.$2.0BinQ1‘22 aboveourguidanceforecastof$1.6Bdueto ongoingexpensemanagementandtimingofhiringandcontentspend', 'operatingmarginwas21 comparedto25%intheyearagoperiod', 'Theyearoveryeardeclineinoperatingmarginwasprimarily duetoF x theappreciationoftheusdollaraccountedforroughlythreepercentagepointsoftheyear overyearchangeinoperatingmargin', 'q1’23epsof$2.88(vs.$3.53inq1‘22)wasin linewithour guidanceof$2.82andincludedan$81millionnon cashunrealizedlossfromF Xremeasurementonour Eurodenominateddebt', 'Forecast Ourprimaryfinancialmetricsarerevenueforgrowthandoperatingmarginforprofitability', 'Ourlong termfinancialobjectivesareunchange sustaindoubledigitrevenuegrowth expandoperatingmargin anddelivergrowingpositivefreecashflow', 'thequarterlyguidanceweprovideisouractualinternal forecastatthetimewereport', 'Westriveforaccuracyalthoughtherolloutofmajornewinitiatives(paid sharingandads)leadstoless normalvisibility', 'we’reontracktomeetourfullyear2023financialobjective', 'ForQ2’23,weforecastrevenueof$8.2B up3%yearoveryear or6 ...
#
#
# Report name: FINAL-Q2-23-Shareholder-Letter
# ['  InMay wesuccessfullylaunchedpaidsharingin100+countrie representingmorethan80%of ourrevenuebase  ', 'Revenueineachregionisnowhigherthanpre launch withsign upsalreadyexceeding cancellation  ', 'Paidnetadditionswere5.9MinQ2,andtodaywe’rerollingoutpaidsharingtoalmost alloftheremainingcountrie  ', 'Q2‘23revenueof$8.2Bandoperatingprofitof$1.8Bweregenerallyin linewithour forecast andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad supportedplan', 'We’restilltargetingafullyear2023operatingmarginof18%to20  ', 'We’realeaderintermsofstreamingengagementand perNielsen wehadthetoporiginal streamingseriesintheUSfor24ofthefirst25weeksof2023,andthetopmoviefor21weeks', 'Whilewe’vemadesteadyprogressthisyear wehavemoreworktodotoreaccelerateourgrowth', 'remainfocusedon creatingasteadydrumbeatofmustwatchshowsandmovies;improve monetization;growingtheenjoymentofourgames;andinvestingtoimproveourserviceformember', "Q3'23 inmillionsexceptpersharedata Q2'22 Q3'22 Q4'22 Q1'23 Q2'23", 'Forecast Revenue $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,187 $ 8,520 Y Y%Growth 8.6 5.9 1.9 3.7 2.7 7.5', 'OperatingIncome $ 1,578 $ 1,533 $ 550 $ 1,714 $ 1,827 $ 1,890 OperatingMargin 19.8 19.3 7.0 21.0 22.3 22.2 NetIncome $ 1,441 $ 1,398 $ 55 $ 1,305 $ 1,488 $ 1,580 dilutedeps $ 3.20 $ 3.10 $ 0.12 $ 2.88 $ 3.29 $ 3.52 globalstreamingpaidmembership 220.67 223.09 230.75 232.50 238.39 Y Y%Growth 5.5 4.5 4.0 4.9 8.0 globalstreamingpaidnetaddition -0.97 2.41 7.66 1.75 5.89 netcashprovidedbyoperatingactivitie $ 103 $ 557 $ 444 $ 2,179 $ 1,440 freecashflow $ 13 $ 472 $ 332 $ 2,117 $ 1,339 Shares(FD', '450.2 450.3 451.6 452.4 451.6 Q2 result RevenueinQ2grew3%yearoveryear(+6%onaforeignexchange(F X)neutralbasis1).Revenuegrowth wasdrivenbya6%increaseinaveragepaidmembership whileARM2declined3%yearoveryear(-1 F xneutral).theyear yeararmdeclinewasdrivenbyacombinationoflimitedpriceincreasesover thepast12months(leadinguptothelaunchofpaidsharing),timingofpaidnetadditions(primarilylate inthequarterduetothemay23rolloutofpaidsharinginq2),andahighermixofmembershipgrowth fromlowerarmcountrie', 'Wehadpaidnetadditionsof5.9MforQ2’23(withover1Mpaidnetaddsineachregion)vs.-1.0Min Q2’22aswesuccessfullyrolledoutpaidsharingtomorethan100countries(representingover80%of ourrevenue).q2operatingincometotaled$1.8b up16%vs.$1.6bintheyearagoquarter', 'operate marginwas22%,comparedwith20%inq2’22.bothwereslightlyaheadofourbeginning quarter forecastduetoongoingexpensemanagement slow projectedheadcountgrowthandtimingof contentspend', 'epsinq2amountedto$3.29vs.$3.20inq2’22andincludeda$29millionnon cash unrealizedlossfromF XremeasurementonourEurodenominateddebt whichisrecognizedbelow operatingincomein“interestandotherincome expense', 'Forecast Ourprimaryfinancialmetricsarerevenueforgrowth andoperatingmarginforprofitability', 'Ourgoalis toacceleraterevenuegrowth expandouroperatingmarginanddelivergrowingpositivefreecashflow', 'Asareminder thequarterlyguidanceweprovideisouractualinternalforecastatthetimewereport', 'nowthatwe’velaunchedpaidsharingbroadly wehaveincreasedconfidenceinourfinancialoutlook', 'weexpectrevenuegrowthwillaccelerateinthesecondhalfof2023asmonetizationgrowsfromour', 'mostrecentpaidsharinglaunchandweexpandourinitiativeacrossnearlyallremainingcountriesplus thecontinuedsteadygrowthinourad supportedplan(moredetailsintheMonetizationandRevenue section', 'ForQ3,weforecastrevenueof$8.5B up7%yearoveryearonbothareportedandf Xneutralbasis slightaccelerationfromourq2’23f Xneutralrevenuegrowthrateof6%.OurrevenuegrowthinQ3will comefromgrowthinaveragepaidmembership', 'WeexpectF XneutralARMtobeflattoslightlydown yearoveryear aswearelappingpriceincreasesin2022andwegenerallyhaven’thadpriceincreasesin ourlargestrevenuemarketssincethefirsthalfoflastyear(limitedduringpaidsharingrollout).revenue fromadvertisingandourextramemberfeature3arenotyetmaterialenoughtooffsetthesefactors', 'anticipateq3’23paidnetaddswillbesimilartoq2’23paidnetaddition', ...

# %% [markdown]
# ### Extract sentence and sentiment analyze the sentences

# %%
def analyze_sentiment_of_sentences_with_keywords(joined_sentences, keywords):
    # Initialize the sentiment analysis pipeline
    sentiment_analysis = pipeline("sentiment-analysis")

    # Initialize a dictionary to store the sentences and their sentiment scores for each report
    sentences_with_keywords_and_sentiment_dict = {}

    # Iterate over each report
    for report_name, joined_sentences in joined_sentences.items():

        # For each report, find sentences containing each keyword and analyze their sentiment
        sentences_with_keywords_and_sentiment = {keyword: [] for keyword in keywords}

        for sentence in joined_sentences:
            for keyword in keywords:
                if keyword in sentence.lower():
                    # Analyze the sentiment of the sentence
                    sentiment_result = sentiment_analysis(sentence)[0]
                    sentences_with_keywords_and_sentiment[keyword].append((sentence, sentiment_result))

        # Add the result to the dictionary
        sentences_with_keywords_and_sentiment_dict[report_name] = sentences_with_keywords_and_sentiment

    return sentences_with_keywords_and_sentiment_dict

# Call the function
keywords = ['revenue', 'forecast', 'profit']
sentences_with_keywords_and_sentiment = analyze_sentiment_of_sentences_with_keywords(joined_sentences, keywords)

# Print the results
for report_name, sentences_with_keywords_and_sentiment in sentences_with_keywords_and_sentiment.items():
    print(f"Report name: {report_name}")
    for keyword, sentences in sentences_with_keywords_and_sentiment.items():
        print(f"Keyword: {keyword}")
        for sentence, sentiment in sentences:
            print(f"Sentence: {sentence}")
            print(f"Sentiment: {sentiment}")
        print("\n")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# 2023-08-02 15:34:03.873479: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# Report name: FINAL-Q1-21-Shareholder-Letter
# Keyword: revenue
# Sentence: revenue grow 24 year year line withour beginning quarter forecast operate profit margin reach time high
# Sentiment: {'label': 'POSITIVE', 'score': 0.9941546320915222}
# Sentence: Q1 Results Q2 Forecast Average revenue membership1rose 6 year overyear 5 exclude foreign exchange impact + $ 80 m. operate income $ 2 billion vs. $ 958 millionmore double vs. Q1’20
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9828703999519348}
# Sentence: turn end 2020 big membership revenue base otherwisehave contribute record q1’21 revenue
# Sentiment: {'label': 'POSITIVE', 'score': 0.7947750091552734}
# Sentence: ramp productionlevel late year low content spendin 1average revenue membership ARM define asstreame revenue divide average number streaming pay membership divide number ofmonth period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9983633160591125}
# Sentence: important focuson engagement revenue key indicator success drive flywheel investment ineven amazing story member future growth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9982501864433289}
#
#
# Keyword: forecast
# Sentence: revenue grow 24 year year line withour beginning quarter forecast operate profit margin reach time high
# Sentiment: {'label': 'POSITIVE', 'score': 0.9941546320915222}
# Sentence: finishedq1’21 208 m pay membership 14 year year guidance forecast 210mpaid membership
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9727792143821716}
# Sentence: Q1 Results Q2 Forecast Average revenue membership1rose 6 year overyear 5 exclude foreign exchange impact + $ 80 m. operate income $ 2 billion vs. $ 958 millionmore double vs. Q1’20
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9828703999519348}
# Sentence: exceed guidance forecast primarily timing contentspend
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9960874319076538}
# Sentence: believe competitive intensity materially change quarter material factor inthe variance forecast allof region
# Sentiment: {'label': 'POSITIVE', 'score': 0.8553963899612427}
# Sentence: reminder quarterly guidance provide isour actual internal forecast time report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7242087721824646}
# Sentence: mean quarter result highrelative guidance forecast low see chart
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9983878135681152}
# Sentence: asour membership base continue grow naturally volatility absolute paidnet addition performance vs. forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9642707705497742}
#
#
# Keyword: profit
# Sentence: revenue grow 24 year year line withour beginning quarter forecast operate profit margin reach time high
# Sentiment: {'label': 'POSITIVE', 'score': 0.9941546320915222}
#
#
# Report name: FINAL-Q2-21-Shareholder-Letter
# Keyword: revenue
# Sentence: Q2 revenue increase 19 year year $ 7.3billion operating income rise 36 year year $ 1.8 billion
# Sentiment: {'label': 'POSITIVE', 'score': 0.993477463722229}
# Sentence: q2 result Q3 Forecast Revenue growth drive 11 increase averagepaid stream membership 8 growth average revenue membership ARM)1
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7473174929618835}
# Sentence: similarly retention continue strong well pre covid Q2’19 level average revenueper membership grow 8 year 1average revenue membership ARM define asstreame revenue divide average number streaming pay membership divide number ofmonth period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9775589108467102}
# Sentence: 2with revenue margin increase operatingprofit dollar rise dramatically invest heavily about$100 million quarter 2016 nearly $ 2 billion quarter far 2021
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6737790703773499}
# Sentence: belief isthat steadily improve service betterplease member lead continued growth inour membership base ARM revenue operate margin profit dollar
# Sentiment: {'label': 'POSITIVE', 'score': 0.9938902854919434}
# Sentence: market previouslylaunche mobile plan find mobile plan effective way tointroduce consumer Netflix roughly revenue neutral low average revenueper membership offset incremental acquisition generally well retention
# Sentiment: {'label': 'POSITIVE', 'score': 0.9480124711990356}
#
#
# Keyword: forecast
# Sentence: finish quarter withover 209 m pay membership slightly ahead forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7101755142211914}
# Sentence: summary result forecast Q3
# Sentiment: {'label': 'POSITIVE', 'score': 0.6349904537200928}
# Sentence: q2 result Q3 Forecast Revenue growth drive 11 increase averagepaid stream membership 8 growth average revenue membership ARM)1
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7473174929618835}
# Sentence: add 1.5 m pay membership Q2 slightly aheadof 1.0 m guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8958832025527954}
# Sentence: reminder quarterly guidance provide isour actual internal forecast time report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7242087721824646}
# Sentence: Q3’21 forecast pay net addition 3.5mvs
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9398429989814758}
# Sentence: achieve forecast add 54 m pay netadd past 24 month 27 m annualize basis time period consistentwith pre covid annual rate net addition
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7522164583206177}
# Sentence: forecast ARM grow roughly5 year year FX neutral basis Q3’21
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9806602597236633}
#
#
# Keyword: profit
# Sentence: 2with revenue margin increase operatingprofit dollar rise dramatically invest heavily about$100 million quarter 2016 nearly $ 2 billion quarter far 2021
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6737790703773499}
# Sentence: belief isthat steadily improve service betterplease member lead continued growth inour membership base ARM revenue operate margin profit dollar
# Sentiment: {'label': 'POSITIVE', 'score': 0.9938902854919434}
# Sentence: ourgrowe operating profit allow complementthis priority return capital shareholder
# Sentiment: {'label': 'NEGATIVE', 'score': 0.5453131198883057}
#
#
# Report name: FINAL-Q3-21-Shareholder-Letter
# Keyword: revenue
# Sentence: Q3 grow revenue 16 year year $ 7.5 billion operating income rise 33 vs. prior year quarter $ 1.8 billion
# Sentiment: {'label': 'POSITIVE', 'score': 0.9787514805793762}
# Sentence: Q3 result Q4 Forecast Revenue growth Q3 drive 9 7 increase average pay stream membership ARM1 respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.922314465045929}
# Sentence: UCAN 1ARM Average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9888352751731873}
#
#
# Keyword: forecast
# Sentence: Q3 result Q4 Forecast Revenue growth Q3 drive 9 7 increase average pay stream membership ARM1 respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.922314465045929}
# Sentence: beginning quarter forecast timing content spend low forecast marketing spend
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9993078708648682}
# Sentence: forecast pay net add quarter 4.4 m actual vs. 3.5 m projection end pay membership 214 m 0.4 forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9907209873199463}
# Sentence: reminder quarterly guidance provide actual internal forecast time report strive accuracy
# Sentiment: {'label': 'POSITIVE', 'score': 0.9692850708961487}
# Sentence: Q4’21 forecast pay net add 8.5 m consistent Q4’20 pay net addition
# Sentiment: {'label': 'POSITIVE', 'score': 0.8955652117729187}
# Sentence: year 2021 forecast operate margin 20 slightly well
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944743514060974}
#
#
# Keyword: profit
#
#
# Report name: FINAL-Q4-21-Shareholder-Letter
# Keyword: revenue
# Sentence: year revenue $ 30 billion grow 19 year year operate income $ 6.2 billion rise 35 year year
# Sentiment: {'label': 'POSITIVE', 'score': 0.9986428618431091}
# Sentence: Q4 Results Q1 Forecast Revenue Q4’21 grow 16 year year 9 increase average pay membership
# Sentiment: {'label': 'POSITIVE', 'score': 0.96303391456604}
# Sentence: result year operating margin 21 vs. 18 2020 1arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9829238057136536}
# Sentence: EMEA large contributor pay net add Q4 3.5 m vs. 4.5 m prior year period region deliver record quarterly revenue exceed $ 2.5 billion time
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9521241784095764}
# Sentence: ~60 revenue outside international success estimate dollar appreciation past month cost roughly $ 1 billion expect 2022 revenue reminder hedge
# Sentiment: {'label': 'NEGATIVE', 'score': 0.990721583366394}
# Sentence: goal maximize long term revenue market
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971537590026855}
# Sentence: environmental Social Governance ESG current governance structure serve shareholder extraordinarily sustained period substantial growth clearly prove business model streaming establish business self funding expect sustained positive free cash flow substantially scale revenue operate profit margin
# Sentiment: {'label': 'POSITIVE', 'score': 0.9952287673950195}
#
#
# Keyword: forecast
# Sentence: summary result forecast
# Sentiment: {'label': 'POSITIVE', 'score': 0.9416536688804626}
# Sentence: Q4 Results Q1 Forecast Revenue Q4’21 grow 16 year year 9 increase average pay membership
# Sentiment: {'label': 'POSITIVE', 'score': 0.96303391456604}
# Sentence: operate margin beginning quarter forecast 6.5 slightly low forecast content spend
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9982874989509583}
# Sentence: 1above 20 guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8419808149337769}
# Sentence: slightly forecast pay net add Q4 8.3 m actual compare 8.5 m pay net add year ago quarter beginning quarter projection
# Sentiment: {'label': 'NEGATIVE', 'score': 0.93791264295578}
# Sentence: reminder quarterly guidance provide actual internal forecast time report
# Sentiment: {'label': 'POSITIVE', 'score': 0.653003454208374}
# Sentence: mean quarter result high relative guidance forecast low see chart
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9989134073257446}
# Sentence: membership base continue grow naturally volatility absolute pay net add performance vs. forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9344630241394043}
# Sentence: Q1’22 forecast pay net add 2.5 m vs. 4.0 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9876114726066589}
#
#
# Keyword: profit
# Sentence: environmental Social Governance ESG current governance structure serve shareholder extraordinarily sustained period substantial growth clearly prove business model streaming establish business self funding expect sustained positive free cash flow substantially scale revenue operate profit margin
# Sentiment: {'label': 'POSITIVE', 'score': 0.9952287673950195}
#
#
# Report name: FINAL-Q1-22-Shareholder-Letter
# Keyword: revenue
# Sentence: revenue growth slow considerably result forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9984404444694519}
# Sentence: relatively high household penetration include large number household share account combine competition create revenue growth headwind
# Sentiment: {'label': 'POSITIVE', 'score': 0.8856282830238342}
# Sentence: work reaccelerate revenue growth improvement service effective monetization multi household sharing hold operate margin 20
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9905688166618347}
# Sentence: near term grow revenue fast like
# Sentiment: {'label': 'POSITIVE', 'score': 0.9982832670211792}
# Sentence: high view share indicator high satisfaction support high retention revenue
# Sentiment: {'label': 'POSITIVE', 'score': 0.997194766998291}
# Sentence: 2our plan reaccelerate viewing revenue growth continue improve aspect Netflix particular quality programming recommendation member value
# Sentiment: {'label': 'POSITIVE', 'score': 0.9730191230773926}
# Sentence: large subscription streaming service world key metric pay membership engagement revenue profit
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9579416513442993}
# Sentence: work monetize sharing growth ARM revenue viewing important indicator success membership growth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9956242442131042}
# Sentence: goal sustain double digit revenue growth increase operate income fast expand margin generate grow positive free cash flow FCF
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965685606002808}
# Sentence: period slow revenue growth assume material swing foreign exchange F X aim protect profitability manage minimum operating margin roughly line current level i.e. year 19 20 guidance
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9947958588600159}
# Sentence: accelerated revenue growth committed steadily grow operate margin
# Sentiment: {'label': 'POSITIVE', 'score': 0.9987878203392029}
# Sentence: 10 revenue growth q1’22 drive 8 year year increase average streaming pay membership 2 year year growth ARM2.Excluding F X impact -$280 million year year revenue arm growth +14 +6 respectively
# Sentiment: {'label': 'POSITIVE', 'score': 0.6728251576423645}
# Sentence: recent price change largely track line expectation remain significantly revenue positive
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971534013748169}
# Sentence: UCAN pay net add -0.6 M largely result price change track line expectation significantly revenue positive
# Sentiment: {'label': 'POSITIVE', 'score': 0.9973087310791016}
# Sentence: project revenue grow approximately 10 year year Q2 assume roughly mid high single digit year year 2arm Average Revenue membership define stream revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9425864219665527}
#
#
# Keyword: forecast
# Sentence: revenue growth slow considerably result forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9984404444694519}
# Sentence: Q1 Results Q2 Forecast
# Sentiment: {'label': 'POSITIVE', 'score': 0.9462090730667114}
# Sentence: operate income $ 2.0 billion beginning quarter forecast $ 1.8 billion low project content expense
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9976328611373901}
# Sentence: pay net addition -0.2 m compare guidance forecast 2.5 m 4.0 m quarter year ago
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9900446534156799}
# Sentence: retention slightly low relative guidance forecast remain healthy level believe good industry
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6823549270629883}
# Sentence: reminder quarterly guidance provide actual internal forecast time report
# Sentiment: {'label': 'POSITIVE', 'score': 0.653003454208374}
# Sentence: Q2’22 forecast pay net addition -2.0 m vs. +1.5 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9878569841384888}
# Sentence: forecast assume current trend persist slow acquisition near term impact price change plus typical seasonality Q2 pay net add usually Q1 pay net add
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9948861002922058}
#
#
# Keyword: profit
# Sentence: strong profitability believe foundation significantly improve well monetize service long term
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971644282341003}
# Sentence: growth Outlook launch streaming 2007 operate firm belief internet deliver demand entertainment supplant linear TV transition represent generation opportunity build highly popular profitable entertainment company
# Sentiment: {'label': 'POSITIVE', 'score': 0.996892511844635}
# Sentence: large subscription streaming service world key metric pay membership engagement revenue profit
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9579416513442993}
# Sentence: period slow revenue growth assume material swing foreign exchange F X aim protect profitability manage minimum operating margin roughly line current level i.e. year 19 20 guidance
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9947958588600159}
#
#
# Report name: FINAL-Q2-22-Shareholder-Letter
# Keyword: revenue
# Sentence: Q2 well expect membership growth foreign exchange bad expect strong dollar result 9 revenue growth 13 constant currency
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9719138741493225}
# Sentence: challenge opportunity accelerate revenue membership growth continue improve product content marketing 25 year well monetize big audience
# Sentiment: {'label': 'POSITIVE', 'score': 0.9985503554344177}
# Sentence: position strength give $ 30 billion plus revenue $ 6 billion operating profit year grow free cash flow strong balance sheet
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971792697906494}
# Sentence: q2 result Revenue Q2 grow 9 year year 13 exclude -$339 million foreign currency impact drive 6 2 increase average pay membership ARM1 respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8748611807823181}
# Sentence: appreciation dollar usd vs. currency April earning report primary reason variance revenue guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9766858220100403}
# Sentence: APAC revenue grow 23 year year exclude F X.
# Sentiment: {'label': 'POSITIVE', 'score': 0.7208932042121887}
# Sentence: $ 900 million revenue APAC approach size LATAM business
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9906818866729736}
# Sentence: year year F x neutral basis impact price decrease India December plan mix partially offset 1arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.983674168586731}
# Sentence: exclude F X EMEA revenue ARM increase 13 6 year year respectively pay net addition total -0.8 m vs. 0.2 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9808855652809143}
# Sentence: revenue LATAM grow 19 year year exclude F X surpass $ 1 billion quarterly mark time help constant currency arm growth 15
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8376597762107849}
# Sentence: UCAN arm revenue increase 10 year year exclude impact F X. pay net add -1.3 m vs. -0.4 m year ago period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9691497087478638}
# Sentence: adjust cost structure current rate revenue growth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9915027618408203}
# Sentence: high exposure unprecedented appreciation usd nearly 60 revenue come outside swing F X large flow operate profit expense usd benefit strong usd
# Sentiment: {'label': 'POSITIVE', 'score': 0.9949435591697693}
# Sentence: Q3 revenue growth forecast 5 translate 12 year year revenue growth constant currency basis
# Sentiment: {'label': 'POSITIVE', 'score': 0.9617477059364319}
# Sentence: Content Marketing product quarter discuss slow revenue growth believe result connected tv adoption account sharing competition macro factor sluggish economic growth impact war Ukraine
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9982327222824097}
# Sentence: pure play streaming business unencumbered legacy revenue stream
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958686828613281}
# Sentence: near Term Focus near term key priority accelerate revenue growth evolve improve monetization
# Sentiment: {'label': 'POSITIVE', 'score': 0.988471508026123}
# Sentence: time grow member base ad tier associated ad revenue long run think advertising enable substantial incremental membership low price profit growth ad revenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9696547389030457}
# Sentence: see table F x drive change revenue high flow operate income operate profit impact range ~75 80%+ revenue impact
# Sentiment: {'label': 'POSITIVE', 'score': 0.5877764225006104}
# Sentence: expect annual positive FCF go forward substantial growth FCF 2023 vs. 2022 increase revenue solid profitability successful multi year evolution content model
# Sentiment: {'label': 'POSITIVE', 'score': 0.9987969398498535}
# Sentence: target maintain minimum cash equivalent roughly month revenue eg $ 5.3 billion base Q2 revenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9760611057281494}
# Sentence: Summary reaccelerate revenue growth big challenge
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9923317432403564}
# Sentence: fortunate position strength leader stream entertainment metric revenue engagement subscriber profit free cash flow
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971312284469604}
#
#
# Keyword: forecast
# Sentence: summary result forecast
# Sentiment: {'label': 'POSITIVE', 'score': 0.9416536688804626}
# Sentence: appreciation dollar usd vs. currency April earning report primary reason variance revenue guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9766858220100403}
# Sentence: slightly forecast global pay net add Q2 -1.0 m vs. -2.0 m forecast compare +1.5 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9327335357666016}
# Sentence: exclude item total $ 150 million F X impact strong dollar April report operate profit operating margin slightly ahead guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9040749669075012}
# Sentence: EPS $ 3.20 vs. $ 2.97 year ago exceed guidance forecast $ 3.00 $ 305 million non cash unrealized gain F X remeasurement Euro denominate debt recognize operating income interest income
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9818468689918518}
# Sentence: Q3 Forecast reminder quarterly guidance provide actual internal forecast time report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7595838904380798}
# Sentence: Q3 revenue growth forecast 5 translate 12 year year revenue growth constant currency basis
# Sentiment: {'label': 'POSITIVE', 'score': 0.9617477059364319}
# Sentence: similarly exclude impact currency operate profit growth -3 year year vs forecast decline -29 operate margin 20 vs forecast 16
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9756816029548645}
# Sentence: forecast pay net add Q3 +1.0 m vs. 4.4 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9840750694274902}
#
#
# Keyword: profit
# Sentence: position strength give $ 30 billion plus revenue $ 6 billion operating profit year grow free cash flow strong balance sheet
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971792697906494}
# Sentence: exclude item total $ 150 million F X impact strong dollar April report operate profit operating margin slightly ahead guidance forecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9040749669075012}
# Sentence: high exposure unprecedented appreciation usd nearly 60 revenue come outside swing F X large flow operate profit expense usd benefit strong usd
# Sentiment: {'label': 'POSITIVE', 'score': 0.9949435591697693}
# Sentence: similarly exclude impact currency operate profit growth -3 year year vs forecast decline -29 operate margin 20 vs forecast 16
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9756816029548645}
# Sentence: time grow member base ad tier associated ad revenue long run think advertising enable substantial incremental membership low price profit growth ad revenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9696547389030457}
# Sentence: see table F x drive change revenue high flow operate income operate profit impact range ~75 80%+ revenue impact
# Sentiment: {'label': 'POSITIVE', 'score': 0.5877764225006104}
# Sentence: expect annual positive FCF go forward substantial growth FCF 2023 vs. 2022 increase revenue solid profitability successful multi year evolution content model
# Sentiment: {'label': 'POSITIVE', 'score': 0.9987969398498535}
# Sentence: fortunate position strength leader stream entertainment metric revenue engagement subscriber profit free cash flow
# Sentiment: {'label': 'POSITIVE', 'score': 0.9971312284469604}
#
#
# Report name: FINAL-Q3-22-Shareholder-Letter
# Keyword: revenue
# Sentence: summary   revenue operate income membership slightly exceed forecast Q3’22
# Sentiment: {'label': 'NEGATIVE', 'score': 0.753528356552124}
# Sentence: 1base report fromBARB September 2022 2based onNielsen Gauge August 2022 Q3 result 6 year year revenue growth Q3 drive 5 increase average pay membership 1 rise ARM3
# Sentiment: {'label': 'NEGATIVE', 'score': 0.5392684936523438}
# Sentence: exclude impact foreign exchange F X revenue ARM grow 13 8 year year respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9810581207275391}
# Sentence: sequential decline revenue entirely F X. forecast pay net addition total 2.4 million vs. 1.0 m forecast compare 4.4 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9923900961875916}
# Sentence: APAC revenue grow 19 exclude F X average pay membership rise 23 year year
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7939969301223755}
# Sentence: exclude F X EMEA revenue ARM grow 13 7 respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9964892864227295}
# Sentence: LATAM revenue increase 19 year year support arm growth 16 vs. year ago quarter exclude F X.
# Sentiment: {'label': 'NEGATIVE', 'score': 0.5882991552352905}
# Sentence: UCAN penetrated market ARM revenue grow 12 11 respectively exclude F X. pay net add total 0.1 m similar 0.1 m Q3’21
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9878853559494019}
# Sentence: operate income beginning quarter forecast partially high revenue shift timing spend Q3 Q4
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9946138262748718}
# Sentence: Q4’22 expect revenue $ 7.8 billion sequential decline entirely continue strengthening dollar vs. currency
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9644756317138672}
# Sentence: constant currency basis equate 9 year year revenue growth
# Sentiment: {'label': 'POSITIVE', 'score': 0.995862603187561}
# Sentence: revenue growth forecast drive expectation 4.5 m pay net add vs. 8.3 m Q4’21 arm growth 6 year year exclude F X.
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9707080125808716}
# Sentence: aim 3arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9927197694778442}
# Sentence: addition aforementioned F X impact high flow operate income ~75%-80 revenue impact cost dollar
# Sentiment: {'label': 'POSITIVE', 'score': 0.66107177734375}
# Sentence: base YTD actual Q4 guidance estimate appreciation January 1 2022 negatively impact year 2022 revenue operating income ~$1 billion $ 0.8 billion respectively
# Sentiment: {'label': 'NEGATIVE', 'score': 0.998017430305481}
# Sentence: long term goal remain unchanged sustain double digit revenue growth increase operate profit fast expand margin deliver grow positive free cash flow
# Sentiment: {'label': 'POSITIVE', 'score': 0.9961112141609192}
# Sentence: Guidance Evolution discuss previous letter increasingly focus revenue primary line metric
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9222453236579895}
# Sentence: particularly important heading 2023 develop new revenue stream like advertising pay sharing membership component revenue growth
# Sentiment: {'label': 'POSITIVE', 'score': 0.9935460686683655}
# Sentence: 3starting Q4’22 letter January 2023 continue provide guidance revenue operate income operate margin net income EPS fully diluted share outstanding follow quarter pay membership
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9855144023895264}
# Sentence: reaction advertiser far extremely positive believe choice especially price conscious consumer translate meaningful incremental revenue operating profit time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9908083081245422}
# Sentence: say early day keep exist plan ad free time build membership base associated ad revenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9669327735900879}
# Sentence: 190 country operate $ 30 billion plus annual revenue roughly 5 combine estimate ~$300 billion pay tv stream industry ~$180 billion brand advertising market $ 130 billion consumer spend annually gaming6
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9361093640327454}
# Sentence: excess cash minimum cash level equivalent roughly month revenue return shareholder share repurchase
# Sentiment: {'label': 'NEGATIVE', 'score': 0.980067789554596}
#
#
# Keyword: forecast
# Sentence: summary   revenue operate income membership slightly exceed forecast Q3’22
# Sentiment: {'label': 'NEGATIVE', 'score': 0.753528356552124}
# Sentence: sequential decline revenue entirely F X. forecast pay net addition total 2.4 million vs. 1.0 m forecast compare 4.4 m year ago quarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9923900961875916}
# Sentence: operate income beginning quarter forecast partially high revenue shift timing spend Q3 Q4
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9946138262748718}
# Sentence: result operate margin 19 16 forecast
# Sentiment: {'label': 'POSITIVE', 'score': 0.8380715250968933}
# Sentence: Q4 Forecast reminder quarterly guidance provide actual internal forecast time report
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7421392798423767}
# Sentence: revenue growth forecast drive expectation 4.5 m pay net add vs. 8.3 m Q4’21 arm growth 6 year year exclude F X.
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9707080125808716}
# Sentence: pay net add forecast assume experience usual seasonality impact strong content slate counterbalance macroeconomic weakness lead normal visibility
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9953095316886902}
# Sentence: forecast Q4’22 operating margin 4 vs. 8 year ago period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9430875182151794}
# Sentence: exclude year year impact F X Q4’22 operating margin forecast 10 vs. 8 Q4’21
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9429407119750977}
#
#
# Keyword: profit
# Sentence: competitor invest heavily drive subscriber engagement build large successful streaming business hard estimate lose money combine 2022 operating loss $ 10 billion vs. Netflix $ 5 $ 6 billion annual operating profit
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9976370334625244}
# Sentence: long term goal remain unchanged sustain double digit revenue growth increase operate profit fast expand margin deliver grow positive free cash flow
# Sentiment: {'label': 'POSITIVE', 'score': 0.9961112141609192}
# Sentence: reaction advertiser far extremely positive believe choice especially price conscious consumer translate meaningful incremental revenue operating profit time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9908083081245422}
# Sentence: hard build large profitable streaming business good estimate competitor lose money streaming aggregate annual direct operating loss year excess $ 10 billion compare + $ 5-$6 billion annual operating profit
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9921600222587585}
# Sentence: incumbent entertainment company high level investment understandable give accelerate decline linear TV currently generate bulk profit
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9439258575439453}
# Sentence: ultimately believe competitor seek build sustainable profitable business streaming continued industry consolidation
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7382568717002869}
# Sentence: early day start increase profit focus raise price streaming service reign content spending retrench traditional operating model dilute direct consumer offering
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9907900094985962}
# Sentence: aim remain choice entertainment continue build amazingly successful profitable business
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997569918632507}
#
#
# Report name: FINAL-Q4-22-Shareholder-Letter
# Keyword: revenue
# Sentence: summary   Q4’22 revenue operate profit membership growth exceed forecast continue lead industry stream engagement revenue profit
# Sentiment: {'label': 'POSITIVE', 'score': 0.8706945180892944}
# Sentence: 2022 finish 231 M pay membership generate $ 32b revenue $ 5.6b operating income $ 2.0b net cash operate activity $ 1.6b free cash flow FCF
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9864306449890137}
# Sentence: believe clear path reaccelerate revenue growth continue improve aspect Netflix launch pay sharing build ad offer
# Sentiment: {'label': 'POSITIVE', 'score': 0.5443623661994934}
# Sentence: q4 Results Year year revenue growth 2 Q4 10 foreign exchange F X neutral basis2 drive 4 increase average pay membership
# Sentiment: {'label': 'POSITIVE', 'score': 0.8682200312614441}
# Sentence: revenue slightly beginning quarterprojection pay net add 7.7 M vs. 8.3 M Q4’21 come high 4.5 M forecast strong acquisition retention drive primarily success Q4 content slate
# Sentiment: {'label': 'POSITIVE', 'score': 0.9969621300697327}
# Sentence: guidance forecast $ 330 m primarily high expect revenue slow forecast hiring
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9981462955474854}
# Sentence: 3arm(average Revenue membership define asstreame revenue divide average number streaming pay membership divide number month period
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9908475875854492}
# Sentence: Forecast note Q3’22 shareholder letter revenue primary line metric particularly develop additional revenue stream membership component growth like advertising pay sharing
# Sentiment: {'label': 'POSITIVE', 'score': 0.9478018879890442}
# Sentence: forecast Q1’23 revenue growth 4 8 F x neutral basis
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9826350212097168}
# Sentence: expect F X neutral revenue growth drive combination year year growth average pay membership ARM
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9899341464042664}
# Sentence: borrower household begin activate standalone account extra member account add expect improve overall revenue goal plan pricing change
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9460203051567078}
# Sentence: long term financial objective remain unchanged sustain double digit revenue growth expand operate margin deliver grow positive free cash flow
# Sentiment: {'label': 'POSITIVE', 'score': 0.9957789182662964}
# Sentence: year 2023 continue improve service grow advertising business launch pay sharing expect constant currency revenue growth accelerate course year
# Sentiment: {'label': 'POSITIVE', 'score': 0.9780738949775696}
# Sentence: believe brand television advertising substantial long term incremental revenue profit opportunity Netflix ability stand business month underscore commitment member choice reaccelerate growth
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8372336626052856}
# Sentence: overall reaction launch consumer advertiser confirm belief ad support plan strong unit economic minimum line well comparable ad free plan generate incremental revenue profit impact 2023 modest give build slowly time
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6052074432373047}
# Sentence: example 190 country operate $ 30b+ annual revenue compare combine annual estimate ~$300b pay tv stream industry $ 180b brand tv advertising spend $ 130 billion consumer spend gaming5
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9917581677436829}
# Sentence: compete position strength lead industry term engagement revenue streaming profit
# Sentiment: {'label': 'POSITIVE', 'score': 0.9910876154899597}
# Sentence: say revenue profitability way look business engagement pleased Kantar join Nielsen expand effort BARB publicly report shift linear streaming view share different entertainment company Brazil Mexico Poland
# Sentiment: {'label': 'POSITIVE', 'score': 0.9780566692352295}
# Sentence: target maintain minimum cash equivalent roughly month revenue e.g. $ 5.2b base Q4 revenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9686755537986755}
#
#
# Keyword: forecast
# Sentence: summary   Q4’22 revenue operate profit membership growth exceed forecast continue lead industry stream engagement revenue profit
# Sentiment: {'label': 'POSITIVE', 'score': 0.8706945180892944}
# Sentence: revenue slightly beginning quarterprojection pay net add 7.7 M vs. 8.3 M Q4’21 come high 4.5 M forecast strong acquisition retention drive primarily success Q4 content slate
# Sentiment: {'label': 'POSITIVE', 'score': 0.9969621300697327}
# Sentence: guidance forecast $ 330 m primarily high expect revenue slow forecast hiring
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9981462955474854}
# Sentence: $ 0.36 forecast $ 462 m non cash unrealized loss F X remeasurement Euro denominate debt result depreciation dollar vs. Euro Q4’22
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9893901944160461}
# Sentence: Forecast note Q3’22 shareholder letter revenue primary line metric particularly develop additional revenue stream membership component growth like advertising pay sharing
# Sentiment: {'label': 'POSITIVE', 'score': 0.9478018879890442}
# Sentence: quarterly guidance provide actual internal forecast time report
# Sentiment: {'label': 'POSITIVE', 'score': 0.9108838438987732}
# Sentence: forecast Q1’23 revenue growth 4 8 F x neutral basis
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9826350212097168}
# Sentence: FY22 generate FCF $ 1.6b vs. -$0.2b FY21 forecast approximately $ 1b. decade original programming initiative successfully scale past cash intensive phase buildout
# Sentiment: {'label': 'POSITIVE', 'score': 0.9834327101707458}
#
#
# Keyword: profit
# Sentence: summary   Q4’22 revenue operate profit membership growth exceed forecast continue lead industry stream engagement revenue profit
# Sentiment: {'label': 'POSITIVE', 'score': 0.8706945180892944}
# Sentence: deliver high end operate profit margin target year 2022 expect increase operate margin 2023 vs. 2022
# Sentiment: {'label': 'POSITIVE', 'score': 0.9420273900032043}
# Sentence: north star remain pleasing member build great profitability time
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996803998947144}
# Sentence: expect year year operate profit growth operate margin expansion year assume material swing F X
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9085128307342529}
# Sentence: believe brand television advertising substantial long term incremental revenue profit opportunity Netflix ability stand business month underscore commitment member choice reaccelerate growth
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8372336626052856}
# Sentence: overall reaction launch consumer advertiser confirm belief ad support plan strong unit economic minimum line well comparable ad free plan generate incremental revenue profit impact 2023 modest give build slowly time
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6052074432373047}
# Sentence: easy build large profitable streaming business
# Sentiment: {'label': 'POSITIVE', 'score': 0.9992734789848328}
# Sentence: compete position strength lead industry term engagement revenue streaming profit
# Sentiment: {'label': 'POSITIVE', 'score': 0.9910876154899597}
# Sentence: say revenue profitability way look business engagement pleased Kantar join Nielsen expand effort BARB publicly report shift linear streaming view share different entertainment company Brazil Mexico Poland
# Sentiment: {'label': 'POSITIVE', 'score': 0.9780566692352295}
#
#
# Report name: FINAL-Q1-23-Shareholder-Letter
# Keyword: revenue
# Sentence: summary   Q1‘23revenueandoperatingprofitwerein linewithourforecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9901431798934937}
# Sentence: netflixistheleade streamingservicebasedonengagement revenueandprofitandweareworkingtobuildonthat in‘23,byseekingtoexpandoperatingmarginto18%-20%andtogenerateatleast+$3.5Bof freecashflow(upfromourpriorexpectationofatleast$3.0boffcf
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9946355223655701}
# Sentence: Q1'23 Forecast Revenue $ 7,868 $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,242 Y Y%Growth 9.8 8.6 5.9 1.9 3.7 3.4 OperatingIncome $ 1,972 $ 1,578 $ 1,533 $ 550 $ 1,714 $ 1,565 OperatingMargin 25.1 19.8 19.3 7.0 21.0 19.0 NetIncome $ 1,597 $ 1,441 $ 1,398 $ 55 $ 1,305 $ 1,283 dilutedeps $ 3.53 $ 3.20 $ 3.10 $ 0.12 $ 2.88 $ 2.84 globalstreamingpaidmembership 221.64 220.67 223.09 230.75 232.50 Y Y%Growth 6.7 5.5 4.5 4.0 4.9 globalstreamingpaidnetaddition -0.20 -0.97 2.41 7.66 1.75 Netcashprovidedbyoperatingactivities $ 923 $ 103 $ 557 $ 444 $ 2,179 freecashflow $ 802 $ 13 $ 472 $ 332 $ 2,117 Shares(FD
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9881987571716309}
# Sentence: 453.0 450.2 450.3 451.6 452.4 Q1 result Revenuegrew4%yearoveryearinQ1(+8%onaforeignexchange(F X)neutralbasis1),consistentwith ourbeginning quarterforecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9788374900817871}
# Sentence: regionalhighlightsinclude   ucanrevenuegrew8%yearoveryear(bothreportedandf xneutral)drivenbya9%increase inARM(bothreportedandF Xneutral
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9939365983009338}
# Sentence: EMEArevenuewasdown2%yearoveryear(+6%onanF Xneutralbasis),dueprimarilytoa declineof6%inARM(+1%onanF xneutralbasis),offsetpartiallybya4%increaseinaverage paidmembership
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9982767105102539}
# Sentence: LATAMrevenueincreased7%yearoveryear(+13%F Xneutral),witha3%riseinARM(+8%F X neutral).paidmembershipdippedby0.4m whichwebelieveisduetopullforwardfromq4 whenwehadabigquarterwith1.8Mpaidnetadds)andongoingmacroeconomicsoftness
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9947709441184998}
# Sentence: APACrevenuegrew2%yearoveryear(+10%F xneutral).averagepaidmembershipsincrease 17%yearoveryear
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9926905035972595}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowthandoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9749853014945984}
# Sentence: Ourlong termfinancialobjectivesareunchange sustaindoubledigitrevenuegrowth expandoperatingmargin anddelivergrowingpositivefreecashflow
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9727538228034973}
# Sentence: ForQ2’23,weforecastrevenueof$8.2B up3%yearoveryear or6%growthonanF Xneutralbasis
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9827346205711365}
# Sentence: 2ARM(AverageRevenueperMembership)isdefinedasstreamingrevenuedividedbytheaveragenumberof streamingpaidmembershipsdividedbythenumberofmonthsintheperiod
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9880969524383545}
# Sentence: 2outthetimingofthebroadlaunchfromlateQ1toQ2.Whilethismeansthatsomeoftheexpected membershipgrowthandrevenuebenefitwillfallinQ3ratherthanQ2,webelievethiswillresultina betteroutcomeforbothourmembersandourbusiness(moredetailsintheMonetizationandRevenue section).ThemajorityofouryearoveryearF xneutralrevenuegrowthinq2isexpectedtocomefrom growthinourpaidmembershipbase
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9924611449241638}
# Sentence: weexpectconstantcurrencyrevenuegrowthtoaccelerateoverthecourseofthesecondhalfof2023as wecontinuetoimproveourservice morebroadlyrolloutpaidsharinginq2andgrowouradvertise business
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9878606200218201}
# Sentence: webelieveourabilitytodeliveronourlongtermfinancialtargetswillhingeon1)growingengagement and2)improvingourmonetizationtofuelrevenuegrowthandincreasedprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9241589903831482}
# Sentence: Monetization Revenue Asweimproveourmemberexperiencewithmoremustwatchstories wealsoneedtoimproveour monetization
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9963422417640686}
# Sentence: Thiswillnotonlyhelpreacceleraterevenuegrowthandincreaseoperatingmargin itwill alsoenableustoinvestmoreingreatentertainment
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9905492663383484}
# Sentence: Overtimewe’ve adaptedourpricestomeetlocalneedsandtofurtherdeepenourpenetration includingloweringprice inindiaby20%-60%indecember‘21.thesereduction combinedwithanimprovedslate help growengagementinIndiabynearly30%yearonyearwhileF Xneutralrevenuegrowthin2022 acceleratedto24%(versus19%in2021).Learningfromthissuccess wereducedpricesinanadditional 116countriesinq1.whiletheyrepresentedlessthan5%ofourfy‘22revenue webelievethat increasingadoptioninthesemarketswillhelptomaximizeourrevenuelongerterm
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9878501296043396}
# Sentence: buta borrowersstarttoactivatetheirownaccountsandexistingmembersadd“extramember”accounts seeincreasedacquisitionandrevenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.988034188747406}
# Sentence: Forexample inCanada whichwebelieveisareliablepredictor fortheUS ourpaidmembershipbase4isnowlargerthanpriortothelaunchofpaidsharingandrevenue growthhasacceleratedandisnowgrowingfasterthanintheUS
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9815457463264465}
# Sentence: Asnotedabove whilethiswillshiftsomeofthe membershipgrowthandrevenuebenefitfromq2toq3,webelieveitwillresultinabetteroutcomefor ourmembersandourbusiness
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9889608025550842}
# Sentence: longerterm paidsharingwillensureabiggerrevenuebasefromwhich wecangrowasweimproveourservice
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9952261447906494}
# Sentence: Competition Competitionremainsintenseaswecompetewithsomanyformsofentertainment(linearTV gaming usergeneratedcontent premiumstreamingcontent andsocialmediatonamejustafew).amongour streamingvideocompetitor ourtraditionalentertainmentpeersappeartobefocusedonrevenue diversification(acrosstheatrical linearTVandthirdpartylicensing)astheymanagethroughthehard transitionfromlegacybusinessestostreaming whereasweare“allin”onstreamingandalready generatingsignificantprofitandfreecashflow
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9926067590713501}
# Sentence: Wetarget maintainingminimumcashequivalenttoroughlytwomonthsofrevenue(e.g ,about$5.4BbasedonQ1 revenue).aftermeetingthoseneed weanticipatereturningcashtostockholdersthroughshare repurchase
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9956523776054382}
#
#
# Keyword: forecast
# Sentence: summary   Q1‘23revenueandoperatingprofitwerein linewithourforecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9901431798934937}
# Sentence: Q1'23 Forecast Revenue $ 7,868 $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,242 Y Y%Growth 9.8 8.6 5.9 1.9 3.7 3.4 OperatingIncome $ 1,972 $ 1,578 $ 1,533 $ 550 $ 1,714 $ 1,565 OperatingMargin 25.1 19.8 19.3 7.0 21.0 19.0 NetIncome $ 1,597 $ 1,441 $ 1,398 $ 55 $ 1,305 $ 1,283 dilutedeps $ 3.53 $ 3.20 $ 3.10 $ 0.12 $ 2.88 $ 2.84 globalstreamingpaidmembership 221.64 220.67 223.09 230.75 232.50 Y Y%Growth 6.7 5.5 4.5 4.0 4.9 globalstreamingpaidnetaddition -0.20 -0.97 2.41 7.66 1.75 Netcashprovidedbyoperatingactivities $ 923 $ 103 $ 557 $ 444 $ 2,179 freecashflow $ 802 $ 13 $ 472 $ 332 $ 2,117 Shares(FD
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9881987571716309}
# Sentence: 453.0 450.2 450.3 451.6 452.4 Q1 result Revenuegrew4%yearoveryearinQ1(+8%onaforeignexchange(F X)neutralbasis1),consistentwith ourbeginning quarterforecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9788374900817871}
# Sentence: Operatingincometotaled$1.7Bvs.$2.0BinQ1‘22 aboveourguidanceforecastof$1.6Bdueto ongoingexpensemanagementandtimingofhiringandcontentspend
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9962713718414307}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowthandoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9749853014945984}
# Sentence: thequarterlyguidanceweprovideisouractualinternal forecastatthetimewereport
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9854676127433777}
# Sentence: ForQ2’23,weforecastrevenueof$8.2B up3%yearoveryear or6%growthonanF Xneutralbasis
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9827346205711365}
# Sentence: WeforecastQ2’23operatingincomeof$1.6B(roughlyflatyearoveryear)andanoperatingmarginof 19%vs.20%inq2’22.theyearoveryeardeclineinoperatingmarginisattributabletotheappreciation oftheusdollaragainstmostothercurrenciesoverthepastyear
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9949778914451599}
# Sentence: Freecash flow(FCF)5inQ1totaled$2.1Bcomparedwith$0.8BinlastQ1.AssumingnomaterialswingsinF X nowexpectatleast$3.5boffcfforthefullyear2023,upfromourpriorexpectationofatleast$3.0b. Thisreflectslowercashspendoncontentthanweoriginallyforecasted resultinginayearoveryear decreaseincashcontentspend(bringingour2023cashcontenttocontentamortizationratiocloserto 4ourpaidmembershipcountdoesnotinclude“extramembers
# Sentiment: {'label': 'NEGATIVE', 'score': 0.995245635509491}
#
#
# Keyword: profit
# Sentence: summary   Q1‘23revenueandoperatingprofitwerein linewithourforecast
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9901431798934937}
# Sentence: netflixistheleade streamingservicebasedonengagement revenueandprofitandweareworkingtobuildonthat in‘23,byseekingtoexpandoperatingmarginto18%-20%andtogenerateatleast+$3.5Bof freecashflow(upfromourpriorexpectationofatleast$3.0boffcf
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9946355223655701}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowthandoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9749853014945984}
# Sentence: Wealsoexpectyearoveryearoperatingprofitgrowthandoperatingmarginexpansionforthe fullyear(assumingnomaterialswingsinF x).we’restilltargetinga2023operatingmarginof18%-20 basedonF XratesasofJanuary1,2023
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9552491307258606}
# Sentence: webelieveourabilitytodeliveronourlongtermfinancialtargetswillhingeon1)growingengagement and2)improvingourmonetizationtofuelrevenuegrowthandincreasedprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9241589903831482}
# Sentence: Competition Competitionremainsintenseaswecompetewithsomanyformsofentertainment(linearTV gaming usergeneratedcontent premiumstreamingcontent andsocialmediatonamejustafew).amongour streamingvideocompetitor ourtraditionalentertainmentpeersappeartobefocusedonrevenue diversification(acrosstheatrical linearTVandthirdpartylicensing)astheymanagethroughthehard transitionfromlegacybusinessestostreaming whereasweare“allin”onstreamingandalready generatingsignificantprofitandfreecashflow
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9926067590713501}
#
#
# Report name: FINAL-Q2-23-Shareholder-Letter
# Keyword: revenue
# Sentence:   InMay wesuccessfullylaunchedpaidsharingin100+countrie representingmorethan80%of ourrevenuebase
# Sentiment: {'label': 'NEGATIVE', 'score': 0.979362964630127}
# Sentence: Revenueineachregionisnowhigherthanpre launch withsign upsalreadyexceeding cancellation
# Sentiment: {'label': 'NEGATIVE', 'score': 0.999133288860321}
# Sentence: Q2‘23revenueof$8.2Bandoperatingprofitof$1.8Bweregenerallyin linewithour forecast andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad supportedplan
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9925619959831238}
# Sentence: Forecast Revenue $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,187 $ 8,520 Y Y%Growth 8.6 5.9 1.9 3.7 2.7 7.5
# Sentiment: {'label': 'POSITIVE', 'score': 0.8732399344444275}
# Sentence: 450.2 450.3 451.6 452.4 451.6 Q2 result RevenueinQ2grew3%yearoveryear(+6%onaforeignexchange(F X)neutralbasis1).Revenuegrowth wasdrivenbya6%increaseinaveragepaidmembership whileARM2declined3%yearoveryear(-1 F xneutral).theyear yeararmdeclinewasdrivenbyacombinationoflimitedpriceincreasesover thepast12months(leadinguptothelaunchofpaidsharing),timingofpaidnetadditions(primarilylate inthequarterduetothemay23rolloutofpaidsharinginq2),andahighermixofmembershipgrowth fromlowerarmcountrie
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9932998418807983}
# Sentence: Wehadpaidnetadditionsof5.9MforQ2’23(withover1Mpaidnetaddsineachregion)vs.-1.0Min Q2’22aswesuccessfullyrolledoutpaidsharingtomorethan100countries(representingover80%of ourrevenue).q2operatingincometotaled$1.8b up16%vs.$1.6bintheyearagoquarter
# Sentiment: {'label': 'NEGATIVE', 'score': 0.995243489742279}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowth andoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9799455404281616}
# Sentence: Ourgoalis toacceleraterevenuegrowth expandouroperatingmarginanddelivergrowingpositivefreecashflow
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9853421449661255}
# Sentence: weexpectrevenuegrowthwillaccelerateinthesecondhalfof2023asmonetizationgrowsfromour
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9902321696281433}
# Sentence: mostrecentpaidsharinglaunchandweexpandourinitiativeacrossnearlyallremainingcountriesplus thecontinuedsteadygrowthinourad supportedplan(moredetailsintheMonetizationandRevenue section
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9918158650398254}
# Sentence: ForQ3,weforecastrevenueof$8.5B up7%yearoveryearonbothareportedandf Xneutralbasis slightaccelerationfromourq2’23f Xneutralrevenuegrowthrateof6%.OurrevenuegrowthinQ3will comefromgrowthinaveragepaidmembership
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9931126236915588}
# Sentence: WeexpectF XneutralARMtobeflattoslightlydown yearoveryear aswearelappingpriceincreasesin2022andwegenerallyhaven’thadpriceincreasesin ourlargestrevenuemarketssincethefirsthalfoflastyear(limitedduringpaidsharingrollout).revenue fromadvertisingandourextramemberfeature3arenotyetmaterialenoughtooffsetthesefactors
# Sentiment: {'label': 'NEGATIVE', 'score': 0.99310702085495}
# Sentence: Weexpectthatourrevenue 1excludingtheyearoveryeareffectofforeignexchangeratemovement
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9839276671409607}
# Sentence: 2ARM(AverageRevenueperMembership)isdefinedasstreamingrevenuedividedbytheaveragenumberof streamingpaidmembershipsdividedbythenumberofmonthsintheperiod
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9880969524383545}
# Sentence: 3asareminder extramemberaccountsarenotincludedinourpaidmembershipcountbutaddrevenuethatis includedinARM
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9788447022438049}
# Sentence: 2growthwillacceleratemoresubstantiallyinq4’23aswefurthermonetizeaccountsharingbetween householdsandsteadilygrowouradvertisingrevenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9915408492088318}
# Sentence: monetization Revenue Inadditiontodeliveringanever improvingslateandproductexperience we’vebeenworkingtoimprove ourmonetizationthroughinitiativeslikepaidsharingandadvertising
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9978922009468079}
# Sentence: thiswillallowustogeneratemore revenueoffabiggerbase whichwecanreinvesttomakenetflixevenbetterforourmember
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9934898614883423}
# Sentence: Whilewecontinuetogrowourreach adsplanmembershiphasnearlydoubledsinceQ1 it’sstilloffasmallmembershipbase socurrentadrevenueisn’tmaterialfornetflix
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9936069250106812}
# Sentence: buildinganad businessfromscratchisn’teasyandwehavelotsofhardworkahead butwe’reconfidentthatovertime wecandevelopadvertisingintoamulti billiondollarincrementalrevenuestream
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9829941987991333}
# Sentence: InMay weexpandedpaid sharingto100+countrie whichaccountforover80%ofourrevenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9855018854141235}
# Sentence: arerevenueandpaidmembershippositivevs.priortothelaunchofpaidsharingacrosseveryregionin ourlatestlaunch
# Sentiment: {'label': 'NEGATIVE', 'score': 0.984152615070343}
# Sentence: AndourbigtechcompetitorsApple AmazonandYouTube withtheirbroadreachanddeeppocket continuetoinvestheavilytogrowtheirstreamingrevenue
# Sentiment: {'label': 'NEGATIVE', 'score': 0.984744131565094}
# Sentence: Netflix’srevenuewas$32Bin2022 comparedtonearly$40bforyoutubeacrossallitsproducts7(trailing12 monthbasisasofq1’23)and amazon’s$35bsubscriptionrevenuein2022,ofwhichweassumethemajorityrelatestotheprime bundle8thatincludesshipping videoandotherservice
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9933116436004639}
# Sentence: 8Wedon’tknowhowmuchofAmazon’ssubscriptionrevenueisrelatedtoPrime PrimeVideo orotherdigitaland non awssubscription
# Sentiment: {'label': 'NEGATIVE', 'score': 0.991465151309967}
# Sentence: 6packintermsofengagement revenueandprofitoverthelongterm
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9944650530815125}
# Sentence: 10wetargetmaintainingminimumcashequivalenttoroughlytwomonthsofrevenue(i.e ,about$5.5Bbasedon Q2revenueof$8.2B
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9892727136611938}
#
#
# Keyword: forecast
# Sentence: Q2‘23revenueof$8.2Bandoperatingprofitof$1.8Bweregenerallyin linewithour forecast andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad supportedplan
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9925619959831238}
# Sentence: Forecast Revenue $ 7,970 $ 7,926 $ 7,852 $ 8,162 $ 8,187 $ 8,520 Y Y%Growth 8.6 5.9 1.9 3.7 2.7 7.5
# Sentiment: {'label': 'POSITIVE', 'score': 0.8732399344444275}
# Sentence: operate marginwas22%,comparedwith20%inq2’22.bothwereslightlyaheadofourbeginning quarter forecastduetoongoingexpensemanagement slow projectedheadcountgrowthandtimingof contentspend
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9965800642967224}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowth andoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9799455404281616}
# Sentence: Asareminder thequarterlyguidanceweprovideisouractualinternalforecastatthetimewereport
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865421056747437}
# Sentence: ForQ3,weforecastrevenueof$8.5B up7%yearoveryearonbothareportedandf Xneutralbasis slightaccelerationfromourq2’23f Xneutralrevenuegrowthrateof6%.OurrevenuegrowthinQ3will comefromgrowthinaveragepaidmembership
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9931126236915588}
#
#
# Keyword: profit
# Sentence: Q2‘23revenueof$8.2Bandoperatingprofitof$1.8Bweregenerallyin linewithour forecast andweexpectrevenuegrowthtoaccelerateinthesecondhalfof‘23aswestartto seethefullbenefitsofpaidsharingpluscontinuedsteadygrowthinourad supportedplan
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9925619959831238}
# Sentence: Forecast Ourprimaryfinancialmetricsarerevenueforgrowth andoperatingmarginforprofitability
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9799455404281616}
# Sentence: ourbiggesttraditionalentertainmentcompetitor Disney Comcast NBCU ParamountGlobalandWarnerBrothersDiscovery withtheirlargecontentlibrariesandcreative expertise arenowfocusedonprofitsotheycanbuildsustainable longtermstreamingbusinesse
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9849012494087219}
# Sentence: 6packintermsofengagement revenueandprofitoverthelongterm
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9944650530815125}

# %% [markdown]
# ### sentiment analysis score for each sentence

# %%
import pandas as pd
from transformers import pipeline

def analyze_sentiment_of_sentences_with_keywords(joined_sentences, keywords):
    # Initialize the sentiment analysis pipeline
    sentiment_analysis = pipeline("sentiment-analysis")

    # Initialize a DataFrame to store the total polarity scores for each report
    sentiment_scores_df = pd.DataFrame(columns=['Report', 'Keyword', 'Score'])

    # Iterate over each report
    for report_name, joined_sentences in joined_sentences.items():
        # For each report, find sentences containing each keyword and analyze their sentiment
        for keyword in keywords:
            total_score = 0  # Initialize total score for each keyword
            for sentence in joined_sentences:
                if keyword in sentence.lower():
                    # Analyze the sentiment of the sentence
                    sentiment_result = sentiment_analysis(sentence)[0]
                    # Add to total score
                    if sentiment_result['label'] == 'POSITIVE':
                        total_score += sentiment_result['score']
                    else:
                        total_score -= sentiment_result['score']
            # Append the result to the DataFrame
            sentiment_scores_df = sentiment_scores_df.append({'Report': report_name, 'Keyword': keyword, 'Score': total_score}, ignore_index=True)

    return sentiment_scores_df

# Call the function
keywords = ['revenue', 'forecast', 'profit']
sentiment_scores_df = analyze_sentiment_of_sentences_with_keywords(joined_sentences, keywords)

# Print the results
sentiment_scores_df
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
#                             Report   Keyword      Score
# 0   FINAL-Q1-21-Shareholder-Letter   revenue   0.805946
# 1   FINAL-Q1-21-Shareholder-Letter  forecast  -3.789053
# 2   FINAL-Q1-21-Shareholder-Letter    profit   0.994155
# 3   FINAL-Q2-21-Shareholder-Letter   revenue   2.491843
# 4   FINAL-Q2-21-Shareholder-Letter  forecast  -5.115314
# 5   FINAL-Q2-21-Shareholder-Letter    profit  -0.225202
# 6   FINAL-Q3-21-Shareholder-Letter   revenue  -0.932398
# 7   FINAL-Q3-21-Shareholder-Letter  forecast  -0.053019
# 8   FINAL-Q3-21-Shareholder-Letter    profit   0.000000
# 9   FINAL-Q4-21-Shareholder-Letter   revenue   1.028290
# 10  FINAL-Q4-21-Shareholder-Letter  forecast  -3.141478
# 11  FINAL-Q4-21-Shareholder-Letter    profit   0.995229
# 12  FINAL-Q1-22-Shareholder-Letter   revenue   4.628060
# 13  FINAL-Q1-22-Shareholder-Letter  forecast  -4.052003
# 14  FINAL-Q1-22-Shareholder-Letter    profit   0.041319
# 15  FINAL-Q2-22-Shareholder-Letter   revenue  -3.280668
# 16  FINAL-Q2-22-Shareholder-Letter  forecast  -4.611280
# 17  FINAL-Q2-22-Shareholder-Letter    profit   1.726416
# 18  FINAL-Q3-22-Shareholder-Letter   revenue -11.706920
# 19  FINAL-Q3-22-Shareholder-Letter  forecast  -6.496646
# 20  FINAL-Q3-22-Shareholder-Letter    profit  -1.676093
# 21  FINAL-Q4-22-Shareholder-Letter   revenue  -1.125851
# 22  FINAL-Q4-22-Shareholder-Letter  forecast   1.739604
# 23  FINAL-Q4-22-Shareholder-Letter    profit   3.429866
# 24  FINAL-Q1-23-Shareholder-Letter   revenue -23.671309
# 25  FINAL-Q1-23-Shareholder-Letter  forecast  -8.886862
# 26  FINAL-Q1-23-Shareholder-Letter    profit  -5.831779
# 27  FINAL-Q2-23-Shareholder-Letter   revenue -24.853224
# 28  FINAL-Q2-23-Shareholder-Letter  forecast  -4.075502
# 29  FINAL-Q2-23-Shareholder-Letter    profit  -3.951874

# %%
# Pivot the DataFrame
sentiment_scores_pivot = sentiment_scores_df.pivot(index='Report', columns='Keyword', values='Score')

# Reset the index
sentiment_scores_pivot = sentiment_scores_pivot.reset_index()

# Print the results
sentiment_scores_pivot
# Out:
# Keyword                          Report  forecast    profit    revenue
# 0        FINAL-Q1-21-Shareholder-Letter -3.789053  0.994155   0.805946
# 1        FINAL-Q1-22-Shareholder-Letter -4.052003  0.041319   4.628060
# 2        FINAL-Q1-23-Shareholder-Letter -8.886862 -5.831779 -23.671309
# 3        FINAL-Q2-21-Shareholder-Letter -5.115314 -0.225202   2.491843
# 4        FINAL-Q2-22-Shareholder-Letter -4.611280  1.726416  -3.280668
# 5        FINAL-Q2-23-Shareholder-Letter -4.075502 -3.951874 -24.853224
# 6        FINAL-Q3-21-Shareholder-Letter -0.053019  0.000000  -0.932398
# 7        FINAL-Q3-22-Shareholder-Letter -6.496646 -1.676093 -11.706920
# 8        FINAL-Q4-21-Shareholder-Letter -3.141478  0.995229   1.028290
# 9        FINAL-Q4-22-Shareholder-Letter  1.739604  3.429866  -1.125851

# %%
# Add a new column 'total_score'
sentiment_scores_pivot['total_score'] = sentiment_scores_pivot['revenue'] + sentiment_scores_pivot['forecast'] + sentiment_scores_pivot['profit']

# Print the results
sentiment_scores_pivot
# Out:
# Keyword                          Report  forecast    profit    revenue  \
# 0        FINAL-Q1-21-Shareholder-Letter -3.789053  0.994155   0.805946
# 1        FINAL-Q1-22-Shareholder-Letter -4.052003  0.041319   4.628060
# 2        FINAL-Q1-23-Shareholder-Letter -8.886862 -5.831779 -23.671309
# 3        FINAL-Q2-21-Shareholder-Letter -5.115314 -0.225202   2.491843
# 4        FINAL-Q2-22-Shareholder-Letter -4.611280  1.726416  -3.280668
# 5        FINAL-Q2-23-Shareholder-Letter -4.075502 -3.951874 -24.853224
# 6        FINAL-Q3-21-Shareholder-Letter -0.053019  0.000000  -0.932398
# 7        FINAL-Q3-22-Shareholder-Letter -6.496646 -1.676093 -11.706920
# 8        FINAL-Q4-21-Shareholder-Letter -3.141478  0.995229   1.028290
# 9        FINAL-Q4-22-Shareholder-Letter  1.739604  3.429866  -1.125851
#
# Keyword  total_score
# 0          -1.988953
# 1           0.617376
# 2         -38.389950
# 3          -2.848674
# 4          -6.165532
# 5         -32.880600
# 6          -0.985417
# 7         -19.879659
# 8          -1.117959
# 9           4.043619

# %% [markdown]
# ### Stock price processing

# %%
stock_price = pd.read_csv("NFLX.csv")
stock_price.loc[:, "open_close_diff"] = stock_price.Close - stock_price.Open
stock_price
# Out:
#                            Quater        Date        Open        High  \
# 0  FINAL-Q2-23-Shareholder-Letter  19/07/2023  476.860000  485.000000
# 1  FINAL-Q1-23-Shareholder-Letter  18/04/2023  335.000000  337.190002
# 2  FINAL-Q4-22-Shareholder-Letter  19/01/2023  322.570007  324.890015
# 3  FINAL-Q3-22-Shareholder-Letter  18/10/2022  249.800003  250.369995
# 4  FINAL-Q2-22-Shareholder-Letter  19/07/2022  193.020004  201.970001
# 5  FINAL-Q1-22-Shareholder-Letter  19/04/2022  333.220001  351.679993
# 6  FINAL-Q4-21-Shareholder-Letter  20/01/2022  517.750000  526.640015
# 7  FINAL-Q3-21-Shareholder-Letter  19/10/2021  636.969971  641.000000
# 8  FINAL-Q2-21-Shareholder-Letter  20/07/2021  526.070000  536.640000
# 9  FINAL-Q1-21-Shareholder-Letter  20/04/2021  554.420000  563.560000
#
#           Low       Close   Adj Close      Volume  open_close_diff
# 0  470.000000  477.590000  477.590000    20210900         0.730000
# 1  330.500000  333.700012  333.700012    17944500        -1.299988
# 2  313.390015  315.779999  315.779999    18008200        -6.790008
# 3  237.729996  240.860001  240.860001    25776700        -8.940002
# 4  188.399994  201.630005  201.630005    28178700         8.610001
# 5  333.220001  348.609985  348.609985    20906900        15.389984
# 6  506.929993  508.250000  508.250000    12659000        -9.500000
# 7  632.299988  639.000000  639.000000     7633100         2.030029
# 8  520.300000  531.050000  531.050000   6,930,400         4.980000
# 9  546.300000  549.570000  549.570000  11,257,600        -4.850000

# %% [markdown]
# ### match the polarity score with open_close_diff

# %%
# Merge sentiment_scores_pivot and stock_price DataFrames
final_df = pd.merge(sentiment_scores_pivot, stock_price, left_on='Report', right_on='Quater')

# Print the results
final_df
# Out:
#                            Report  forecast    profit    revenue  total_score  \
# 0  FINAL-Q1-21-Shareholder-Letter -3.789053  0.994155   0.805946    -1.988953
# 1  FINAL-Q1-22-Shareholder-Letter -4.052003  0.041319   4.628060     0.617376
# 2  FINAL-Q1-23-Shareholder-Letter -8.886862 -5.831779 -23.671309   -38.389950
# 3  FINAL-Q2-21-Shareholder-Letter -5.115314 -0.225202   2.491843    -2.848674
# 4  FINAL-Q2-22-Shareholder-Letter -4.611280  1.726416  -3.280668    -6.165532
# 5  FINAL-Q2-23-Shareholder-Letter -4.075502 -3.951874 -24.853224   -32.880600
# 6  FINAL-Q3-21-Shareholder-Letter -0.053019  0.000000  -0.932398    -0.985417
# 7  FINAL-Q3-22-Shareholder-Letter -6.496646 -1.676093 -11.706920   -19.879659
# 8  FINAL-Q4-21-Shareholder-Letter -3.141478  0.995229   1.028290    -1.117959
# 9  FINAL-Q4-22-Shareholder-Letter  1.739604  3.429866  -1.125851     4.043619
#
#                            Quater        Date        Open        High  \
# 0  FINAL-Q1-21-Shareholder-Letter  20/04/2021  554.420000  563.560000
# 1  FINAL-Q1-22-Shareholder-Letter  19/04/2022  333.220001  351.679993
# 2  FINAL-Q1-23-Shareholder-Letter  18/04/2023  335.000000  337.190002
# 3  FINAL-Q2-21-Shareholder-Letter  20/07/2021  526.070000  536.640000
# 4  FINAL-Q2-22-Shareholder-Letter  19/07/2022  193.020004  201.970001
# 5  FINAL-Q2-23-Shareholder-Letter  19/07/2023  476.860000  485.000000
# 6  FINAL-Q3-21-Shareholder-Letter  19/10/2021  636.969971  641.000000
# 7  FINAL-Q3-22-Shareholder-Letter  18/10/2022  249.800003  250.369995
# 8  FINAL-Q4-21-Shareholder-Letter  20/01/2022  517.750000  526.640015
# 9  FINAL-Q4-22-Shareholder-Letter  19/01/2023  322.570007  324.890015
#
#           Low       Close   Adj Close      Volume  open_close_diff
# 0  546.300000  549.570000  549.570000  11,257,600        -4.850000
# 1  333.220001  348.609985  348.609985    20906900        15.389984
# 2  330.500000  333.700012  333.700012    17944500        -1.299988
# 3  520.300000  531.050000  531.050000   6,930,400         4.980000
# 4  188.399994  201.630005  201.630005    28178700         8.610001
# 5  470.000000  477.590000  477.590000    20210900         0.730000
# 6  632.299988  639.000000  639.000000     7633100         2.030029
# 7  237.729996  240.860001  240.860001    25776700        -8.940002
# 8  506.929993  508.250000  508.250000    12659000        -9.500000
# 9  313.390015  315.779999  315.779999    18008200        -6.790008

# %%
final_df = final_df.drop(columns=['Quater'])
final_df
# Out:
#                            Report  forecast    profit    revenue  total_score  \
# 0  FINAL-Q1-21-Shareholder-Letter -3.789053  0.994155   0.805946    -1.988953
# 1  FINAL-Q1-22-Shareholder-Letter -4.052003  0.041319   4.628060     0.617376
# 2  FINAL-Q1-23-Shareholder-Letter -8.886862 -5.831779 -23.671309   -38.389950
# 3  FINAL-Q2-21-Shareholder-Letter -5.115314 -0.225202   2.491843    -2.848674
# 4  FINAL-Q2-22-Shareholder-Letter -4.611280  1.726416  -3.280668    -6.165532
# 5  FINAL-Q2-23-Shareholder-Letter -4.075502 -3.951874 -24.853224   -32.880600
# 6  FINAL-Q3-21-Shareholder-Letter -0.053019  0.000000  -0.932398    -0.985417
# 7  FINAL-Q3-22-Shareholder-Letter -6.496646 -1.676093 -11.706920   -19.879659
# 8  FINAL-Q4-21-Shareholder-Letter -3.141478  0.995229   1.028290    -1.117959
# 9  FINAL-Q4-22-Shareholder-Letter  1.739604  3.429866  -1.125851     4.043619
#
#          Date        Open        High         Low       Close   Adj Close  \
# 0  20/04/2021  554.420000  563.560000  546.300000  549.570000  549.570000
# 1  19/04/2022  333.220001  351.679993  333.220001  348.609985  348.609985
# 2  18/04/2023  335.000000  337.190002  330.500000  333.700012  333.700012
# 3  20/07/2021  526.070000  536.640000  520.300000  531.050000  531.050000
# 4  19/07/2022  193.020004  201.970001  188.399994  201.630005  201.630005
# 5  19/07/2023  476.860000  485.000000  470.000000  477.590000  477.590000
# 6  19/10/2021  636.969971  641.000000  632.299988  639.000000  639.000000
# 7  18/10/2022  249.800003  250.369995  237.729996  240.860001  240.860001
# 8  20/01/2022  517.750000  526.640015  506.929993  508.250000  508.250000
# 9  19/01/2023  322.570007  324.890015  313.390015  315.779999  315.779999
#
#        Volume  open_close_diff
# 0  11,257,600        -4.850000
# 1    20906900        15.389984
# 2    17944500        -1.299988
# 3   6,930,400         4.980000
# 4    28178700         8.610001
# 5    20210900         0.730000
# 6     7633100         2.030029
# 7    25776700        -8.940002
# 8    12659000        -9.500000
# 9    18008200        -6.790008

# %%
final_df['match'] = np.sign(final_df['total_score']) == np.sign(final_df['open_close_diff'])

# Print the results
final_df
# Out:
#                            Report  forecast    profit    revenue  total_score  \
# 0  FINAL-Q1-21-Shareholder-Letter -3.789053  0.994155   0.805946    -1.988953
# 1  FINAL-Q1-22-Shareholder-Letter -4.052003  0.041319   4.628060     0.617376
# 2  FINAL-Q1-23-Shareholder-Letter -8.886862 -5.831779 -23.671309   -38.389950
# 3  FINAL-Q2-21-Shareholder-Letter -5.115314 -0.225202   2.491843    -2.848674
# 4  FINAL-Q2-22-Shareholder-Letter -4.611280  1.726416  -3.280668    -6.165532
# 5  FINAL-Q2-23-Shareholder-Letter -4.075502 -3.951874 -24.853224   -32.880600
# 6  FINAL-Q3-21-Shareholder-Letter -0.053019  0.000000  -0.932398    -0.985417
# 7  FINAL-Q3-22-Shareholder-Letter -6.496646 -1.676093 -11.706920   -19.879659
# 8  FINAL-Q4-21-Shareholder-Letter -3.141478  0.995229   1.028290    -1.117959
# 9  FINAL-Q4-22-Shareholder-Letter  1.739604  3.429866  -1.125851     4.043619
#
#          Date        Open        High         Low       Close   Adj Close  \
# 0  20/04/2021  554.420000  563.560000  546.300000  549.570000  549.570000
# 1  19/04/2022  333.220001  351.679993  333.220001  348.609985  348.609985
# 2  18/04/2023  335.000000  337.190002  330.500000  333.700012  333.700012
# 3  20/07/2021  526.070000  536.640000  520.300000  531.050000  531.050000
# 4  19/07/2022  193.020004  201.970001  188.399994  201.630005  201.630005
# 5  19/07/2023  476.860000  485.000000  470.000000  477.590000  477.590000
# 6  19/10/2021  636.969971  641.000000  632.299988  639.000000  639.000000
# 7  18/10/2022  249.800003  250.369995  237.729996  240.860001  240.860001
# 8  20/01/2022  517.750000  526.640015  506.929993  508.250000  508.250000
# 9  19/01/2023  322.570007  324.890015  313.390015  315.779999  315.779999
#
#        Volume  open_close_diff  match
# 0  11,257,600        -4.850000   True
# 1    20906900        15.389984   True
# 2    17944500        -1.299988   True
# 3   6,930,400         4.980000  False
# 4    28178700         8.610001  False
# 5    20210900         0.730000  False
# 6     7633100         2.030029  False
# 7    25776700        -8.940002   True
# 8    12659000        -9.500000   True
# 9    18008200        -6.790008  False
